# %% [markdown]
# # Clustering Tutorial

# %% [markdown]
# ## What's in scope
# - what is clustering?
# - clustering algorithms
#     - k-means
#     - hierarchical clustering
#         - affinity propagation
# - clustering word embeddings
#     - how to get insight from clusters of word embeddings
# - labeling clusters using a hierarchy

# %% [markdown]
# ## What's not in scope?
# - any other clustering algorithm
# - any other unsupervised learning algorithm

# %% [markdown]
# # What is Clustering?
#
# Remember how we had feature vectors (or word embeddings) that lived in n-dimensional space? Clustering is an [unsupervised learning algorithm](https://en.wikipedia.org/wiki/Unsupervised_learning) that puts similar feature vectors into the same group or cluster.
#
# ![hierarchical clustering](figures/hierarchical-clustering.gif)
#
# ## When should I use clustering?
#
# If you're wondering "what don't I know about this data set?", clustering will give some insight.
#
# Clustering can also be used as a feature extraction piece in the predictive modeling process.

# %%
# first, let's load in the FastText model from before so we're ready to cluster them
import os
from gensim.models import FastText

model_file = os.path.join('models', 'phrased_got_ft.model')
model = FastText.load(model_file)

# %%
# in all of these clustering trials, we'll need a way to link
# the word vector from FastText to the word itself. 

"""
---------------------------------------------------------------
Objective: Keep track of your words and vectors in a smart way
---------------------------------------------------------------
each clustering algorithm will need the input as an iterable of 
vectors (and nothing else)

it'll return a cluster model object, which has an attribute model.labels_

These labels will be an index of the cluster this vector fell into

But we want to know what _word_ fell into each cluster

So we need a map to know which vector corrresponds to each word

You might want a few jupyter notebook cells to explore 
what the FastText model has (maybe a vocab attribute?)
"""

# %%
model.wv.vocab
# Out:
# {'what': <gensim.models.keyedvectors.Vocab at 0x1a20bb2a58>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x1a20bb2b70>,
#  'they’re': <gensim.models.keyedvectors.Vocab at 0x1a20bb2ba8>,
#  'savages': <gensim.models.keyedvectors.Vocab at 0x1a20bb2c18>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1a20bb2c88>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x1a20bb2cf8>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x1a20bb2d30>,
#  'goat': <gensim.models.keyedvectors.Vocab at 0x1a20bb2da0>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x1a20bb2e10>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x1a20bb2e80>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x1a20bb2ef0>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x1a20bb2f60>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x1a20bb2fd0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x1a20bbd080>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x1a20bbd0f0>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x1a20bbd160>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x1a20bbd1d0>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x1a20bbd240>,
#  'pieces': <gensim.models.keyedvectors.Vocab at 0x1a20bbd2b0>,
#  'i’ve': <gensim.models.keyedvectors.Vocab at 0x1a20bbd2e8>,
#  'never_seen': <gensim.models.keyedvectors.Vocab at 0x1a20bbd320>,
#  'wildlings': <gensim.models.keyedvectors.Vocab at 0x1a20bbd358>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x1a20bbd3c8>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x1a20bbd438>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1a20bbd4a8>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x1a20bbd518>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x1a20bbd588>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x1a20bbd5f8>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x1a20bbd668>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x1a20bbd6d8>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1a20bbd748>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x1a20bbd7b8>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x1a20bbd828>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x1a20bbd898>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1a20bbd908>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1a20bbd978>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x1a20bbd9e8>,
#  'dead': <gensim.models.keyedvectors.Vocab at 0x1a20bbda58>,
#  'frighten': <gensim.models.keyedvectors.Vocab at 0x1a20bbda90>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x1a20bbdb00>,
#  'orders': <gensim.models.keyedvectors.Vocab at 0x1a20bbdb70>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x1a20bbdbe0>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x1a20bbdc50>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x1a20bbdcc0>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x1a20bbdd30>,
#  'won’t': <gensim.models.keyedvectors.Vocab at 0x1a20bbdd68>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x1a20bbddd8>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x1a20bbde48>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x1a20bbdeb8>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x1a20bbdf28>,
#  'don’t_think': <gensim.models.keyedvectors.Vocab at 0x1a20bbdf60>,
#  'he’ll': <gensim.models.keyedvectors.Vocab at 0x1a20bbdf98>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x1a20bc3048>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x1a20bc30b8>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x1a20bc3128>,
#  'get_back': <gensim.models.keyedvectors.Vocab at 0x1a20bc3160>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x1a20bc31d0>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x1a20bc3240>,
#  'horse': <gensim.models.keyedvectors.Vocab at 0x1a20bc32b0>,
#  'dead_men': <gensim.models.keyedvectors.Vocab at 0x1a20bc32e8>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x1a20bc3358>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x1a20bc33c8>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x1a20bc3438>,
#  'camp': <gensim.models.keyedvectors.Vocab at 0x1a20bc34a8>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x1a20bc3518>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1a20bc3588>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x1a20bc35f8>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x1a20bc3668>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x1a20bc36d8>,
#  'it’s': <gensim.models.keyedvectors.Vocab at 0x1a20bc3710>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x1a20bc3780>,
#  'father’s': <gensim.models.keyedvectors.Vocab at 0x1a20bc37b8>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x1a20bc37f0>,
#  'mother': <gensim.models.keyedvectors.Vocab at 0x1a20bc3860>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x1a20bc38d0>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1a20bc3940>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x1a20bc39b0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1a20bc3a20>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x1a20bc3a90>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x1a20bc3b00>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x1a20bc3b38>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x1a20bc3ba8>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x1a20bc3c18>,
#  'you’ve': <gensim.models.keyedvectors.Vocab at 0x1a20bc3c50>,
#  'managed': <gensim.models.keyedvectors.Vocab at 0x1a20bc3cc0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x1a20bc3d30>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x1a20bc3da0>,
#  'beautiful': <gensim.models.keyedvectors.Vocab at 0x1a20bc3dd8>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x1a20bc3e48>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x1a20bc3eb8>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x1a20bc3f28>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x1a20bc3f98>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x1a20bc8048>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x1a20bc80b8>,
#  'practicing': <gensim.models.keyedvectors.Vocab at 0x1a20bc80f0>,
#  'bran': <gensim.models.keyedvectors.Vocab at 0x1a20bc8160>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x1a20bc81d0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1a20bc8240>,
#  'relax': <gensim.models.keyedvectors.Vocab at 0x1a20bc82b0>,
#  'bow': <gensim.models.keyedvectors.Vocab at 0x1a20bc8320>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x1a20bc8390>,
#  'jon': <gensim.models.keyedvectors.Vocab at 0x1a20bc8400>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x1a20bc8470>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x1a20bc84e0>,
#  'lord_stark': <gensim.models.keyedvectors.Vocab at 0x1a20bc8518>,
#  'lady': <gensim.models.keyedvectors.Vocab at 0x1a20bc8588>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x1a20bc85f8>,
#  'rode': <gensim.models.keyedvectors.Vocab at 0x1a20bc8668>,
#  'hills': <gensim.models.keyedvectors.Vocab at 0x1a20bc86d8>,
#  'they’ve': <gensim.models.keyedvectors.Vocab at 0x1a20bc8710>,
#  'captured': <gensim.models.keyedvectors.Vocab at 0x1a20bc8748>,
#  'night’s_watch': <gensim.models.keyedvectors.Vocab at 0x1a20bc8780>,
#  'lads': <gensim.models.keyedvectors.Vocab at 0x1a20bc87f0>,
#  'saddle': <gensim.models.keyedvectors.Vocab at 0x1a20bc8860>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x1a20bc88d0>,
#  'horses': <gensim.models.keyedvectors.Vocab at 0x1a20bc8940>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x1a20bc89b0>,
#  'swore_an_oath': <gensim.models.keyedvectors.Vocab at 0x1a20bc89e8>,
#  'cat': <gensim.models.keyedvectors.Vocab at 0x1a20bc8a58>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x1a20bc8ac8>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x1a20bc8b38>,
#  'he’s': <gensim.models.keyedvectors.Vocab at 0x1a20bc8b70>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x1a20bc8be0>,
#  'ned': <gensim.models.keyedvectors.Vocab at 0x1a20bc8c50>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x1a20bc8cc0>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x1a20bc8d30>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x1a20bc8da0>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x1a20bc8e10>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x1a20bc8e80>,
#  'forever': <gensim.models.keyedvectors.Vocab at 0x1a20bc8ef0>,
#  'winter_is_coming': <gensim.models.keyedvectors.Vocab at 0x1a20bc8f28>,
#  'lad': <gensim.models.keyedvectors.Vocab at 0x1a20bc8f98>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x1a20bce048>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x1a20bce0b8>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x1a20bce128>,
#  'white_walkers': <gensim.models.keyedvectors.Vocab at 0x1a20bce160>,
#  'saw': <gensim.models.keyedvectors.Vocab at 0x1a20bce1d0>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x1a20bce240>,
#  'oath': <gensim.models.keyedvectors.Vocab at 0x1a20bce2b0>,
#  'i’m': <gensim.models.keyedvectors.Vocab at 0x1a20bce2e8>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x1a20bce358>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x1a20bce3c8>,
#  'wall': <gensim.models.keyedvectors.Vocab at 0x1a20bce438>,
#  'warned': <gensim.models.keyedvectors.Vocab at 0x1a20bce4a8>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x1a20bce518>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x1a20bce588>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1a20bce5f8>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x1a20bce668>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x1a20bce6d8>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x1a20bce748>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x1a20bce7b8>,
#  'coward': <gensim.models.keyedvectors.Vocab at 0x1a20bce828>,
#  'i’m_sorry': <gensim.models.keyedvectors.Vocab at 0x1a20bce860>,
#  'forgive': <gensim.models.keyedvectors.Vocab at 0x1a20bce8d0>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x1a20bce940>,
#  'lord': <gensim.models.keyedvectors.Vocab at 0x1a20bce9b0>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x1a20bcea20>,
#  'robert': <gensim.models.keyedvectors.Vocab at 0x1a20bcea90>,
#  'house_baratheon': <gensim.models.keyedvectors.Vocab at 0x1a20bceac8>,
#  'first_of_his_name': <gensim.models.keyedvectors.Vocab at 0x1a20bceb00>,
#  'don’t': <gensim.models.keyedvectors.Vocab at 0x1a20bceb38>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x1a20bceba8>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x1a20bcec18>,
#  'king_of_the_andals_and_the_first_men': <gensim.models.keyedvectors.Vocab at 0x1a20bcec50>,
#  'father': <gensim.models.keyedvectors.Vocab at 0x1a20bcecc0>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x1a20bced30>,
#  'lord_of_the_seven_kingdoms': <gensim.models.keyedvectors.Vocab at 0x1a20bced68>,
#  'protector_of_the_realm': <gensim.models.keyedvectors.Vocab at 0x1a20bceda0>,
#  'house_stark': <gensim.models.keyedvectors.Vocab at 0x1a20bcedd8>,
#  'lord_of_winterfell': <gensim.models.keyedvectors.Vocab at 0x1a20bcee10>,
#  'warden_of_the_north': <gensim.models.keyedvectors.Vocab at 0x1a20bcee48>,
#  'sentence': <gensim.models.keyedvectors.Vocab at 0x1a20bcee80>,
#  'die': <gensim.models.keyedvectors.Vocab at 0x1a20bceef0>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x1a20bcef60>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x1a20bcef98>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x1a20bd3048>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x1a20bd30b8>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x1a20bd3128>,
#  'kill': <gensim.models.keyedvectors.Vocab at 0x1a20bd3198>,
#  'him': <gensim.models.keyedvectors.Vocab at 0x1a20bd3208>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x1a20bd3278>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1a20bd32e8>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x1a20bd3358>,
#  'passes': <gensim.models.keyedvectors.Vocab at 0x1a20bd33c8>,
#  'swing': <gensim.models.keyedvectors.Vocab at 0x1a20bd3438>,
#  'sword': <gensim.models.keyedvectors.Vocab at 0x1a20bd34a8>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1a20bd3518>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x1a20bd3588>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x1a20bd35f8>,
#  'thousands_of_years': <gensim.models.keyedvectors.Vocab at 0x1a20bd3630>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x1a20bd36a0>,
#  'lying': <gensim.models.keyedvectors.Vocab at 0x1a20bd3710>,
#  'madman': <gensim.models.keyedvectors.Vocab at 0x1a20bd3780>,
#  'sees': <gensim.models.keyedvectors.Vocab at 0x1a20bd37f0>,
#  'mountain': <gensim.models.keyedvectors.Vocab at 0x1a20bd3828>,
#  'lion': <gensim.models.keyedvectors.Vocab at 0x1a20bd3898>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x1a20bd3908>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x1a20bd3978>,
#  'lions': <gensim.models.keyedvectors.Vocab at 0x1a20bd39e8>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x1a20bd3a58>,
#  'woods': <gensim.models.keyedvectors.Vocab at 0x1a20bd3ac8>,
#  'direwolf': <gensim.models.keyedvectors.Vocab at 0x1a20bd3b00>,
#  'tough': <gensim.models.keyedvectors.Vocab at 0x1a20bd3b70>,
#  'beast': <gensim.models.keyedvectors.Vocab at 0x1a20bd3be0>,
#  'south_of_the_wall': <gensim.models.keyedvectors.Vocab at 0x1a20bd3c18>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x1a20bd3c88>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x1a20bd3cf8>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x1a20bd3d68>,
#  'hold': <gensim.models.keyedvectors.Vocab at 0x1a20bd3dd8>,
#  'mother’s': <gensim.models.keyedvectors.Vocab at 0x1a20bd3e10>,
#  'belong': <gensim.models.keyedvectors.Vocab at 0x1a20bd3e80>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x1a20bd3ef0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x1a20bd3f60>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x1a20bd3fd0>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x1a20bd7080>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1a20bd70f0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1a20bd7160>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1a20bd71d0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x1a20bd7240>,
#  'blade': <gensim.models.keyedvectors.Vocab at 0x1a20bd72b0>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1a20bd7320>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x1a20bd7390>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x1a20bd7400>,
#  'yourselves': <gensim.models.keyedvectors.Vocab at 0x1a20bd7438>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x1a20bd74a8>,
#  'bury': <gensim.models.keyedvectors.Vocab at 0x1a20bd7518>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x1a20bd7588>,
#  'stark': <gensim.models.keyedvectors.Vocab at 0x1a20bd75f8>,
#  'one’s': <gensim.models.keyedvectors.Vocab at 0x1a20bd7630>,
#  'yours': <gensim.models.keyedvectors.Vocab at 0x1a20bd76a0>,
#  'snow': <gensim.models.keyedvectors.Vocab at 0x1a20bd7710>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x1a20bd7780>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x1a20bd77f0>,
#  'duty': <gensim.models.keyedvectors.Vocab at 0x1a20bd7860>,
#  'warn': <gensim.models.keyedvectors.Vocab at 0x1a20bd78d0>,
#  'worry': <gensim.models.keyedvectors.Vocab at 0x1a20bd7940>,
#  'starting': <gensim.models.keyedvectors.Vocab at 0x1a20bd7978>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1a20bd79e8>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1a20bd7a58>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x1a20bd7a90>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x1a20bd7b00>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x1a20bd7b70>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x1a20bd7be0>,
#  'casterly_rock': <gensim.models.keyedvectors.Vocab at 0x1a20bd7c18>,
#  'hundred': <gensim.models.keyedvectors.Vocab at 0x1a20bd7c88>,
#  'foot': <gensim.models.keyedvectors.Vocab at 0x1a20bd7cf8>,
#  'drop': <gensim.models.keyedvectors.Vocab at 0x1a20bd7d68>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x1a20bd7dd8>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x1a20bd7e48>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x1a20bd7eb8>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x1a20bd7f28>,
#  'until': <gensim.models.keyedvectors.Vocab at 0x1a20bd7f98>,
#  'told': <gensim.models.keyedvectors.Vocab at 0x1a2130c048>,
#  'we’re': <gensim.models.keyedvectors.Vocab at 0x1a2130c080>,
#  'lannisters': <gensim.models.keyedvectors.Vocab at 0x1a2130c0b8>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x1a2130c128>,
#  'fools': <gensim.models.keyedvectors.Vocab at 0x1a2130c198>,
#  'jon_arryn': <gensim.models.keyedvectors.Vocab at 0x1a2130c1d0>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x1a2130c240>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x1a2130c2b0>,
#  'hand_of_the_king': <gensim.models.keyedvectors.Vocab at 0x1a2130c2e8>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x1a2130c358>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x1a2130c3c8>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1a2130c438>,
#  'feel_like': <gensim.models.keyedvectors.Vocab at 0x1a2130c470>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x1a2130c4e0>,
#  'outsider': <gensim.models.keyedvectors.Vocab at 0x1a2130c518>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1a2130c588>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x1a2130c5f8>,
#  'old_gods': <gensim.models.keyedvectors.Vocab at 0x1a2130c630>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x1a2130c6a0>,
#  'gods': <gensim.models.keyedvectors.Vocab at 0x1a2130c710>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x1a2130c780>,
#  'rules': <gensim.models.keyedvectors.Vocab at 0x1a2130c7f0>,
#  'raven': <gensim.models.keyedvectors.Vocab at 0x1a2130c860>,
#  'kings_landing': <gensim.models.keyedvectors.Vocab at 0x1a2130c898>,
#  'fever': <gensim.models.keyedvectors.Vocab at 0x1a2130c908>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x1a2130c978>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x1a2130c9e8>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x1a2130ca58>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1a2130cac8>,
#  'brought': <gensim.models.keyedvectors.Vocab at 0x1a2130cb38>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x1a2130cba8>,
#  'king': <gensim.models.keyedvectors.Vocab at 0x1a2130cc18>,
#  'rides': <gensim.models.keyedvectors.Vocab at 0x1a2130cc88>,
#  'winterfell': <gensim.models.keyedvectors.Vocab at 0x1a2130ccc0>,
#  'queen': <gensim.models.keyedvectors.Vocab at 0x1a2130cd30>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x1a2130cda0>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x1a2130ce10>,
#  'there’s': <gensim.models.keyedvectors.Vocab at 0x1a2130ce48>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x1a2130ceb8>,
#  'one_thing': <gensim.models.keyedvectors.Vocab at 0x1a2130cef0>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x1a2130cf60>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1a2130cfd0>,
#  'plenty': <gensim.models.keyedvectors.Vocab at 0x1a21311080>,
#  'candles': <gensim.models.keyedvectors.Vocab at 0x1a213110f0>,
#  'chamber': <gensim.models.keyedvectors.Vocab at 0x1a21311160>,
#  'reads': <gensim.models.keyedvectors.Vocab at 0x1a213111d0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x1a21311240>,
#  'drinks': <gensim.models.keyedvectors.Vocab at 0x1a213112b0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1a21311320>,
#  'possibly': <gensim.models.keyedvectors.Vocab at 0x1a21311358>,
#  'drink': <gensim.models.keyedvectors.Vocab at 0x1a213113c8>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x1a21311438>,
#  'we’ve': <gensim.models.keyedvectors.Vocab at 0x1a21311470>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x1a213114e0>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x1a21311550>,
#  'barrels': <gensim.models.keyedvectors.Vocab at 0x1a213115c0>,
#  'ale': <gensim.models.keyedvectors.Vocab at 0x1a21311630>,
#  'perhaps': <gensim.models.keyedvectors.Vocab at 0x1a213116a0>,
#  'we’ll': <gensim.models.keyedvectors.Vocab at 0x1a213116d8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x1a21311748>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x1a213117b8>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1a21311828>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x1a21311898>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x1a21311908>,
#  'bet': <gensim.models.keyedvectors.Vocab at 0x1a21311978>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x1a213119e8>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x1a21311a58>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x1a21311ac8>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x1a21311b38>,
#  'southern': <gensim.models.keyedvectors.Vocab at 0x1a21311b70>,
#  'girls': <gensim.models.keyedvectors.Vocab at 0x1a21311be0>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x1a21311c50>,
#  'stab': <gensim.models.keyedvectors.Vocab at 0x1a21311cc0>,
#  'royal': <gensim.models.keyedvectors.Vocab at 0x1a21311d30>,
#  'never_met': <gensim.models.keyedvectors.Vocab at 0x1a21311d68>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x1a21311dd8>,
#  'likes': <gensim.models.keyedvectors.Vocab at 0x1a21311e48>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x1a21311eb8>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x1a21311f28>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x1a21311f98>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x1a21317048>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x1a213170b8>,
#  'brandon': <gensim.models.keyedvectors.Vocab at 0x1a21317128>,
#  'he’s_got': <gensim.models.keyedvectors.Vocab at 0x1a21317160>,
#  'hundreds': <gensim.models.keyedvectors.Vocab at 0x1a21317198>,
#  'many_times': <gensim.models.keyedvectors.Vocab at 0x1a213171d0>,
#  'climbing': <gensim.models.keyedvectors.Vocab at 0x1a21317208>,
#  'road': <gensim.models.keyedvectors.Vocab at 0x1a21317278>,
#  'promise': <gensim.models.keyedvectors.Vocab at 0x1a213172e8>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x1a21317358>,
#  'lie': <gensim.models.keyedvectors.Vocab at 0x1a213173c8>,
#  'where’s': <gensim.models.keyedvectors.Vocab at 0x1a21317400>,
#  'arya': <gensim.models.keyedvectors.Vocab at 0x1a21317470>,
#  'sansa': <gensim.models.keyedvectors.Vocab at 0x1a213174e0>,
#  'sister': <gensim.models.keyedvectors.Vocab at 0x1a21317550>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x1a213175c0>,
#  'doing': <gensim.models.keyedvectors.Vocab at 0x1a21317630>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1a213176a0>,
#  'grace': <gensim.models.keyedvectors.Vocab at 0x1a21317710>,
#  'you’ve_got': <gensim.models.keyedvectors.Vocab at 0x1a21317748>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x1a213177b8>,
#  'nine_years': <gensim.models.keyedvectors.Vocab at 0x1a213177f0>,
#  'haven’t': <gensim.models.keyedvectors.Vocab at 0x1a21317828>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x1a21317898>,
#  'hell': <gensim.models.keyedvectors.Vocab at 0x1a21317908>,
#  'guarding': <gensim.models.keyedvectors.Vocab at 0x1a21317940>,
#  'imp': <gensim.models.keyedvectors.Vocab at 0x1a213179b0>,
#  'shut': <gensim.models.keyedvectors.Vocab at 0x1a21317a20>,
#  'ooh': <gensim.models.keyedvectors.Vocab at 0x1a21317a90>,
#  'muscles': <gensim.models.keyedvectors.Vocab at 0x1a21317b00>,
#  'you’ll': <gensim.models.keyedvectors.Vocab at 0x1a21317b38>,
#  'soldier': <gensim.models.keyedvectors.Vocab at 0x1a21317ba8>,
#  'that’s': <gensim.models.keyedvectors.Vocab at 0x1a21317be0>,
#  'jaime_lannister': <gensim.models.keyedvectors.Vocab at 0x1a21317c18>,
#  'queen’s': <gensim.models.keyedvectors.Vocab at 0x1a21317c50>,
#  'crypt': <gensim.models.keyedvectors.Vocab at 0x1a21317cc0>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x1a21317d30>,
#  'respects': <gensim.models.keyedvectors.Vocab at 0x1a21317d68>,
#  'riding': <gensim.models.keyedvectors.Vocab at 0x1a21317dd8>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x1a21317e48>,
#  'surely': <gensim.models.keyedvectors.Vocab at 0x1a21317eb8>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x1a21317f28>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x1a21317f98>,
#  'minute': <gensim.models.keyedvectors.Vocab at 0x1a2131c048>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x1a2131c0b8>,
#  'burned': <gensim.models.keyedvectors.Vocab at 0x1a2131c128>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x1a2131c198>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x1a2131c1d0>,
#  'loved': <gensim.models.keyedvectors.Vocab at 0x1a2131c240>,
#  'teach': <gensim.models.keyedvectors.Vocab at 0x1a2131c2b0>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x1a2131c2e8>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x1a2131c358>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x1a2131c3c8>,
#  'skulls': <gensim.models.keyedvectors.Vocab at 0x1a2131c438>,
#  'fuck': <gensim.models.keyedvectors.Vocab at 0x1a2131c4a8>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x1a2131c518>,
#  'aye': <gensim.models.keyedvectors.Vocab at 0x1a2131c588>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x1a2131c5f8>,
#  'didn’t': <gensim.models.keyedvectors.Vocab at 0x1a2131c630>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x1a2131c6a0>,
#  'you’re': <gensim.models.keyedvectors.Vocab at 0x1a2131c6d8>,
#  'damn': <gensim.models.keyedvectors.Vocab at 0x1a2131c748>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1a2131c7b8>,
#  'anybody': <gensim.models.keyedvectors.Vocab at 0x1a2131c828>,
#  'lord_eddard_stark': <gensim.models.keyedvectors.Vocab at 0x1a2131c860>,
#  'worthy': <gensim.models.keyedvectors.Vocab at 0x1a2131c8d0>,
#  'honor': <gensim.models.keyedvectors.Vocab at 0x1a2131c940>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x1a2131c9b0>,
#  'kingdom': <gensim.models.keyedvectors.Vocab at 0x1a2131ca20>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x1a2131ca90>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x1a2131cb00>,
#  'whore': <gensim.models.keyedvectors.Vocab at 0x1a2131cb70>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x1a2131cbe0>,
#  'grave': <gensim.models.keyedvectors.Vocab at 0x1a2131cc50>,
#  'stand': <gensim.models.keyedvectors.Vocab at 0x1a2131ccc0>,
#  'helped': <gensim.models.keyedvectors.Vocab at 0x1a2131cd30>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x1a2131cda0>,
#  'iron_throne': <gensim.models.keyedvectors.Vocab at 0x1a2131cdd8>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x1a2131ce48>,
#  'meant': <gensim.models.keyedvectors.Vocab at 0x1a2131ceb8>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x1a2131cf28>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x1a2131cf60>,
#  'lived': <gensim.models.keyedvectors.Vocab at 0x1a2131cfd0>,
#  'bound': <gensim.models.keyedvectors.Vocab at 0x1a21322080>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x1a213220f0>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x1a21322160>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x1a213221d0>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x1a21322240>,
#  'daughter': <gensim.models.keyedvectors.Vocab at 0x1a21322278>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x1a213222e8>,
#  'houses': <gensim.models.keyedvectors.Vocab at 0x1a21322358>,
#  'northern': <gensim.models.keyedvectors.Vocab at 0x1a21322390>,
#  'king’s': <gensim.models.keyedvectors.Vocab at 0x1a213223c8>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x1a21322400>,
#  'clever': <gensim.models.keyedvectors.Vocab at 0x1a21322470>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x1a213224e0>,
#  'hates': <gensim.models.keyedvectors.Vocab at 0x1a21322550>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x1a213225c0>,
#  'earned': <gensim.models.keyedvectors.Vocab at 0x1a21322630>,
#  'drunken': <gensim.models.keyedvectors.Vocab at 0x1a213226a0>,
#  'manner': <gensim.models.keyedvectors.Vocab at 0x1a21322710>,
#  'expecting': <gensim.models.keyedvectors.Vocab at 0x1a21322748>,
#  'lord_tyrion': <gensim.models.keyedvectors.Vocab at 0x1a21322780>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x1a213227f0>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x1a21322860>,
#  'closed': <gensim.models.keyedvectors.Vocab at 0x1a213228d0>,
#  'door': <gensim.models.keyedvectors.Vocab at 0x1a21322940>,
#  'doubt': <gensim.models.keyedvectors.Vocab at 0x1a213229b0>,
#  'attention': <gensim.models.keyedvectors.Vocab at 0x1a213229e8>,
#  'starks': <gensim.models.keyedvectors.Vocab at 0x1a21322a58>,
#  'sundown': <gensim.models.keyedvectors.Vocab at 0x1a21322ac8>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x1a21322b38>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x1a21322ba8>,
#  'begun': <gensim.models.keyedvectors.Vocab at 0x1a21322c18>,
#  'feast': <gensim.models.keyedvectors.Vocab at 0x1a21322c88>,
#  'bit': <gensim.models.keyedvectors.Vocab at 0x1a21322cf8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1a21322d68>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x1a21322dd8>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x1a21322e48>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x1a21322eb8>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1a21322f28>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x1a21322f98>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1a21326048>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x1a213260b8>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x1a21326128>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x1a21326198>,
#  'hill': <gensim.models.keyedvectors.Vocab at 0x1a21326208>,
#  'somewhere': <gensim.models.keyedvectors.Vocab at 0x1a21326240>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x1a213262b0>,
#  'clouds': <gensim.models.keyedvectors.Vocab at 0x1a21326320>,
#  'above': <gensim.models.keyedvectors.Vocab at 0x1a21326390>,
#  'dreams': <gensim.models.keyedvectors.Vocab at 0x1a21326400>,
#  'every_night': <gensim.models.keyedvectors.Vocab at 0x1a21326438>,
#  'targaryens': <gensim.models.keyedvectors.Vocab at 0x1a21326470>,
#  'daenerys': <gensim.models.keyedvectors.Vocab at 0x1a213264a8>,
#  'bride': <gensim.models.keyedvectors.Vocab at 0x1a21326518>,
#  '–': <gensim.models.keyedvectors.Vocab at 0x1a21326550>,
#  'gift': <gensim.models.keyedvectors.Vocab at 0x1a213265c0>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x1a21326630>,
#  'isn’t': <gensim.models.keyedvectors.Vocab at 0x1a21326668>,
#  'host': <gensim.models.keyedvectors.Vocab at 0x1a213266d8>,
#  'guests': <gensim.models.keyedvectors.Vocab at 0x1a21326748>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x1a213267b8>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1a21326828>,
#  'never_asked': <gensim.models.keyedvectors.Vocab at 0x1a21326860>,
#  'fool': <gensim.models.keyedvectors.Vocab at 0x1a213268d0>,
#  'knows': <gensim.models.keyedvectors.Vocab at 0x1a21326940>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x1a213269b0>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x1a21326a20>,
#  'throne': <gensim.models.keyedvectors.Vocab at 0x1a21326a90>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x1a21326b00>,
#  'woman’s': <gensim.models.keyedvectors.Vocab at 0x1a21326b38>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x1a21326ba8>,
#  'perfect': <gensim.models.keyedvectors.Vocab at 0x1a21326c18>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x1a21326c88>,
#  'don’t_want': <gensim.models.keyedvectors.Vocab at 0x1a21326cc0>,
#  'wake': <gensim.models.keyedvectors.Vocab at 0x1a21326d30>,
#  'dragon': <gensim.models.keyedvectors.Vocab at 0x1a21326da0>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x1a21326e10>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x1a21326e80>,
#  'reign': <gensim.models.keyedvectors.Vocab at 0x1a21326ef0>,
#  'sweet': <gensim.models.keyedvectors.Vocab at 0x1a21326f60>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x1a21326fd0>,
#  'dothraki': <gensim.models.keyedvectors.Vocab at 0x1a2132b048>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x1a2132b0b8>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x1a2132b128>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1a2132b198>,
#  'honored': <gensim.models.keyedvectors.Vocab at 0x1a2132b208>,
#  'viserys': <gensim.models.keyedvectors.Vocab at 0x1a2132b278>,
#  'house_targaryen': <gensim.models.keyedvectors.Vocab at 0x1a2132b2b0>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x1a2132b320>,
#  'rightful_king': <gensim.models.keyedvectors.Vocab at 0x1a2132b358>,
#  'andals_and_the_first_men': <gensim.models.keyedvectors.Vocab at 0x1a2132b390>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1a2132b400>,
#  'defeated': <gensim.models.keyedvectors.Vocab at 0x1a2132b438>,
#  'combat': <gensim.models.keyedvectors.Vocab at 0x1a2132b4a8>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x1a2132b518>,
#  'whole': <gensim.models.keyedvectors.Vocab at 0x1a2132b588>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1a2132b5f8>,
#  'shame': <gensim.models.keyedvectors.Vocab at 0x1a2132b668>,
#  'khal_drogo': <gensim.models.keyedvectors.Vocab at 0x1a2132b6a0>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x1a2132b710>,
#  'savage': <gensim.models.keyedvectors.Vocab at 0x1a2132b780>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x1a2132b7f0>,
#  'finest': <gensim.models.keyedvectors.Vocab at 0x1a2132b860>,
#  'killers': <gensim.models.keyedvectors.Vocab at 0x1a2132b8d0>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x1a2132b940>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x1a2132b9b0>,
#  'dear': <gensim.models.keyedvectors.Vocab at 0x1a2132ba20>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x1a2132ba90>,
#  'ceremony': <gensim.models.keyedvectors.Vocab at 0x1a2132bac8>,
#  'trust': <gensim.models.keyedvectors.Vocab at 0x1a2132bb38>,
#  'we’d': <gensim.models.keyedvectors.Vocab at 0x1a2132bb70>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x1a2132bbe0>,
#  'cross': <gensim.models.keyedvectors.Vocab at 0x1a2132bc50>,
#  'narrow_sea': <gensim.models.keyedvectors.Vocab at 0x1a2132bc88>,
#  'secret': <gensim.models.keyedvectors.Vocab at 0x1a2132bcf8>,
#  'cry': <gensim.models.keyedvectors.Vocab at 0x1a2132bd68>,
#  'true_king': <gensim.models.keyedvectors.Vocab at 0x1a2132bda0>,
#  'married': <gensim.models.keyedvectors.Vocab at 0x1a2132be10>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x1a2132be80>,
#  'wouldn’t': <gensim.models.keyedvectors.Vocab at 0x1a2132beb8>,
#  'kings': <gensim.models.keyedvectors.Vocab at 0x1a2132bf28>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x1a2132bf98>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x1a21332048>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x1a213320b8>,
#  'apologies': <gensim.models.keyedvectors.Vocab at 0x1a213320f0>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x1a21332160>,
#  'offense': <gensim.models.keyedvectors.Vocab at 0x1a213321d0>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x1a21332240>,
#  'drogo': <gensim.models.keyedvectors.Vocab at 0x1a213322b0>,
#  'gives': <gensim.models.keyedvectors.Vocab at 0x1a21332320>,
#  'army': <gensim.models.keyedvectors.Vocab at 0x1a21332390>,
#  'go_home': <gensim.models.keyedvectors.Vocab at 0x1a21332400>,
#  'don’t_know': <gensim.models.keyedvectors.Vocab at 0x1a21332438>,
#  'khal': <gensim.models.keyedvectors.Vocab at 0x1a213324a8>,
#  'prince': <gensim.models.keyedvectors.Vocab at 0x1a21332518>,
#  'ever_lived': <gensim.models.keyedvectors.Vocab at 0x1a21332550>,
#  'handsome': <gensim.models.keyedvectors.Vocab at 0x1a21332588>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x1a213325f8>,
#  'hush': <gensim.models.keyedvectors.Vocab at 0x1a21332668>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1a213326d8>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x1a21332748>,
#  'he’d': <gensim.models.keyedvectors.Vocab at 0x1a21332780>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1a213327f0>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x1a21332860>,
#  'powerful_man': <gensim.models.keyedvectors.Vocab at 0x1a21332898>,
#  'kingdoms': <gensim.models.keyedvectors.Vocab at 0x1a213328d0>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x1a21332940>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x1a213329b0>,
#  'i’d': <gensim.models.keyedvectors.Vocab at 0x1a213329e8>,
#  'someday': <gensim.models.keyedvectors.Vocab at 0x1a21332a58>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1a21332ac8>,
#  'please_please': <gensim.models.keyedvectors.Vocab at 0x1a21332b00>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x1a21332b70>,
#  'bigger': <gensim.models.keyedvectors.Vocab at 0x1a21332be0>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1a21332c50>,
#  'didn’t_want': <gensim.models.keyedvectors.Vocab at 0x1a21332c88>,
#  'aren’t': <gensim.models.keyedvectors.Vocab at 0x1a21332cc0>,
#  'lady_stark': <gensim.models.keyedvectors.Vocab at 0x1a21332cf8>,
#  'insult': <gensim.models.keyedvectors.Vocab at 0x1a21332d68>,
#  'seat': <gensim.models.keyedvectors.Vocab at 0x1a21332dd8>,
#  'bastard': <gensim.models.keyedvectors.Vocab at 0x1a21332e48>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x1a21332eb8>,
#  'refused': <gensim.models.keyedvectors.Vocab at 0x1a21332f28>,
#  'going_anywhere': <gensim.models.keyedvectors.Vocab at 0x1a21332f60>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x1a21332fd0>,
#  'swear': <gensim.models.keyedvectors.Vocab at 0x1a21336080>,
#  'don’t_understand': <gensim.models.keyedvectors.Vocab at 0x1a213360b8>,
#  'you’d': <gensim.models.keyedvectors.Vocab at 0x1a213360f0>,
#  'giving': <gensim.models.keyedvectors.Vocab at 0x1a21336160>,
#  'families': <gensim.models.keyedvectors.Vocab at 0x1a21336198>,
#  'none_of_us': <gensim.models.keyedvectors.Vocab at 0x1a213361d0>,
#  'sons': <gensim.models.keyedvectors.Vocab at 0x1a21336240>,
#  'don’t_care': <gensim.models.keyedvectors.Vocab at 0x1a21336278>,
#  'knew': <gensim.models.keyedvectors.Vocab at 0x1a213362e8>,
#  'inside': <gensim.models.keyedvectors.Vocab at 0x1a21336358>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x1a213363c8>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x1a21336438>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x1a213364a8>,
#  'what’re': <gensim.models.keyedvectors.Vocab at 0x1a213364e0>,
#  'preparing': <gensim.models.keyedvectors.Vocab at 0x1a21336518>,
#  'always_wanted': <gensim.models.keyedvectors.Vocab at 0x1a21336550>,
#  'tyrion_lannister': <gensim.models.keyedvectors.Vocab at 0x1a21336588>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x1a213365c0>,
#  'stark’s': <gensim.models.keyedvectors.Vocab at 0x1a213365f8>,
#  'offend': <gensim.models.keyedvectors.Vocab at 0x1a21336668>,
#  'sorry': <gensim.models.keyedvectors.Vocab at 0x1a213366d8>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x1a21336748>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x1a213367b8>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x1a21336828>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x1a21336898>,
#  'never_forget': <gensim.models.keyedvectors.Vocab at 0x1a213368d0>,
#  'wear': <gensim.models.keyedvectors.Vocab at 0x1a21336940>,
#  'armor': <gensim.models.keyedvectors.Vocab at 0x1a213369b0>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x1a21336a20>,
#  'hurt': <gensim.models.keyedvectors.Vocab at 0x1a21336a90>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x1a21336b00>,
#  'bastards': <gensim.models.keyedvectors.Vocab at 0x1a21336b38>,
#  'eyes': <gensim.models.keyedvectors.Vocab at 0x1a21336ba8>,
#  'bear': <gensim.models.keyedvectors.Vocab at 0x1a21336c18>,
#  'trap': <gensim.models.keyedvectors.Vocab at 0x1a21336c88>,
#  'beheaded': <gensim.models.keyedvectors.Vocab at 0x1a21336cc0>,
#  'ranger': <gensim.models.keyedvectors.Vocab at 0x1a21336d30>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x1a21336da0>,
#  'madness': <gensim.models.keyedvectors.Vocab at 0x1a21336e10>,
#  'walkers': <gensim.models.keyedvectors.Vocab at 0x1a21336e80>,
#  'slaughtered': <gensim.models.keyedvectors.Vocab at 0x1a21336eb8>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x1a21336f28>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x1a21336f98>,
#  'wildling': <gensim.models.keyedvectors.Vocab at 0x1a21336fd0>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x1a2133b080>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1a2133b0f0>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x1a2133b160>,
#  'uncle': <gensim.models.keyedvectors.Vocab at 0x1a2133b1d0>,
#  'benjen': <gensim.models.keyedvectors.Vocab at 0x1a2133b240>,
#  'robb': <gensim.models.keyedvectors.Vocab at 0x1a2133b2b0>,
#  'catelyn': <gensim.models.keyedvectors.Vocab at 0x1a2133b320>,
#  'first_time': <gensim.models.keyedvectors.Vocab at 0x1a2133b358>,
#  'lovely': <gensim.models.keyedvectors.Vocab at 0x1a2133b3c8>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x1a2133b438>,
#  'i’m_sure': <gensim.models.keyedvectors.Vocab at 0x1a2133b470>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x1a2133b4e0>,
#  'grim': <gensim.models.keyedvectors.Vocab at 0x1a2133b550>,
#  'scared': <gensim.models.keyedvectors.Vocab at 0x1a2133b5c0>,
#  'hello': <gensim.models.keyedvectors.Vocab at 0x1a2133b630>,
#  'dove': <gensim.models.keyedvectors.Vocab at 0x1a2133b6a0>,
#  'beauty': <gensim.models.keyedvectors.Vocab at 0x1a2133b710>,
#  'thirteen': <gensim.models.keyedvectors.Vocab at 0x1a2133b748>,
#  'tall': <gensim.models.keyedvectors.Vocab at 0x1a2133b7b8>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x1a2133b828>,
#  'bled': <gensim.models.keyedvectors.Vocab at 0x1a2133b898>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1a2133b908>,
#  'dress': <gensim.models.keyedvectors.Vocab at 0x1a2133b978>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x1a2133b9e8>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x1a2133ba58>,
#  'capital': <gensim.models.keyedvectors.Vocab at 0x1a2133bac8>,
#  'shouldn’t': <gensim.models.keyedvectors.Vocab at 0x1a2133bb00>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x1a2133bb70>,
#  'pardon': <gensim.models.keyedvectors.Vocab at 0x1a2133bbe0>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x1a2133bc50>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x1a2133bcc0>,
#  'tournament': <gensim.models.keyedvectors.Vocab at 0x1a2133bcf8>,
#  'celebrate': <gensim.models.keyedvectors.Vocab at 0x1a2133bd30>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1a2133bda0>,
#  'title': <gensim.models.keyedvectors.Vocab at 0x1a2133be10>,
#  'accept': <gensim.models.keyedvectors.Vocab at 0x1a2133be80>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x1a2133bef0>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x1a2133bf60>,
#  'fight': <gensim.models.keyedvectors.Vocab at 0x1a2133bfd0>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x1a21342080>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x1a213420f0>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x1a21342160>,
#  'south': <gensim.models.keyedvectors.Vocab at 0x1a213421d0>,
#  'takes': <gensim.models.keyedvectors.Vocab at 0x1a21342240>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x1a213422b0>,
#  'i’ll': <gensim.models.keyedvectors.Vocab at 0x1a213422e8>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x1a21342358>,
#  'anywhere': <gensim.models.keyedvectors.Vocab at 0x1a21342390>,
#  'belongs': <gensim.models.keyedvectors.Vocab at 0x1a21342400>,
#  'stops': <gensim.models.keyedvectors.Vocab at 0x1a21342470>,
#  'eating': <gensim.models.keyedvectors.Vocab at 0x1a213424e0>,
#  'it’s_time': <gensim.models.keyedvectors.Vocab at 0x1a21342518>,
#  'maester_luwin': <gensim.models.keyedvectors.Vocab at 0x1a21342550>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x1a213425c0>,
#  'rider': <gensim.models.keyedvectors.Vocab at 0x1a21342630>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x1a213426a0>,
#  'eyrie': <gensim.models.keyedvectors.Vocab at 0x1a21342710>,
#  'what’s': <gensim.models.keyedvectors.Vocab at 0x1a21342748>,
#  'wedding': <gensim.models.keyedvectors.Vocab at 0x1a213427b8>,
#  'she’s': <gensim.models.keyedvectors.Vocab at 0x1a213427f0>,
#  'fled': <gensim.models.keyedvectors.Vocab at 0x1a21342860>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x1a213428d0>,
#  'murdered': <gensim.models.keyedvectors.Vocab at 0x1a21342908>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x1a21342978>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x1a213429e8>,
#  'doesn’t': <gensim.models.keyedvectors.Vocab at 0x1a21342a20>,
#  'saying': <gensim.models.keyedvectors.Vocab at 0x1a21342a90>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x1a21342b00>,
#  'spike': <gensim.models.keyedvectors.Vocab at 0x1a21342b70>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x1a21342be0>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x1a21342c50>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x1a21342cc0>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x1a21342d30>,
#  'son’s': <gensim.models.keyedvectors.Vocab at 0x1a21342d68>,
#  'wasn’t': <gensim.models.keyedvectors.Vocab at 0x1a21342da0>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x1a21342e10>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x1a21342e80>,
#  'protect': <gensim.models.keyedvectors.Vocab at 0x1a21342ef0>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x1a21342f60>,
#  'trusts': <gensim.models.keyedvectors.Vocab at 0x1a21342fd0>,
#  'swore': <gensim.models.keyedvectors.Vocab at 0x1a21347080>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x1a213470f0>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x1a21347160>,
#  'fighting': <gensim.models.keyedvectors.Vocab at 0x1a21347198>,
#  'robert’s': <gensim.models.keyedvectors.Vocab at 0x1a213471d0>,
#  'wars': <gensim.models.keyedvectors.Vocab at 0x1a21347240>,
#  'owes': <gensim.models.keyedvectors.Vocab at 0x1a213472b0>,
#  'once': <gensim.models.keyedvectors.Vocab at 0x1a21347320>,
#  'demand': <gensim.models.keyedvectors.Vocab at 0x1a21347390>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x1a213473c8>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x1a21347438>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x1a213474a8>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x1a213474e0>,
#  'promised': <gensim.models.keyedvectors.Vocab at 0x1a21347518>,
#  'crown': <gensim.models.keyedvectors.Vocab at 0x1a21347588>,
#  'shall': <gensim.models.keyedvectors.Vocab at 0x1a213475f8>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x1a21347668>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x1a213476d8>,
#  'piss': <gensim.models.keyedvectors.Vocab at 0x1a21347748>,
#  'waited': <gensim.models.keyedvectors.Vocab at 0x1a213477b8>,
#  '17': <gensim.models.keyedvectors.Vocab at 0x1a21347828>,
#  'ser': <gensim.models.keyedvectors.Vocab at 0x1a21347898>,
#  'ser_jorah': <gensim.models.keyedvectors.Vocab at 0x1a213478d0>,
#  'mormont': <gensim.models.keyedvectors.Vocab at 0x1a21347940>,
#  'bear_island': <gensim.models.keyedvectors.Vocab at 0x1a21347978>,
#  'served': <gensim.models.keyedvectors.Vocab at 0x1a213479e8>,
#  'many_years': <gensim.models.keyedvectors.Vocab at 0x1a21347a20>,
#  'serve': <gensim.models.keyedvectors.Vocab at 0x1a21347a90>,
#  'eggs': <gensim.models.keyedvectors.Vocab at 0x1a21347b00>,
#  'shadow': <gensim.models.keyedvectors.Vocab at 0x1a21347b70>,
#  'lands': <gensim.models.keyedvectors.Vocab at 0x1a21347be0>,
#  'beyond': <gensim.models.keyedvectors.Vocab at 0x1a21347c50>,
#  'asshai': <gensim.models.keyedvectors.Vocab at 0x1a21347cc0>,
#  'turned': <gensim.models.keyedvectors.Vocab at 0x1a21347d30>,
#  'stone': <gensim.models.keyedvectors.Vocab at 0x1a21347da0>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x1a21347e10>,
#  'tongue': <gensim.models.keyedvectors.Vocab at 0x1a21347e80>,
#  'rough': <gensim.models.keyedvectors.Vocab at 0x1a21347ef0>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1a21347f60>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x1a21347fd0>,
#  'hunter': <gensim.models.keyedvectors.Vocab at 0x1a2134c080>,
#  'land': <gensim.models.keyedvectors.Vocab at 0x1a2134c0f0>,
#  'spear': <gensim.models.keyedvectors.Vocab at 0x1a2134c160>,
#  'hunting': <gensim.models.keyedvectors.Vocab at 0x1a2134c1d0>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x1a2134c240>,
#  'loyal': <gensim.models.keyedvectors.Vocab at 0x1a2134c2b0>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x1a2134c320>,
#  'make_sure': <gensim.models.keyedvectors.Vocab at 0x1a2134c358>,
#  'fucking': <gensim.models.keyedvectors.Vocab at 0x1a2134c3c8>,
#  'boys': <gensim.models.keyedvectors.Vocab at 0x1a2134c438>,
#  'let’s': <gensim.models.keyedvectors.Vocab at 0x1a2134c470>,
#  'boar': <gensim.models.keyedvectors.Vocab at 0x1a2134c4e0>,
#  'stop_stop': <gensim.models.keyedvectors.Vocab at 0x1a2134c518>,
#  'completely': <gensim.models.keyedvectors.Vocab at 0x1a2134c550>,
#  'mad': <gensim.models.keyedvectors.Vocab at 0x1a2134c5c0>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x1a2134c630>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x1a2134c6a0>,
#  'isnt': <gensim.models.keyedvectors.Vocab at 0x1a2134c710>,
#  'anything_else': <gensim.models.keyedvectors.Vocab at 0x1a2134c748>,
#  'grass': <gensim.models.keyedvectors.Vocab at 0x1a2134c7b8>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x1a2134c828>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x1a2134c898>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x1a2134c908>,
#  'ghost': <gensim.models.keyedvectors.Vocab at 0x1a2134c978>,
#  'pale': <gensim.models.keyedvectors.Vocab at 0x1a2134c9e8>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x1a2134ca58>,
#  'murders': <gensim.models.keyedvectors.Vocab at 0x1a2134cac8>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x1a2134cb38>,
#  'one_day': <gensim.models.keyedvectors.Vocab at 0x1a2134cba8>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x1a2134cc18>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x1a2134cc50>,
#  'thats': <gensim.models.keyedvectors.Vocab at 0x1a2134ccc0>,
#  'itll': <gensim.models.keyedvectors.Vocab at 0x1a2134cd30>,
#  'easier': <gensim.models.keyedvectors.Vocab at 0x1a2134cda0>,
#  'khaleesi': <gensim.models.keyedvectors.Vocab at 0x1a2134cdd8>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x1a2134ce48>,
#  'pentos': <gensim.models.keyedvectors.Vocab at 0x1a2134ceb8>,
#  'hospitality': <gensim.models.keyedvectors.Vocab at 0x1a2134cef0>,
#  'youd': <gensim.models.keyedvectors.Vocab at 0x1a2134cf60>,
#  'comfortable': <gensim.models.keyedvectors.Vocab at 0x1a2134cf98>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x1a2134cfd0>,
#  'comfort': <gensim.models.keyedvectors.Vocab at 0x1a21352080>,
#  'ill': <gensim.models.keyedvectors.Vocab at 0x1a213520f0>,
#  'bargain': <gensim.models.keyedvectors.Vocab at 0x1a21352160>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x1a213521d0>,
#  'suppose': <gensim.models.keyedvectors.Vocab at 0x1a21352240>,
#  'beheading': <gensim.models.keyedvectors.Vocab at 0x1a21352278>,
#  'ned_stark': <gensim.models.keyedvectors.Vocab at 0x1a213522b0>,
#  'buying': <gensim.models.keyedvectors.Vocab at 0x1a21352320>,
#  'slaver': <gensim.models.keyedvectors.Vocab at 0x1a21352390>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x1a21352400>,
#  'caught': <gensim.models.keyedvectors.Vocab at 0x1a21352470>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x1a213524e0>,
#  'wont': <gensim.models.keyedvectors.Vocab at 0x1a21352550>,
#  'punished': <gensim.models.keyedvectors.Vocab at 0x1a21352588>,
#  'nonsense': <gensim.models.keyedvectors.Vocab at 0x1a213525c0>,
#  'assured': <gensim.models.keyedvectors.Vocab at 0x1a21352630>,
#  'bitches': <gensim.models.keyedvectors.Vocab at 0x1a213526a0>,
#  'youre': <gensim.models.keyedvectors.Vocab at 0x1a21352710>,
#  'mothers': <gensim.models.keyedvectors.Vocab at 0x1a21352780>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x1a213527f0>,
#  'ride': <gensim.models.keyedvectors.Vocab at 0x1a21352860>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x1a213528d0>,
#  'expected': <gensim.models.keyedvectors.Vocab at 0x1a21352908>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x1a21352978>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x1a213529e8>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x1a21352a58>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x1a21352ac8>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x1a21352b38>,
#  'telling': <gensim.models.keyedvectors.Vocab at 0x1a21352ba8>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x1a21352c18>,
#  'knees': <gensim.models.keyedvectors.Vocab at 0x1a21352c88>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x1a21352cf8>,
#  'service': <gensim.models.keyedvectors.Vocab at 0x1a21352d68>,
#  'prayers': <gensim.models.keyedvectors.Vocab at 0x1a21352dd8>,
#  'little_lord': <gensim.models.keyedvectors.Vocab at 0x1a21352e10>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x1a21352e80>,
#  'remind': <gensim.models.keyedvectors.Vocab at 0x1a21352ef0>,
#  'breakfast': <gensim.models.keyedvectors.Vocab at 0x1a21352f28>,
#  'bread': <gensim.models.keyedvectors.Vocab at 0x1a21352f98>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x1a21357048>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x1a213570b8>,
#  'beer': <gensim.models.keyedvectors.Vocab at 0x1a21357128>,
#  'wash': <gensim.models.keyedvectors.Vocab at 0x1a21357198>,
#  'burnt': <gensim.models.keyedvectors.Vocab at 0x1a21357208>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x1a21357278>,
#  'little_brother': <gensim.models.keyedvectors.Vocab at 0x1a213572b0>,
#  'beloved': <gensim.models.keyedvectors.Vocab at 0x1a21357320>,
#  'going_to_die': <gensim.models.keyedvectors.Vocab at 0x1a21357358>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1a213573c8>,
#  'maester': <gensim.models.keyedvectors.Vocab at 0x1a21357438>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x1a213574a8>,
#  'mercy': <gensim.models.keyedvectors.Vocab at 0x1a21357518>,
#  'letting': <gensim.models.keyedvectors.Vocab at 0x1a21357588>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x1a213575f8>,
#  'rest_of_us': <gensim.models.keyedvectors.Vocab at 0x1a21357630>,
#  'pray': <gensim.models.keyedvectors.Vocab at 0x1a213576a0>,
#  'entirely': <gensim.models.keyedvectors.Vocab at 0x1a213576d8>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x1a21357748>,
#  'cant_believe': <gensim.models.keyedvectors.Vocab at 0x1a21357780>,
#  'youre_going': <gensim.models.keyedvectors.Vocab at 0x1a213577b8>,
#  'ridiculous': <gensim.models.keyedvectors.Vocab at 0x1a213577f0>,
#  'wheres': <gensim.models.keyedvectors.Vocab at 0x1a21357860>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x1a213578d0>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x1a21357940>,
#  'nights_watch': <gensim.models.keyedvectors.Vocab at 0x1a21357978>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x1a213579b0>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x1a213579e8>,
#  'dont_need': <gensim.models.keyedvectors.Vocab at 0x1a21357a20>,
#  'filth': <gensim.models.keyedvectors.Vocab at 0x1a21357a90>,
#  'lives': <gensim.models.keyedvectors.Vocab at 0x1a21357b00>,
#  'cripple': <gensim.models.keyedvectors.Vocab at 0x1a21357b70>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x1a21357be0>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x1a21357c50>,
#  'whose': <gensim.models.keyedvectors.Vocab at 0x1a21357cc0>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x1a21357d30>,
#  'wound': <gensim.models.keyedvectors.Vocab at 0x1a21357da0>,
#  'dressed': <gensim.models.keyedvectors.Vocab at 0x1a21357e10>,
#  'guest': <gensim.models.keyedvectors.Vocab at 0x1a21357e80>,
#  'fighter': <gensim.models.keyedvectors.Vocab at 0x1a21357ef0>,
#  'tried': <gensim.models.keyedvectors.Vocab at 0x1a21357f60>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x1a21357fd0>,
#  'last_thing': <gensim.models.keyedvectors.Vocab at 0x1a2135d048>,
#  'never_knew': <gensim.models.keyedvectors.Vocab at 0x1a2135d080>,
#  'years_ago': <gensim.models.keyedvectors.Vocab at 0x1a2135d0b8>,
#  'bloody': <gensim.models.keyedvectors.Vocab at 0x1a2135d128>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x1a2135d198>,
#  'looked': <gensim.models.keyedvectors.Vocab at 0x1a2135d208>,
#  'bird': <gensim.models.keyedvectors.Vocab at 0x1a2135d278>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x1a2135d2e8>,
#  'held': <gensim.models.keyedvectors.Vocab at 0x1a2135d358>,
#  'screamed': <gensim.models.keyedvectors.Vocab at 0x1a2135d390>,
#  'again': <gensim.models.keyedvectors.Vocab at 0x1a2135d400>,
#  'visited': <gensim.models.keyedvectors.Vocab at 0x1a2135d470>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x1a2135d4e0>,
#  'morning': <gensim.models.keyedvectors.Vocab at 0x1a2135d550>,
#  'return': <gensim.models.keyedvectors.Vocab at 0x1a2135d5c0>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x1a2135d630>,
#  'grateful': <gensim.models.keyedvectors.Vocab at 0x1a2135d668>,
#  'shell': <gensim.models.keyedvectors.Vocab at 0x1a2135d6d8>,
#  'good_man': <gensim.models.keyedvectors.Vocab at 0x1a2135d710>,
#  'strange': <gensim.models.keyedvectors.Vocab at 0x1a2135d780>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x1a2135d7f0>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x1a2135d860>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x1a2135d8d0>,
#  'standing': <gensim.models.keyedvectors.Vocab at 0x1a2135d908>,
#  'ahead': <gensim.models.keyedvectors.Vocab at 0x1a2135d978>,
#  'beyond_the_wall': <gensim.models.keyedvectors.Vocab at 0x1a2135d9b0>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x1a2135da20>,
#  'protecting': <gensim.models.keyedvectors.Vocab at 0x1a2135da58>,
#  'weve': <gensim.models.keyedvectors.Vocab at 0x1a2135dac8>,
#  'guarded': <gensim.models.keyedvectors.Vocab at 0x1a2135db38>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x1a2135dba8>,
#  'vows': <gensim.models.keyedvectors.Vocab at 0x1a2135dc18>,
#  'soon_enough': <gensim.models.keyedvectors.Vocab at 0x1a2135dc50>,
#  'regards': <gensim.models.keyedvectors.Vocab at 0x1a2135dcc0>,
#  'im_sure': <gensim.models.keyedvectors.Vocab at 0x1a2135dd30>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x1a2135dda0>,
#  'nymeria': <gensim.models.keyedvectors.Vocab at 0x1a2135de10>,
#  'septa': <gensim.models.keyedvectors.Vocab at 0x1a2135de80>,
#  'werent': <gensim.models.keyedvectors.Vocab at 0x1a2135def0>,
#  'properly': <gensim.models.keyedvectors.Vocab at 0x1a2135df28>,
#  'cares': <gensim.models.keyedvectors.Vocab at 0x1a2135df98>,
#  'theyre': <gensim.models.keyedvectors.Vocab at 0x1a21361048>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x1a213610b8>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x1a21361128>,
#  'gloves': <gensim.models.keyedvectors.Vocab at 0x1a21361198>,
#  'impressive': <gensim.models.keyedvectors.Vocab at 0x1a213611d0>,
#  'carefully': <gensim.models.keyedvectors.Vocab at 0x1a21361208>,
#  'toy': <gensim.models.keyedvectors.Vocab at 0x1a21361278>,
#  'careful': <gensim.models.keyedvectors.Vocab at 0x1a213612e8>,
#  'dont': <gensim.models.keyedvectors.Vocab at 0x1a21361358>,
#  'yourself': <gensim.models.keyedvectors.Vocab at 0x1a21361390>,
#  'skinny': <gensim.models.keyedvectors.Vocab at 0x1a21361400>,
#  'blacksmith': <gensim.models.keyedvectors.Vocab at 0x1a21361438>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x1a213614a8>,
#  'mans': <gensim.models.keyedvectors.Vocab at 0x1a21361518>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1a21361588>,
#  'holes': <gensim.models.keyedvectors.Vocab at 0x1a213615f8>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x1a21361668>,
#  'youll': <gensim.models.keyedvectors.Vocab at 0x1a213616d8>,
#  'every_day': <gensim.models.keyedvectors.Vocab at 0x1a21361710>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x1a21361780>,
#  'lesson': <gensim.models.keyedvectors.Vocab at 0x1a213617f0>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x1a21361860>,
#  'im_going': <gensim.models.keyedvectors.Vocab at 0x1a21361898>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x1a21361908>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x1a21361978>,
#  'swords': <gensim.models.keyedvectors.Vocab at 0x1a213619e8>,
#  'names': <gensim.models.keyedvectors.Vocab at 0x1a21361a58>,
#  'ive_got': <gensim.models.keyedvectors.Vocab at 0x1a21361ac8>,
#  'needle': <gensim.models.keyedvectors.Vocab at 0x1a21361b38>,
#  'say_goodbye': <gensim.models.keyedvectors.Vocab at 0x1a21361b70>,
#  'youve': <gensim.models.keyedvectors.Vocab at 0x1a21361be0>,
#  'robert_baratheon': <gensim.models.keyedvectors.Vocab at 0x1a21361c18>,
#  'came_back': <gensim.models.keyedvectors.Vocab at 0x1a21361c50>,
#  'womans': <gensim.models.keyedvectors.Vocab at 0x1a21361cc0>,
#  'youre_leaving': <gensim.models.keyedvectors.Vocab at 0x1a21361cf8>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x1a21361d68>,
#  'calls': <gensim.models.keyedvectors.Vocab at 0x1a21361dd8>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1a21361e48>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x1a21361eb8>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x1a21361f28>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1a21361f98>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x1a21368048>,
#  'next_time': <gensim.models.keyedvectors.Vocab at 0x1a21368080>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x1a213680f0>,
#  'farewell': <gensim.models.keyedvectors.Vocab at 0x1a21368128>,
#  'theres': <gensim.models.keyedvectors.Vocab at 0x1a21368198>,
#  'great_honor': <gensim.models.keyedvectors.Vocab at 0x1a213681d0>,
#  'serving': <gensim.models.keyedvectors.Vocab at 0x1a21368240>,
#  'manned': <gensim.models.keyedvectors.Vocab at 0x1a213682b0>,
#  'ive': <gensim.models.keyedvectors.Vocab at 0x1a21368320>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x1a21368390>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x1a21368400>,
#  'kingsroad': <gensim.models.keyedvectors.Vocab at 0x1a21368438>,
#  'sides': <gensim.models.keyedvectors.Vocab at 0x1a213684a8>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x1a21368518>,
#  'tavern': <gensim.models.keyedvectors.Vocab at 0x1a21368588>,
#  'warm': <gensim.models.keyedvectors.Vocab at 0x1a213685f8>,
#  'beds': <gensim.models.keyedvectors.Vocab at 0x1a21368668>,
#  'tonight': <gensim.models.keyedvectors.Vocab at 0x1a213686d8>,
#  'asked': <gensim.models.keyedvectors.Vocab at 0x1a21368748>,
#  '20_years': <gensim.models.keyedvectors.Vocab at 0x1a21368780>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x1a213687f0>,
#  'marry': <gensim.models.keyedvectors.Vocab at 0x1a21368860>,
#  'chance': <gensim.models.keyedvectors.Vocab at 0x1a213688d0>,
#  'recall': <gensim.models.keyedvectors.Vocab at 0x1a21368940>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x1a213689b0>,
#  'chances': <gensim.models.keyedvectors.Vocab at 0x1a21368a20>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1a21368a90>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x1a21368b00>,
#  'tits': <gensim.models.keyedvectors.Vocab at 0x1a21368b70>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x1a21368be0>,
#  'thank_the_gods': <gensim.models.keyedvectors.Vocab at 0x1a21368c18>,
#  'rare': <gensim.models.keyedvectors.Vocab at 0x1a21368c88>,
#  'wench': <gensim.models.keyedvectors.Vocab at 0x1a21368cf8>,
#  'looked_like': <gensim.models.keyedvectors.Vocab at 0x1a21368d30>,
#  'gonna': <gensim.models.keyedvectors.Vocab at 0x1a21368da0>,
#  'go_back': <gensim.models.keyedvectors.Vocab at 0x1a21368e10>,
#  'hit': <gensim.models.keyedvectors.Vocab at 0x1a21368e80>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x1a21368ef0>,
#  'daenerys_targaryen': <gensim.models.keyedvectors.Vocab at 0x1a21368f28>,
#  'wed': <gensim.models.keyedvectors.Vocab at 0x1a21368f98>,
#  'knife': <gensim.models.keyedvectors.Vocab at 0x1a2136c048>,
#  'sharp': <gensim.models.keyedvectors.Vocab at 0x1a2136c0b8>,
#  'bold': <gensim.models.keyedvectors.Vocab at 0x1a2136c128>,
#  'wield': <gensim.models.keyedvectors.Vocab at 0x1a2136c198>,
#  'shes': <gensim.models.keyedvectors.Vocab at 0x1a2136c208>,
#  'spread': <gensim.models.keyedvectors.Vocab at 0x1a2136c278>,
#  'legs': <gensim.models.keyedvectors.Vocab at 0x1a2136c2e8>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1a2136c358>,
#  'speaking': <gensim.models.keyedvectors.Vocab at 0x1a2136c390>,
#  'unspeakable': <gensim.models.keyedvectors.Vocab at 0x1a2136c3c8>,
#  'rhaegar_targaryen': <gensim.models.keyedvectors.Vocab at 0x1a2136c400>,
#  'woman': <gensim.models.keyedvectors.Vocab at 0x1a2136c470>,
#  'targaryen': <gensim.models.keyedvectors.Vocab at 0x1a2136c4a8>,
#  ...}

# %%
words = [word for word in model.wv.vocab]
vectors = [model.wv[word] for word in words]

# %%
# we're going to do this a few times, so let's make a function

def get_vectors_and_words(model):
    words = [word for word in model.wv.vocab]
    vectors = [model.wv[word] for word in words]
    return vectors, words

vectors, words = get_vectors_and_words(model)

# %% [markdown]
# ## Clustering Algorithms
#
# ### k-means
# ![k-means](figures/K-means-convergence.gif)
#
# As an input, the k-means algorithm requires the number of clusters present `k`, and a maximum number of iterations `i`.
#
# This algorithms consists of alternating two steps `i` times
# 1. assignment step: Assign each observation to the cluster whose mean has the least squared Euclidean distance, this is intuitively the "nearest" mean.
# 2. update step: Calculate the new means (centroids) of the observations in the new clusters. Do this by averaging the vectors for all instances in a given cluster
#
# Quiz: What's the run time for k-means for `n` data points?

# %%
# let's implement k-means on our word data
from sklearn.cluster import KMeans
vectors, words = get_vectors_and_words(model)

# k means takes an input, the number of clusters we expect.
# we'll have to take guess
num_clusters_guess = 217

kmeans = KMeans(n_clusters=num_clusters_guess,
                random_state=666)
kmeans.fit(vectors)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=217, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=666, tol=0.0001, verbose=0)

# %%
# we want the attribute of the KMeans model model.labels_
kmeans.labels_
# Out:
# array([141,  41, 198, ...,  48, 106, 106], dtype=int32)

# %%
'''
-----------------------------------------------------------------
Objective: find a way to view words that are in the same cluster
-----------------------------------------------------------------
Right now we have the words ['these', 'are', 'unique', 'vocab', 'items', ...]
and the labels [0, 1, 1, 0, 2, ...]
These labels don't mean anything except that all the 1s go together, all the 2s, and so on

Figure out a way to hold this information so you can see which words are in which clusters
'''
from collections import defaultdict

def get_clusters(words, cluster_model):
    id_to_words = defaultdict(lambda: [])
    labels = cluster_model.labels_
    for word, label in zip(words, labels):
        id_to_words[label].append(word)
    return id_to_words


clusters = get_clusters(words, kmeans)
clusters
# Out:
# defaultdict(<function __main__.get_clusters.<locals>.<lambda>()>,
#             {141: ['what',
#               'thing',
#               'no',
#               'always',
#               'things',
#               'anything',
#               'nothing',
#               'someone',
#               'one_thing',
#               'something',
#               'some',
#               'anything_else',
#               'everything',
#               'none',
#               'last_thing',
#               'good_thing',
#               'theres_nothing',
#               'terrible_thing',
#               'there’s_nothing',
#               'ally',
#               'something_else',
#               'theres_something',
#               'nothing_else',
#               'many_things'],
#              41: ['expect',
#               'without',
#               'warn',
#               'wonder',
#               'with',
#               'promise',
#               'trap',
#               'risk',
#               'learn',
#               'wild',
#               'happen',
#               'wise',
#               'either',
#               'otherwise',
#               'neither',
#               'raise',
#               'happens',
#               'forge',
#               'ruin',
#               'strictly',
#               'harm',
#               'noise',
#               'within',
#               'corpse',
#               'rise',
#               'lt',
#               'surprised',
#               'proud',
#               'trip',
#               'raid',
#               'surrender',
#               'repaid',
#               'swallow',
#               'devise',
#               'surprise',
#               'trant',
#               'praise',
#               'laid',
#               'learns',
#               'collect',
#               'learner'],
#              198: ['they’re',
#               'they',
#               'they’ve',
#               'you’ve_got',
#               'theyre',
#               'ive_got',
#               'theyve',
#               'youve_got',
#               'theyll',
#               'theyd',
#               'weve_got',
#               'they’ll',
#               'theyve_got',
#               'they’d'],
#              92: ['savages',
#               'muscles',
#               'families',
#               'enemies',
#               'ladies',
#               'ones',
#               'babies',
#               'miles',
#               'lies',
#               'tries',
#               'flies',
#               'dies',
#               'villages',
#               'titles',
#               'isles',
#               'spies',
#               'marries',
#               'bodies',
#               'allies',
#               'duties',
#               'tales',
#               'beetles'],
#              42: ['one',
#               'name',
#               'grace',
#               'alone',
#               'place',
#               'shame',
#               'khal',
#               'side',
#               'bone',
#               'choice',
#               'face',
#               'khals',
#               'wolf',
#               'money',
#               'mark',
#               'pride',
#               'khalasar',
#               'peace',
#               'voice',
#               'ship',
#               'price',
#               'chairs',
#               'chair',
#               'path',
#               'coin',
#               'palace',
#               'safest_place',
#               'mace',
#               'ice',
#               'first_place'],
#              164: ['lot'],
#              179: ['a'],
#              60: ['goat',
#               'horse',
#               'quick',
#               'foot',
#               'fools',
#               'climbing',
#               'drunken',
#               '–',
#               'body',
#               'drogo',
#               'armor',
#               'fresh',
#               'piss',
#               'eggs',
#               'boar',
#               'milk',
#               'fish',
#               'filth',
#               'cripple',
#               'bird',
#               'blacksmith',
#               'big',
#               'bold',
#               'weapon',
#               'handle',
#               'hot',
#               'climb',
#               'bunch',
#               'slowly',
#               'slow',
#               'shit',
#               'bowl',
#               'taste',
#               'company',
#               'steel',
#               'rabbits',
#               'ducks',
#               'cripples',
#               'pigs',
#               'piggy',
#               'pile',
#               'dragonglass',
#               'silk',
#               'helmet',
#               'scar',
#               'wooden',
#               'manage',
#               'nice',
#               'sigil',
#               'box',
#               'floor',
#               'near',
#               'flesh',
#               'drunk',
#               'badge',
#               'fun',
#               'pin',
#               'silver',
#               'piece',
#               'sausage',
#               'bald',
#               'pitch',
#               'village',
#               'riddles',
#               'middle',
#               'pig',
#               'market',
#               'dry',
#               'pit',
#               'heel',
#               'twat',
#               'pie',
#               'potatoes',
#               'chamber_pot',
#               'drops',
#               'oil',
#               'onion_knight',
#               'board',
#               'climbs',
#               'mutton',
#               'drums',
#               'folks',
#               'kiss',
#               'atop',
#               'smash',
#               'pod',
#               'boats',
#               'cliff',
#               'good_luck',
#               'fucker',
#               'gamble',
#               'tiny',
#               'rabbit',
#               'glass',
#               'pink',
#               'pigeon',
#               'slayer',
#               'bag',
#               'bucket',
#               'cockels'],
#              187: ['from',
#               'show',
#               'drop',
#               'short',
#               'top',
#               'shoot',
#               'shove',
#               'shore',
#               'low',
#               'shown',
#               'shoo',
#               'shot',
#               'shop',
#               'shows'],
#              83: ['another',
#               'father’s',
#               'mother',
#               'father',
#               'mother’s',
#               'brother',
#               'husband',
#               'after',
#               'sister',
#               'since',
#               'prince',
#               'wedding',
#               'son’s',
#               'mothers',
#               'little_brother',
#               'brothers',
#               'wife',
#               'brotherhood',
#               'brothels',
#               'brothel',
#               'fathers',
#               'gather',
#               'grandfather',
#               'princes',
#               'older_brother',
#               'aunt',
#               'brother_jaime',
#               'brother’s',
#               'sister’s',
#               'bother',
#               'brothers_and_sisters',
#               'husbands',
#               'killed_my_father',
#               'grandchildren',
#               'wedding_night',
#               'wifes',
#               'grand',
#               'prison',
#               'grandson',
#               'grandmother',
#               'prince_oberyn',
#               'elia',
#               'red_wedding',
#               'leather',
#               'halfbrother',
#               'granddaughter'],
#              143: ['and',
#               'before',
#               'until',
#               'crypt',
#               'above',
#               'narrow_sea',
#               'inside',
#               'next',
#               'bear_island',
#               'shadow',
#               'asshai',
#               'one_day',
#               'pentos',
#               'bargain',
#               'breakfast',
#               'rest_of_us',
#               'tonight',
#               'scum',
#               'untie',
#               'alongside',
#               'six',
#               'across_the_world',
#               'whip',
#               'tomorrow',
#               'summer',
#               'wind',
#               'outlaws',
#               'dogs',
#               'aside',
#               'axe',
#               'vaes_dothrak',
#               'patrol',
#               'shape',
#               'yield',
#               'last_hearth',
#               'final',
#               'shadows',
#               'holdfast',
#               'pyke',
#               'afternoon',
#               'moles_town',
#               'widows',
#               'ill_take',
#               'slept',
#               'come_along',
#               'hide_behind',
#               'livestock',
#               'salt',
#               'white_harbor',
#               'blow',
#               'homeland',
#               'weirwood',
#               'daily',
#               'day_and_night',
#               'assassins',
#               'awhile',
#               'window',
#               'bridge',
#               'beside',
#               'beneath',
#               'castle_black',
#               'vanguard',
#               'tribesmen',
#               'across_the_narrow_sea',
#               'agony',
#               'crypts',
#               'shield_that_guards',
#               'dusk',
#               'stronghold',
#               'pyre',
#               'hollard',
#               'smoke',
#               'torrhens_square',
#               'night_is_dark_and_full_of_terrors',
#               'ride_south',
#               'kitchen',
#               'craster',
#               'ashore',
#               'harbor',
#               'overthrow',
#               'solid',
#               'volantis',
#               'passage',
#               'moat_cailin',
#               'wildfire',
#               'pyromancer',
#               'whilst',
#               'guide',
#               'hail',
#               'widow',
#               'square',
#               'sunrise',
#               'crag',
#               'open_the_gate',
#               'rhoyne',
#               'nightshade',
#               'castamere',
#               'rains_weep_oer',
#               'overboard',
#               'boros',
#               'chicken',
#               'halt',
#               'torch',
#               'dirty',
#               'bolt',
#               'full_moon',
#               'stomach',
#               'locke',
#               'days_ago',
#               'crakehall',
#               'pyramid',
#               'open_the_gates',
#               'island',
#               'tommens',
#               'yarwyck',
#               'crossbow',
#               'bare',
#               'hold_the_door',
#               'hold_the_door_hold_the_door'],
#              43: ['you',
#               'your',
#               'yours',
#               'you’re',
#               'you’d',
#               'youd',
#               'youre',
#               'yourself',
#               'youre_leaving',
#               'safe',
#               'youre_right',
#               'youve_done',
#               'safely',
#               'safety',
#               'youll_never',
#               'safer',
#               'you’ve_done'],
#              193: ['know',
#               'understand',
#               'hates',
#               'don’t_understand',
#               'means',
#               'hate',
#               'understands',
#               'understood',
#               'dont_understand',
#               'hateful'],
#              71: ['it'],
#              184: ['each', 'teach', 'breach', 'beach', 'reach'],
#              149: ['other',
#               'trouble',
#               'faster',
#               'soldier',
#               'bigger',
#               'later',
#               'ranger',
#               'rider',
#               'danger',
#               'hunter',
#               'easier',
#               'under',
#               'beer',
#               'dagger',
#               'happier',
#               'finger',
#               'rather',
#               'id_rather',
#               'smaller',
#               'warmer',
#               'prettier',
#               'harder',
#               'closer',
#               'lover',
#               'sooner',
#               'spider',
#               'wiser',
#               'older',
#               'longer',
#               'kinder',
#               'prefer',
#               'further',
#               'paper',
#               'younger',
#               'enter',
#               'ginger',
#               'stronger',
#               'fewer',
#               'eager',
#               'corner',
#               'dinner',
#               'gambler',
#               'pretender',
#               'farther',
#               'shelter',
#               'stranger',
#               'whether',
#               'walder',
#               'raper',
#               'weather',
#               'cheer',
#               'lower',
#               'sinner',
#               'glover'],
#              163: ['to'],
#              150: ['pieces',
#               'horses',
#               'passes',
#               'rides',
#               'candles',
#               'hands',
#               'times',
#               'gloves',
#               'holes',
#               'names',
#               'sides',
#               'beds',
#               'legs',
#               'comes',
#               'finds',
#               'tribes',
#               'hides',
#               'castles',
#               'clothes',
#               'fires',
#               'trees',
#               'ends',
#               'games',
#               'holds',
#               'crimes',
#               'corpses',
#               'heads',
#               'shores',
#               'rises',
#               'hole',
#               'armies',
#               'wives',
#               'homes',
#               'forces',
#               'remains',
#               'halls',
#               'continue',
#               'moves',
#               'promises',
#               'gates',
#               'leagues',
#               'axes',
#               'lines',
#               'leads',
#               'agrees',
#               'winds',
#               'loses',
#               'losses',
#               'battles',
#               'cocks',
#               'roses',
#               'refuses',
#               'amends',
#               'defenses',
#               'hopes',
#               'continues',
#               'wages',
#               'boxes',
#               'kisses',
#               'pauses',
#               'glances',
#               'retrieves'],
#              168: ['i’ve', 'ive'],
#              172: ['never_seen',
#               'just',
#               'white_walkers',
#               'about',
#               'raven',
#               'haven’t',
#               'first_time',
#               'it’s_time',
#               'beyond',
#               'already',
#               'dog',
#               'beyond_the_wall',
#               'next_time',
#               'ago',
#               'threat',
#               'last_time',
#               'three',
#               'havent',
#               'giant',
#               'ive_seen',
#               'three_days',
#               'three_times',
#               'youve_seen',
#               'ive_known',
#               'dozen',
#               'dynasty',
#               'wheat',
#               'red_waste',
#               'ive_never_seen',
#               'nasty',
#               'white',
#               'halfway',
#               'threeeyed_raven',
#               'three_dragons',
#               'ive_ever_seen',
#               'first_time_i_saw',
#               'six_times',
#               'killed_a_white_walker',
#               'white_walker',
#               'i’ve_seen'],
#              148: ['wildlings',
#               'all',
#               'ale',
#               'history',
#               'wildling',
#               'lands',
#               'stone',
#               'end',
#               'land',
#               'story',
#               'stories',
#               'stood',
#               'spend',
#               'food',
#               'castle',
#               'histories',
#               'vale',
#               'storm',
#               'dragonstone',
#               'stones',
#               'stormlands',
#               'stony',
#               'stores',
#               'storms_end'],
#              206: ['do'],
#              89: ['like',
#               'seem',
#               'feel',
#               'feel_like',
#               'spike',
#               'looked_like',
#               'sounds_like',
#               'dont_like',
#               'youd_like',
#               'felt_like',
#               'felt',
#               'feels',
#               'seems',
#               'looks_like',
#               'id_like',
#               'likely',
#               'look_like',
#               'seems_like',
#               'alike'],
#              33: ['this',
#               'not',
#               'that',
#               'which',
#               'only',
#               'think',
#               'fool',
#               'third',
#               'hope',
#               'happy',
#               'really',
#               'joke',
#               'thirsty',
#               'thinks',
#               'angry',
#               'mistake',
#               'vow',
#               'lf',
#               'think_id',
#               'joy',
#               'thin'],
#              78: ['ever',
#               'forever',
#               'never',
#               'when',
#               'fever',
#               'whatever',
#               'clever',
#               'once',
#               'ive_never',
#               'whichever',
#               'whoever',
#               'ive_ever',
#               'however',
#               'whenever',
#               'youve_ever'],
#              30: ['in'],
#              159: ['my'],
#              170: ['life',
#               'lord_stark',
#               'lord',
#               'duty',
#               'royal',
#               'brandon',
#               'lord_eddard_stark',
#               'lord_tyrion',
#               'uncle',
#               'maester_luwin',
#               'friend',
#               'maester',
#               'vows',
#               'lord_baelish',
#               'grand_maester',
#               'lord_tywin',
#               'lord_snow',
#               'true_friend',
#               'also',
#               'lords_of_westeros',
#               'lordship',
#               'old_friend',
#               'hoster',
#               'lord_walder',
#               'reply',
#               'prisoner',
#               'monster',
#               'brandon_stark',
#               'mord',
#               'guilty',
#               'report',
#               'lord_eddard',
#               'maester_aemon',
#               'hostage',
#               'lord_frey',
#               'lord_varys',
#               'lord_janos',
#               'grand_maester_pycelle',
#               'friendship',
#               'lord_karstark',
#               'archmaester',
#               'mandon',
#               'mallister',
#               'lord_royce',
#               'lord’s',
#               'maester_wolkan'],
#              115: ['close',
#               'have',
#               'thank',
#               'need',
#               'use',
#               'wish',
#               'care',
#               'needle',
#               'needs',
#               'speaks',
#               'speak',
#               'thanks',
#               'weak',
#               'needed',
#               'lose',
#               'need_to_speak',
#               'loose'],
#              57: ['as'],
#              34: ['any',
#               'much',
#               'many_times',
#               'many',
#               'ships',
#               'many_people',
#               'many_ships',
#               'many_men'],
#              65: ['man',
#               'too',
#               'young',
#               'madman',
#               'manner',
#               'bit',
#               'woman’s',
#               'yes',
#               'beauty',
#               'good_man',
#               'mans',
#               'womans',
#               'woman',
#               'young_man',
#               'old_man',
#               'human',
#               'nan',
#               'beautiful_woman',
#               'man’s'],
#              161: ['would',
#               'should',
#               'could',
#               'might',
#               'wouldn’t',
#               'shouldn’t',
#               'shall',
#               'wouldnt',
#               'mighty',
#               'shouldnt',
#               'couldnt',
#               'wish_i_could',
#               'shouldve',
#               'couldve',
#               'should’ve',
#               'couldn’t'],
#              2: ['the',
#               'them',
#               'their',
#               'these',
#               'yourselves',
#               'themselves',
#               'ourselves',
#               'ours',
#               'theirs'],
#              101: ['dead',
#               'kill',
#               'killers',
#               'murdered',
#               'murders',
#               'killed',
#               'murder',
#               'killer',
#               'murderer',
#               'murdering',
#               'kills',
#               'murderers'],
#              18: ['frighten',
#               'saddle',
#               'listen',
#               'explain',
#               'touch',
#               'forget',
#               'write',
#               'sweet',
#               'play',
#               'make',
#               'hurt',
#               'dove',
#               'begin',
#               'make_sure',
#               'meat',
#               'miss',
#               'say_goodbye',
#               'recall',
#               'take_care',
#               'dare',
#               'pet',
#               'admire',
#               'afford',
#               'sat',
#               'spare',
#               'eaten',
#               'admit',
#               'sake',
#               'task',
#               'enjoy',
#               'travel',
#               'catch',
#               'hatch',
#               'awake',
#               'invite',
#               'snake',
#               'match',
#               'cook',
#               'hurry',
#               'wrote',
#               'get_used',
#               'run_away',
#               'spite',
#               'threaten',
#               'release',
#               'give_us',
#               'seize',
#               'join_us',
#               'blame',
#               'seek',
#               'fetch',
#               'make_peace',
#               'persuade',
#               'waste',
#               'approve',
#               'escape',
#               'scare',
#               'vouch',
#               'exist',
#               'recognize',
#               'execute',
#               'hang',
#               'list',
#               'explains',
#               'heave',
#               'swim',
#               'complain',
#               'teacher'],
#              84: ['our'],
#              110: ['orders',
#               'order',
#               'ordered',
#               'command',
#               'lord_commander',
#               'commands',
#               'commanded',
#               'guard',
#               'commander'],
#              81: ['were',
#               'are',
#               'aren’t',
#               'isnt',
#               'werent',
#               'arent',
#               'weren’t',
#               'area'],
#              144: ['we', 'we’re', 'we’d', 'i’d'],
#              210: ['won’t',
#               'can',
#               'don’t',
#               'cant',
#               'wont',
#               'dont',
#               'cannot',
#               'can’t'],
#              23: ['us'],
#              173: ['more'],
#              58: ['don’t_think',
#               'never_met',
#               'don’t_know',
#               'don’t_care',
#               'always_wanted',
#               'never_forget',
#               'cant_believe',
#               'dont_need',
#               'never_knew',
#               'dont_know',
#               'dont_believe',
#               'dont_care',
#               'dont_think',
#               'tried_to_kill',
#               'dont_trust',
#               'dont_want',
#               'dont_worry',
#               'wont_hurt',
#               'please_dont',
#               'dont_remember',
#               'doesnt_mean',
#               'would_never',
#               'won',
#               'cant_defend',
#               'want_to_see',
#               'going_to_kill',
#               'wont_be_able',
#               'don’t_believe',
#               'i’ll_never',
#               'aint',
#               'mustnt',
#               'cant_win',
#               'don’t_need'],
#              119: ['he’ll', 'will', 'we’ll', 'you’ll', 'i’ll', 'ill'],
#              197: ['ask'],
#              77: ['how'],
#              176: ['died',
#               'moved',
#               'captured',
#               'seen',
#               'lived',
#               'married',
#               'bled',
#               'bed',
#               'fled',
#               'turned',
#               'tried',
#               'came',
#               'taken',
#               'made',
#               'wed',
#               'fed',
#               'prayed',
#               'healed',
#               'played',
#               'called',
#               'named',
#               'red',
#               'stayed',
#               'failed',
#               'pulled',
#               'lied',
#               'ended',
#               'led',
#               'sailed',
#               'proved',
#               'carried',
#               'saved',
#               'cried',
#               'arrived',
#               'worked',
#               'returned',
#               'sealed',
#               'buried',
#               'flayed',
#               'spoken',
#               'headed',
#               'marked',
#               'faced',
#               'filled',
#               'exiled'],
#              4: ['get_back',
#               'now',
#               'both',
#               'winterfell',
#               'wait',
#               'soon',
#               'ready',
#               'again',
#               'ahead',
#               'go_back',
#               'spread',
#               'read',
#               'turn',
#               'dread',
#               'mourn',
#               'go_ahead',
#               'coming_back',
#               'warg',
#               'behead'],
#              145: ['on'],
#              106: ['dead_men',
#               'bran',
#               'jon',
#               'snow',
#               'hey',
#               'benjen',
#               'mormont',
#               'ghost',
#               'rickon',
#               'hes_dead',
#               'tower',
#               'snows',
#               'halfman',
#               'hodor',
#               'balerion',
#               'himself',
#               'varyss',
#               'varys',
#               'thoros_of_myr',
#               'thorne',
#               'grenn',
#               'mance_rayder',
#               'eastwatch',
#               'clegane',
#               'jorah',
#               'mormonts',
#               'tyrion',
#               'ingslayer',
#               'dungeon',
#               'beric',
#               'dondarrion',
#               'gregor_clegane',
#               'gold_cloaks',
#               'traitors',
#               'aemon',
#               'afterwards',
#               'lemon',
#               'jon_snow',
#               'kingbeyondthewall',
#               'legendary',
#               'gendrys',
#               'red_woman',
#               'lady_melisandre',
#               'jorah_mormont',
#               'raiding_party',
#               'alley',
#               'balon',
#               'raven_scroll',
#               'bran_and_rickon',
#               'jaqen',
#               'dracarys',
#               'tormund',
#               'jojen',
#               'meera',
#               'thoros',
#               'blackfish',
#               'ya',
#               'eastwatchbythesea',
#               'sandor_clegane',
#               'missandei',
#               'bran_bran',
#               'thorns',
#               'euron',
#               'goldcloaks',
#               'sandor'],
#              31: ['camp',
#               'hills',
#               'woods',
#               'down',
#               'water',
#               'reads',
#               'barrels',
#               'road',
#               'skulls',
#               'sundown',
#               'sun',
#               'clouds',
#               'hidden',
#               'rough',
#               'grass',
#               'pale',
#               'cover',
#               'dark',
#               'color',
#               'tavern',
#               'warm',
#               'sky',
#               'feasts',
#               'supper',
#               'deep',
#               'blue',
#               'air',
#               'edge',
#               'appear',
#               'book',
#               'brown',
#               'soup',
#               'hood',
#               'town',
#               'mouths',
#               'gown',
#               'cloak',
#               'weep',
#               'collapse',
#               'dirt',
#               'pour',
#               'bar',
#               'shields',
#               'view',
#               'group',
#               'walda',
#               'chickens',
#               'baelor',
#               'mountains',
#               'dawn',
#               'camera',
#               'frozen',
#               'grown',
#               'flea_bottom',
#               'crossroads',
#               'secrets',
#               'sir',
#               'docks',
#               'mom',
#               'bottom',
#               'blue_eyes',
#               'roads',
#               'crew',
#               'wood',
#               'warlocks',
#               'pair',
#               'courtyard',
#               'flag',
#               'bay',
#               'rocks',
#               'beasts',
#               'mo',
#               'babe',
#               'rose',
#               'gardens',
#               'upper',
#               'taverns',
#               'settle',
#               'mood',
#               'sunspear',
#               'drawn',
#               'water_gardens',
#               'beetle'],
#              188: ['here',
#               'where',
#               'away',
#               'there',
#               'far',
#               'somewhere',
#               'going_anywhere',
#               'anywhere',
#               'wherever',
#               'far_away',
#               'miles_away',
#               'elsewhere',
#               'nowhere',
#               'farm'],
#              73: ['see',
#               'bow',
#               'run',
#               'feet',
#               'lie',
#               'move',
#               'fall',
#               'hit',
#               'stream',
#               'streets',
#               'strike',
#               'street',
#               'struck',
#               'steps',
#               'stew',
#               'steal',
#               'strip',
#               'drove',
#               'stead',
#               'step',
#               'strikes',
#               'strife'],
#              68: ['went', 'rode', 'marching', 'march', 'marched', 'marches'],
#              17: ['is'],
#              177: ['it’s', 'i’m'],
#              70: ['go'],
#              26: ['watching',
#               'practicing',
#               'starting',
#               'giving',
#               'preparing',
#               'missing',
#               'growing',
#               'darling',
#               'laughing',
#               'hoping',
#               'providing',
#               'blessing',
#               'charming',
#               'stealing',
#               'dreaming',
#               'approaching',
#               'enjoying',
#               'dancing',
#               'needing',
#               'holding',
#               'feeling',
#               'surviving',
#               'seeing',
#               'advising',
#               'keeping',
#               'during',
#               'freezing',
#               'pretending',
#               'sleeping',
#               'living',
#               'along',
#               'starving',
#               'howling',
#               'having',
#               'offering',
#               'begging',
#               'hearing',
#               'searching',
#               'losing',
#               'fearing',
#               'convincing',
#               'whispering',
#               'saving',
#               'according',
#               'wondering',
#               'moving',
#               'crossing',
#               'shooting',
#               'chopping',
#               'boring',
#               'bringing',
#               'gathering',
#               'rising',
#               'believing',
#               'fishing',
#               'helping',
#               'wearing',
#               'bidding',
#               'bedding',
#               'torturing',
#               'raping',
#               'scrubbing',
#               'died_fighting',
#               'feeding',
#               'spending',
#               'knowing',
#               'escaping',
#               'traveling',
#               'bleeding',
#               'teaching',
#               'kneeling',
#               'bearing',
#               'conquering',
#               'flaming',
#               'weeping',
#               'choosing',
#               'discussing',
#               'hanging',
#               'gonna_die',
#               'facing',
#               'sand',
#               'sparring',
#               'including',
#               'glancing'],
#              74: ['fine',
#               'drinks',
#               'drink',
#               'grow',
#               'shut',
#               'fuck',
#               'cry',
#               'pick',
#               'wash',
#               'stick',
#               'came_back',
#               'knife',
#               'belly',
#               'leg',
#               'drank',
#               'carry',
#               'finish',
#               'shake',
#               'gut',
#               'cunt',
#               'check',
#               'em',
#               'drag',
#               'cheese',
#               'arrow',
#               'fucks',
#               'tunnel',
#               'target',
#               'grip',
#               'neck',
#               'spot',
#               'ass',
#               'pass',
#               'smell',
#               'touches',
#               'stinks',
#               'slut',
#               'sneak',
#               'luck',
#               'draw',
#               'arse',
#               'slip',
#               'lips',
#               'stuff',
#               'moon_door',
#               'sheep',
#               'teeth',
#               'slit',
#               'brush',
#               'melt',
#               'smile',
#               'skin',
#               'carve',
#               'put_a_sword',
#               'sick',
#               'stink',
#               'podrick',
#               'rope',
#               'grow_old',
#               'ripe',
#               'cub',
#               'grows',
#               'cargo',
#               'argue',
#               'chop',
#               'push',
#               'woke',
#               'crush',
#               'lick',
#               'arrows',
#               'draw_loose',
#               'stuck',
#               'dig',
#               'smells',
#               'ash',
#               'rip',
#               'hut',
#               'suck',
#               'dick',
#               'rush',
#               'bran_wake',
#               'rodrick',
#               'draws'],
#              40: ['work',
#               'news',
#               'plenty',
#               'course',
#               'country',
#               'new',
#               'couple',
#               'wine',
#               'tent',
#               'sorts',
#               'sort',
#               'cousin',
#               'citadel',
#               'court',
#               'fair',
#               'age',
#               'works',
#               'count',
#               'lots',
#               'courage',
#               'port',
#               'cousins',
#               'cage',
#               'pork'],
#              174: ['well',
#               'hell',
#               'itll',
#               'shell',
#               'youll',
#               'she’ll',
#               'lll',
#               'dull'],
#              82: ['done',
#               'tell',
#               'true',
#               'afraid',
#               'worthy',
#               'doubt',
#               'trust',
#               'because',
#               'real',
#               'trusts',
#               'loyal',
#               'loyalty',
#               'truth',
#               'brave',
#               'worth',
#               'owe',
#               'truly',
#               'truths',
#               'trustworthy',
#               'trusted',
#               'truce'],
#              6: ['i'],
#              93: ['love',
#               'said',
#               'told',
#               'loved',
#               'knows',
#               'knew',
#               'says',
#               'believe',
#               'beloved',
#               'maid',
#               'spoke',
#               'believes',
#               'believed',
#               'aid'],
#              127: ['you’ve', 'we’ve', 'weve', 'youve', 'lve'],
#              135: ['managed',
#               'broke',
#               'helped',
#               'never_asked',
#               'honored',
#               'beheaded',
#               'promised',
#               'mad',
#               'punished',
#               'assured',
#               'guarded',
#               'asked',
#               'traveled',
#               'unharmed',
#               'chained',
#               'settled',
#               'remembered',
#               'tired',
#               'hoped',
#               'allowed',
#               'experienced',
#               'blueeyed',
#               'stolen',
#               'harmed',
#               'betrayed',
#               'broken',
#               'realized',
#               'offended',
#               'yielded',
#               'kept',
#               'wronged',
#               'bloodshed',
#               'changed',
#               'placed',
#               'rebelled',
#               'suffered',
#               'doomed',
#               'followed',
#               'feared',
#               'became',
#               'butchered',
#               'prepared',
#               'flogged',
#               'shared',
#               'branded',
#               'blessed',
#               'protected',
#               'seized',
#               'destroyed',
#               'frightened',
#               'engaged',
#               'unarmed',
#               'sacred',
#               'crippled',
#               'compared',
#               'arranged',
#               'confessed',
#               'wounded',
#               'begged',
#               'noticed',
#               'declared',
#               'disappeared',
#               'offered',
#               'executed',
#               'threatened',
#               'acquired',
#               'devoted',
#               'released',
#               'charged',
#               'underestimated',
#               'drowned',
#               'gathered',
#               'listened',
#               'hanged',
#               'admired',
#               'occupied',
#               'endured',
#               'strangled',
#               'preferred',
#               'wished',
#               'claimed',
#               'delivered',
#               'rewarded',
#               'disobeyed',
#               'occurred',
#               'disgraced',
#               'invaded',
#               'ignored',
#               'signed',
#               'risked',
#               'informed',
#               'conquered',
#               'onehanded',
#               'conspired',
#               'intended',
#               'pardoned',
#               'crucified',
#               'defended',
#               'reckoned',
#               'advised',
#               'manyfaced',
#               'assumed'],
#              181: ['get', 'find'],
#              132: ['quite',
#               'jon_arryn',
#               'agree',
#               'marry',
#               'lord_arryn',
#               'loras',
#               'lady_arryn',
#               'arry',
#               'arryn',
#               'lysa_arryn',
#               'meryn',
#               'oberyn'],
#              158: ['beautiful',
#               'such',
#               'tough',
#               'possibly',
#               'perhaps',
#               'pretty',
#               'early',
#               'perfect',
#               'secret',
#               'handsome',
#               'welcome',
#               'lovely',
#               'very',
#               'certain',
#               'different',
#               'completely',
#               'comfortable',
#               'entirely',
#               'grateful',
#               'strange',
#               'properly',
#               'impressive',
#               'carefully',
#               'careful',
#               'skinny',
#               'special',
#               'enough',
#               'hard',
#               'wench',
#               'sharp',
#               'peasant',
#               'nephew',
#               'nicely',
#               'smart',
#               'easily',
#               'dangerous_place',
#               'interesting',
#               'poor',
#               'quiet',
#               'gladly',
#               'small',
#               'nearly',
#               'ugly',
#               'double',
#               'supply',
#               'barely',
#               'sally',
#               'marvelous',
#               'fascinating',
#               'lucky',
#               'imagine',
#               'able',
#               'miserable',
#               'easy',
#               'sometimes',
#               'eventually',
#               'rich',
#               'responsible',
#               'samwell_tarly',
#               'conquer',
#               'expensive',
#               'possible',
#               'conqueror',
#               'usually',
#               'almost',
#               'immediately',
#               'proper',
#               'hungry',
#               'impossible',
#               'silly',
#               'pregnant',
#               'admirable',
#               'soft',
#               'terrible',
#               'loudly',
#               'actually',
#               'important',
#               'lonely',
#               'awful',
#               'difficult',
#               'simple',
#               'honorable_man',
#               'honorable',
#               'unpleasant',
#               'wonderful',
#               'clear',
#               'horrible',
#               'rarely',
#               'aware',
#               'prophecy',
#               'samwell',
#               'certainly',
#               'clearly',
#               'perfectly',
#               'eunuch',
#               'sadly',
#               'apparently',
#               'conquerors',
#               'suitable',
#               'fortunate',
#               'pleasant',
#               'merciful',
#               'exactly',
#               'complicated',
#               'capable',
#               'military',
#               'useful',
#               'exhausted',
#               'especially',
#               'fond',
#               'appreciate',
#               'rally',
#               'differently',
#               'unfortunate',
#               'gilly',
#               'quit',
#               'intelligent',
#               'pretend',
#               'simply',
#               'terribly',
#               'godly',
#               'merely',
#               'brilliant',
#               'ordinary',
#               'valuable',
#               'mostly',
#               'harp',
#               'fully',
#               'horror',
#               'strong_enough',
#               'hardly',
#               'lawful',
#               'property',
#               'luckily',
#               'kindly',
#               'successful',
#               'royal_wedding',
#               'propose',
#               'extraordinary',
#               'frustrating',
#               'arrange',
#               'loud',
#               'softly',
#               'famously'],
#              113: ['of'],
#              162: ['was'],
#              37: ['at'],
#              94: ['ten',
#               'hear',
#               'hair',
#               'eat',
#               'wear',
#               'bear',
#               'spear',
#               'heard',
#               'beat',
#               'fear',
#               'ear',
#               'tear',
#               'beard'],
#              186: ['keep',
#               'hold',
#               'belong',
#               'bet',
#               'help',
#               'join',
#               'belongs',
#               'against',
#               'protect',
#               'remind',
#               'protecting',
#               'behind',
#               'protects',
#               'follows',
#               'stop',
#               'between',
#               'stand_behind',
#               'allow',
#               'save',
#               'destroy',
#               'betray',
#               'follow',
#               'bend_the_knee',
#               'below',
#               'keeps',
#               'defend',
#               'attack',
#               'lead',
#               'remove',
#               'leader',
#               'avenge',
#               'protection',
#               'revenge',
#               'attend',
#               'protector',
#               'abandon',
#               'cause',
#               'obey',
#               'defeat',
#               'treat',
#               'protect_us',
#               'key',
#               'bend',
#               'following'],
#              22: ['relax',
#               'forgive',
#               'sentence',
#               'respects',
#               'honor',
#               'grave',
#               'reign',
#               'present',
#               'offense',
#               'insult',
#               'rescue',
#               'offend',
#               'share',
#               'pardon',
#               'offer',
#               'accept',
#               'tongue',
#               'hospitality',
#               'comfort',
#               'require',
#               'business',
#               'kindness',
#               'consider',
#               'knowledge',
#               'refuse',
#               'respect',
#               'resist',
#               'receive',
#               'deliver',
#               'keep_the_peace',
#               'presume',
#               'behalf',
#               'insults',
#               'presence',
#               'concerns',
#               'desires',
#               'discuss',
#               'send_word',
#               'dishonor',
#               'commit',
#               'grant',
#               'represent',
#               'intend',
#               'confess',
#               'beg',
#               'restore',
#               'concern',
#               'congratulations',
#               'requires',
#               'wisdom',
#               'pledge',
#               'foreign',
#               'nor',
#               'sign',
#               'fealty',
#               'gratitude',
#               'indeed',
#               'excuse',
#               'wishes',
#               'terms',
#               'fork',
#               'advise',
#               'sledge',
#               'forgiveness',
#               'desire',
#               'convince',
#               'confuse',
#               'form',
#               'advisor',
#               'fortress',
#               'provisions',
#               'formal',
#               'contract',
#               'holiness',
#               'advisors',
#               'gravy'],
#              99: ['arm', 'army', 'arms'],
#              53: ['lady',
#               'lad',
#               'sansa',
#               'imp',
#               'her',
#               'lady_stark',
#               'catelyn',
#               'ilyn',
#               'payne',
#               'ladys',
#               'glad',
#               'lady_catelyn',
#               'arya_stark',
#               'robin',
#               'lysa',
#               'catelyn_stark',
#               'lady_sansa',
#               'shae',
#               'llyn',
#               'baelish',
#               'brienne',
#               'pleased',
#               'lady_brienne',
#               'sansas',
#               'sansa_stark',
#               'aryas',
#               'lady_olenna',
#               'shy',
#               'reek',
#               'niece',
#               'aunt_lysa',
#               'lady_crane'],
#              91: ['night’s_watch',
#               'north',
#               'northern',
#               'alive',
#               'bastard',
#               'nights_watch',
#               'traitor',
#               'northerners',
#               'bannermen',
#               'banner',
#               'bannerman',
#               'northerner',
#               'banners',
#               'northmen',
#               'ing_in_the_north',
#               'ing_in_the_north_ing_in_the_north',
#               'king_in_the_north',
#               'alton',
#               'lord_bolton',
#               'band',
#               'boltons',
#               'bolton',
#               'roose_bolton',
#               'ramsay',
#               'ramsay_bolton'],
#              61: ['lads',
#               'girls',
#               'friends',
#               'bastards',
#               'eyes',
#               'favor',
#               'boys',
#               'fields',
#               'regards',
#               'wet',
#               'words',
#               'stern',
#               'troubles',
#               'lords',
#               'favorites',
#               'thieves',
#               'minds',
#               'wolves',
#               'faces',
#               'last_words',
#               'choices',
#               'dresses',
#               'resources',
#               'places',
#               'bones',
#               'skills',
#               'doors',
#               'birds',
#               'goats',
#               'warriors',
#               'scouts',
#               'ls',
#               'tents',
#               'doorstep',
#               'graces',
#               'troops',
#               'sellswords',
#               'usual',
#               'doom',
# ...
#               'injustice',
#               'apprentice',
#               'adventures',
#               'someones',
#               'establishment',
#               'bravery',
#               'threats',
#               'confidence',
#               'dignity',
#               'excellent',
#               'necessary',
#               'affairs',
#               'agreement',
#               'moneys',
#               'exchange',
#               'polliver',
#               'spice',
#               'halfhand',
#               'contents',
#               'chaos',
#               'stonemason',
#               'scent',
#               'custom',
#               'squires',
#               'misery',
#               'arrangement',
#               'control',
#               'strategy',
#               'necklace',
#               'audience',
#               'talents',
#               'challenge',
#               'points',
#               'prize',
#               'lifetime',
#               'actual',
#               'influence',
#               'parents',
#               'amusement',
#               'perspective',
#               'accident',
#               'due',
#               'currently',
#               'condolences',
#               'orson',
#               'atonement'],
#              15: ['getting',
#               'while',
#               'expecting',
#               'being',
#               'eating',
#               'hunting',
#               'putting',
#               'letting',
#               'hurting',
#               'meeting',
#               'counting',
#               'jousting',
#               'waiting',
#               'sitting',
#               'trusting',
#               'rotting',
#               'exciting',
#               'uniting',
#               'wanting',
#               'disgusting',
#               'supporting',
#               'cutting',
#               'writing',
#               'treating',
#               'acting',
#               'beating',
#               'forgetting',
#               'wasting',
#               'awaiting',
#               'tempting',
#               'lasting',
#               'resting'],
#              123: ['she'],
#              214: ['those',
#               'thought',
#               'though',
#               'thoughts',
#               'never_thought',
#               'thought_youd',
#               'thought_you’d'],
#              131: ['gets',
#               'tits',
#               'shits',
#               'eats',
#               'guts',
#               'sits',
#               'puts',
#               'cats',
#               'boots',
#               'cunts',
#               'runs',
#               'lts',
#               'pockets',
#               'sets',
#               'rats',
#               'pots',
#               'pits',
#               'suits',
#               'wits',
#               'hits',
#               'twats',
#               'exits'],
#              10: ['stab',
#               'stand',
#               'live',
#               'starve',
#               'stable',
#               'stag',
#               'arrive',
#               'lay',
#               'vile',
#               'stables',
#               'table',
#               'stands',
#               'stars',
#               'staring',
#               'stairs',
#               'stags',
#               'stares',
#               'statue',
#               'stare',
#               'stays',
#               'drive'],
#              215: ['than'],
#              46: ['arya',
#               'door',
#               'stops',
#               'books',
#               'walk',
#               's',
#               'archer',
#               'hammer',
#               'turns',
#               'fly',
#               'guards',
#               'gendry',
#               't',
#               'inches',
#               'looks',
#               'attacks',
#               'ranks',
#               'bronn',
#               'onto',
#               'begins',
#               'wagon',
#               'davos',
#               'towards',
#               'walks',
#               'approach',
#               'picks',
#               'cave',
#               'gate',
#               'yards',
#               'boat',
#               'backs',
#               'randyll',
#               'reaches',
#               'approaches',
#               'scroll',
#               'drogon',
#               'pulls',
#               'dickon',
#               'opens',
#               'walking_towards',
#               'turns_to_look',
#               'walking_along',
#               'begins_walking',
#               'nods',
#               'walks_away',
#               'turns_and_walks'],
#              117: ['guarding',
#               'riding',
#               'beheading',
#               'standing',
#               'leaving',
#               'finding',
#               'heading',
#               'hiding',
#               'sending',
#               'attacking',
#               'leading',
#               'smiling',
#               'reading',
#               'sailing',
#               'defending',
#               'ending',
#               'building'],
#              209: ['ooh',
#               '16',
#               'aye',
#               'damn',
#               'viserys',
#               'hush',
#               'grim',
#               'yet',
#               'robert’s',
#               '17',
#               'nymeria',
#               'dwarf',
#               'egg',
#               'lys',
#               'mycah',
#               'butchers_boy',
#               'filthy',
#               'inn',
#               'nobody',
#               'mmm',
#               'duncan',
#               'pyp',
#               'itd',
#               'petyr',
#               'huh',
#               'howd',
#               'dumb',
#               'm',
#               'particularly',
#               'i’ve_heard',
#               'eh',
#               '15',
#               'vhagar',
#               'unlikely',
#               'ive_heard',
#               'syrio',
#               'pycelle',
#               'rumor',
#               'rhaegar',
#               'ser_gregor',
#               'music',
#               'many_years_ago',
#               'hmm',
#               'absolutely',
#               'earlier',
#               'shh_shh',
#               'lyanna',
#               'osha',
#               'nobility',
#               'selmy',
#               'gentle',
#               'uh',
#               'ive_made',
#               'jaw',
#               'odd',
#               'braavosi',
#               'shagga',
#               'h',
#               'e',
#               'walder_frey',
#               'yeah',
#               'hyah',
#               'shaggydog',
#               'uncle_jaime',
#               'ive_always',
#               'myrcella',
#               'jaqen_hghar',
#               'shhh',
#               'dead_may_never_die',
#               '30',
#               'willem',
#               'ax',
#               'talisa',
#               'payne_the_hound',
#               'xaro',
#               'xhoan',
#               'daxos',
#               'smith',
#               'monkey',
#               '40',
#               'romantic',
#               'ocean',
#               'qhorin_halfhand',
#               'w',
#               'r',
#               'o',
#               'visenya',
#               'thief',
#               'itself',
#               '12',
#               'beef',
#               '19',
#               '13',
#               '2',
#               'valar_morghulis',
#               'edd',
#               'kraznys',
#               'luthor',
#               'ahem',
#               'guilty_guilty',
#               'mm',
#               'grey_worm',
#               'myranda',
#               'daario_naharis',
#               'how’s',
#               'hodor_hodor',
#               'mhysa',
#               'mhysa_mhysa',
#               'timid',
#               'ellaria',
#               'tansy',
#               'jeor',
#               'uncle_petyr',
#               'meryn_trant',
#               'hizdahr_zo_loraq',
#               'kidney',
#               'um',
#               'khuu_khuu',
#               'khuu',
#               'dohaeris',
#               'greyscale',
#               'dwarf’s',
#               'obara',
#               'dornishman’s',
#               'oysters_clams',
#               'unella',
#               'wylis',
#               'olenna',
#               'momma',
#               'wolkan'],
#              203: ['pay',
#               'leave',
#               'bride',
#               'send',
#               'meet',
#               'ride',
#               'return',
#               'try',
#               'escort',
#               'bring',
#               'provide',
#               'slay',
#               'sends',
#               'repay',
#               'hide',
#               'prove',
#               'returns',
#               'survive',
#               'brings'],
#              153: ['surely',
#               'i’m_sure',
#               'im_sure',
#               'rare',
#               'pleasure',
#               'sure',
#               'assure',
#               'purse',
#               'capture',
#               'future',
#               'pure',
#               'nature',
#               'secure',
#               'cure',
#               'torture',
#               'edmure',
#               'figure',
#               'procedure',
#               'lure'],
#              56: ['then',
#               'hill',
#               'watch',
#               'full',
#               'fell',
#               'battle',
#               'hall',
#               'till',
#               'open',
#               'hunt',
#               'fill',
#               'cell',
#               'ease',
#               'cells',
#               'therell',
#               'watcher',
#               'skull',
#               'nightfall',
#               'pull',
#               'pen',
#               'skill',
#               'watches',
#               'roll',
#               'orell',
#               'mill',
#               'quill',
#               'spill',
#               'doll'],
#              185: ['win'],
#              212: ['by'],
#              136: ['son'],
#              213: ['daughter',
#               'slaughtered',
#               'daughters',
#               'slaughter',
#               'laugh',
#               'slaughtering'],
#              201: ['call', 'calls', 'tells', 'balls', 'falls', 'bells'],
#              118: ['oh'],
#              105: ['every_night',
#               'ever_lived',
#               'every',
#               'every_day',
#               'ever_seen',
#               'everyone',
#               'everywhere',
#               'everybody',
#               'everyone_else',
#               'every_time',
#               'everyone_knows',
#               'every_one',
#               'every_man',
#               'ever_met',
#               'ever_since',
#               'ever_known'],
#              169: ['targaryens',
#               'dragon',
#               'dothraki',
#               'house_targaryen',
#               'andals_and_the_first_men',
#               'women',
#               'children',
#               'daenerys_targaryen',
#               'rhaegar_targaryen',
#               'targaryen',
#               'brave_men',
#               'dragons',
#               '500_men',
#               'aerys',
#               'aegon',
#               'aegons',
#               'targaryen_girl',
#               'women_and_children',
#               'rape',
#               'first_men',
#               'aegon_targaryen',
#               'men_women_and_children'],
#              25: ['gift',
#               'reason',
#               'crime',
#               'meal',
#               'message',
#               'treason',
#               'trial',
#               'reasons',
#               'meals',
#               'natural',
#               'deal',
#               'problem',
#               'gifts',
#               'treasonous',
#               'problems',
#               'good_deal',
#               'reasonable'],
#              32: ['let'],
#              182: ['may'],
#              116: ['defeated',
#               'waited',
#               'expected',
#               'lost',
#               'visited',
#               'lifted',
#               'hated',
#               'insulted',
#               'armed',
#               'melted',
#               'knighted',
#               'met',
#               'started',
#               'invented',
#               'poisoned',
#               'wondered',
#               'united',
#               'enjoyed',
#               'anointed',
#               'treated',
#               'granted',
#               'cursed',
#               'hunted',
#               'painted',
#               'plotted',
#               'humiliated',
#               'interested',
#               'respected',
#               'spotted',
#               'mounted',
#               'wasted',
#               'suggested',
#               'invited',
#               'tasted',
#               'pointed',
#               'seated'],
#              104: ['cut'],
#              36: ['going',
#               'youre_going',
#               'im_going',
#               'gonna',
#               'im_not_going',
#               'we’re_going',
#               'i’m_not_going',
#               'i’m_going',
#               'you’re_going',
#               'we’re_gonna'],
#              27: ['cross', 'across'],
#              160: ['men'],
#              47: ['or'],
#              140: ['even'],
#              7: ['second',
#               'slaver',
#               'slave',
#               'freeze',
#               'master',
#               'masters',
#               'freedom',
#               'free',
#               'astapor',
#               'unsullied',
#               'master_kraznys',
#               'meereenese',
#               'free_men',
#               'slavery',
#               'yunkai',
#               'slavers',
#               'wise_masters',
#               'second_sons',
#               'meereen',
#               'former_slaves',
#               'mereen',
#               'slaver’s_bay'],
#              207: ['home'],
#              199: ['day'],
#              192: ['seat', 'sea', 'set', 'seas', 'search', 'seal'],
#              97: ['two'],
#              189: ['fight',
#               'fighting',
#               'fighter',
#               'knights',
#               'nights',
#               'fights',
#               'sellsword',
#               'fighters',
#               'fighting_pits'],
#              130: ['wants', 'lets', 'goes', 'foes', 'shoes', 'heroes'],
#              134: ['wars', 'war'],
#              178: ['crown',
#               'crops',
#               'crows',
#               'crow',
#               'row',
#               'crowd',
#               'crowded',
#               'crowns'],
#              194: ['served', 'serve', 'deserve', 'deserved'],
#              0: ['selling',
#               'telling',
#               'sing',
#               'willing',
#               'killing',
#               'sell',
#               'calling',
#               'pulling',
#               'falling',
#               'travelling'],
#              107: ['im'],
#              137: ['knees', 'kneel', 'knee', 'kneels'],
#              69: ['its'],
#              45: ['lives', 'slaves', 'cities', 'walls', 'leaves', 'waves'],
#              124: ['screamed',
#               'screams',
#               'screamers',
#               'scream',
#               'screaming',
#               'flames',
#               'flame',
#               'screamer'],
#              205: ['am'],
#              152: ['does'],
#              19: ['must'],
#              75: ['few'],
#              54: ['shes'],
#              216: ['start',
#               'part',
#               'heart',
#               'cart',
#               'hearts',
#               'art',
#               'starts',
#               'apart'],
#              129: ['100000', '20000', '10000', '100', '2000', '1000', '8000'],
#              195: ['choose', 'chosen', 'chose'],
#              85: ['id'],
#              147: ['born',
#               'highborn',
#               'horn',
#               'torn',
#               'lowborn',
#               'trueborn',
#               'ironborn',
#               'stubborn',
#               'reborn',
#               'firstborn'],
#              133: ['hes'],
#              156: ['wasnt'],
#              165: ['joffrey',
#               'joffreys',
#               'tywin',
#               'heir',
#               'joffrey_cersei',
#               'king_joffrey',
#               'freys',
#               'joffrey_baratheon',
#               'king_joffreys',
#               'kill_joffrey',
#               'frey',
#               'tywins'],
#              138: ['city'],
#              211: ['hed'],
#              20: ['10', '50', '20', '500', '200', '300', '700'],
#              11: ['ah'],
#              103: ['l']})

# %%
# show the first few clusters by printing them

# %% [markdown]
# #### How did K-means do?
#
# How do the clusters look? Do they make sense?
#
# How do we know that our number of clusters guess was right?

# %% [markdown]
# ### Hierarchical Clustering
#
# [Hierarchical clustering](https://en.wikipedia.org/wiki/Hierarchical_clustering) is a method of cluster analysis which seeks to build a hierarchy of clusters. There are two ways to do this
#
# 1. Agglomerative: bottom-up. Each observation starts in its own cluster and pairs of clusters are merged as we work up the hierarchy
# 2. Divisive: top-down. All observations start in one cluster, and splits are performed recursively as we move down the hierarchy.

# %% [markdown]
# ### Affinity Propagation - a type of Hierarchical Clustering
# ![affinity propagation](figures/affinity-propagation.gif)
#
# gif taken from [NIPS 2017 paper video](https://www.youtube.com/watch?v=1IOEFNGPNJc)
#
# From [sklearn's documentation](https://scikit-learn.org/stable/modules/clustering.html#affinity-propagation):
# >AffinityPropagation creates clusters by sending messages between pairs of samples until convergence. A dataset is then described using a small number of exemplars, which are identified as those most representative of other samples. The messages sent between pairs represent the suitability for one sample to be the exemplar of the other, which is updated in response to the values from other pairs. This updating happens iteratively until convergence, at which point the final exemplars are chosen, and hence the final clustering is given.
#
# One of the major benefits of affinity propagation is that it determines the number of clusters automatically.
#
# One of the downfalls of affinity propagation is the run time: `O(in^2)`

# %% [markdown]
# For more parameter's that come in sklearn, check [the documentation](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AffinityPropagation.html#sklearn.cluster.AffinityPropagation).

# %%
'''
---------------------------------------
objective: cluster the word embeddings
---------------------------------------
we're going to use sklearn's affinity propagation 

'''

from sklearn.cluster import AffinityPropagation

af = AffinityPropagation(convergence_iter=40,
                         max_iter=1000,
                        )
af.fit(vectors)
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=40, copy=True,
#           damping=0.5, max_iter=1000, preference=None, verbose=False)

# %%
# how many clusters were generated? 
len(set(af.labels_))
# Out:
# 617

# %%
# let's take a look at the clusters by printing the first 20
clusters = get_clusters(words, af)
clusters
# Out:
# defaultdict(<function __main__.get_clusters.<locals>.<lambda>()>,
#             {208: ['what', 'whatever', 'what’re', 'what’s', 'whats'],
#              605: ['expect',
#               'demand',
#               'expected',
#               'experienced',
#               'enemy',
#               'reputation',
#               'entire',
#               'question',
#               'mention',
#               'position',
#               'invitation',
#               'action',
#               'experience',
#               'ambition',
#               'direction',
#               'situation',
#               'notion',
#               'imagination',
#               'devotion',
#               'expert',
#               'traditionally',
#               'tradition',
#               'option',
#               'proposition',
#               'expedition'],
#              600: ['they’re',
#               'they',
#               'they’ve',
#               'theyre',
#               'theyve',
#               'theyll',
#               'theyd',
#               'they’ll',
#               'they’d'],
#              400: ['savages',
#               'dothraki',
#               'women',
#               'children',
#               'women_and_children',
#               'grandchildren',
#               'free_men',
#               'men_women_and_children'],
#              0: ['one'],
#              1: ['lot'],
#              2: ['a'],
#              537: ['goat',
#               'fools',
#               'drunken',
#               '–',
#               'body',
#               'narrow_sea',
#               'armor',
#               'grim',
#               'piss',
#               'milk',
#               'toy',
#               'bold',
#               'easily',
#               'hot',
#               'upset',
#               'small',
#               'barely',
#               'slowly',
#               'slow',
#               'outlaws',
#               'squire',
#               'horseback',
#               'patrol',
#               'likely',
#               'moles_town',
#               'dornish',
#               'drunk',
#               'blow',
#               'slit',
#               'melt',
#               'lt',
#               'crippled',
#               'across_the_narrow_sea',
#               'smoke',
#               'grow_old',
#               'drops',
#               'ax',
#               '40',
#               'drums',
#               'kiss',
#               'smash',
#               'cant_win',
#               'property',
#               'languages',
#               'tiny',
#               'bucket'],
#              3: ['from'],
#              606: ['another',
#               'brother',
#               'half',
#               'brotherhood',
#               'brothels',
#               'brothel',
#               'older_brother',
#               'brother’s',
#               'bother',
#               'cause',
#               'halfhand',
#               'halfbrother'],
#              462: ['and',
#               'with',
#               'muscles',
#               'hush',
#               'share',
#               'asshai',
#               'dog',
#               'sharp',
#               'shake',
#               'butchers_boy',
#               'huh',
#               'dumb',
#               'blond',
#               'dogs',
#               'ducks',
#               'vaes_dothrak',
#               'eh',
#               'shape',
#               'silk',
#               'shadows',
#               'music',
#               'come_along',
#               'osha',
#               'selmy',
#               'sheep',
#               'value',
#               'besides',
#               'shagga',
#               'brush',
#               'walda',
#               'shae',
#               'shaggydog',
#               'ghosts',
#               'torrhens_square',
#               'ill_give',
#               'way_around',
#               'yara',
#               'talisa',
#               'cupbearer',
#               'oil',
#               'shelter',
#               'visenya',
#               'crag',
#               'crush',
#               'ashes',
#               'rains_weep_oer',
#               'boros',
#               'meera',
#               'hodor_hodor',
#               'obara',
#               'dornishman’s',
#               'oysters_clams',
#               'cockels',
#               'else’s'],
#              488: ['before',
#               'whore',
#               'shores',
#               'bore',
#               'shore',
#               'tore',
#               'ashore',
#               'ash'],
#              4: ['you'],
#              474: ['know',
#               'understand',
#               'meant',
#               'don’t_understand',
#               'dont_know',
#               'dont_care',
#               'dont_think',
#               'dont_trust',
#               'dont_worry',
#               'understands',
#               'understood',
#               'dont_understand'],
#              5: ['it'],
#              6: ['each'],
#              590: ['other',
#               'father',
#               'rather',
#               'id_rather',
#               'gather',
#               'matter',
#               'further',
#               'farther',
#               'whether',
#               'leather',
#               'weather'],
#              7: ['to'],
#              596: ['pieces',
#               'thats',
#               'shits',
#               'eats',
#               'cats',
#               'goats',
#               'lts',
#               'twat',
#               'rats',
#               'boats',
#               'twats'],
#              8: ['i’ve'],
#              481: ['never_seen',
#               'never_met',
#               'ever_seen',
#               'ive_seen',
#               'ive_never',
#               'youve_seen',
#               'ive_never_seen',
#               'ive_ever_seen',
#               'i’ve_seen'],
#              478: ['wildlings',
#               'dead_men',
#               'snow',
#               'still',
#               'barrels',
#               'beyond',
#               'boar',
#               'itll',
#               'beyond_the_wall',
#               'brave_men',
#               'wolf',
#               'traitor',
#               'strength',
#               'summer',
#               'wolves',
#               'false',
#               'almost',
#               'mance_rayder',
#               'within',
#               'strengths',
#               'gold_cloaks',
#               'traitors',
#               'northmen',
#               'rallied',
#               'ravens',
#               'tribesmen',
#               'notices',
#               'dust',
#               'red_waste',
#               'kingbeyondthewall',
#               'overthrow',
#               'wildfire',
#               'halfway',
#               'threeeyed_raven',
#               'nightfall',
#               'stark_boys',
#               'jaqen',
#               'side_of_the_wall',
#               'thenns',
#               'eastwatchbythesea'],
#              9: ['do'],
#              607: ['thing', 'things', 'think', 'thin'],
#              321: ['like',
#               'feel_like',
#               'wasn’t',
#               'looked_like',
#               'sounds_like',
#               'dont_like',
#               'youd_like',
#               'felt_like',
#               'felt',
#               'hadnt',
#               'looks_like',
#               'id_like',
#               'look_like',
#               'seems_like',
#               'alike'],
#              507: ['this',
#               'anything',
#               'plenty',
#               'something',
#               'perfect',
#               'anything_else',
#               'sometimes',
#               'theres_nothing',
#               'there’s_nothing',
#               'something_else',
#               'theres_something',
#               'theres_still'],
#              10: ['not'],
#              115: ['ever',
#               'never',
#               'fever',
#               'clever',
#               'whoever',
#               'ive_ever',
#               'however',
#               'whenever'],
#              11: ['in'],
#              12: ['my'],
#              13: ['life'],
#              166: ['close', 'closed', 'closest', 'closer'],
#              14: ['as'],
#              15: ['any'],
#              16: ['man'],
#              187: ['would', 'wouldn’t', 'shouldn’t', 'wouldnt', 'couldn’t'],
#              491: ['the', 'their', 'theirs'],
#              17: ['dead'],
#              570: ['frighten',
#               'relax',
#               'quick',
#               'swore_an_oath',
#               'winter_is_coming',
#               'direwolf',
#               'he’s_got',
#               'minute',
#               'damn',
#               'write',
#               'always_wanted',
#               'never_forget',
#               'hello',
#               'celebrate',
#               'accept',
#               'it’s_time',
#               'bargain',
#               'cripple',
#               'ahead',
#               'nymeria',
#               'say_goodbye',
#               'farewell',
#               'recall',
#               'unspeakable',
#               'untie',
#               'dwarf',
#               'repulsive',
#               'nephew',
#               'nicely',
#               'ill_tell',
#               'immediate',
#               'whats_happening',
#               'hes_dead',
#               'myself',
#               'finally',
#               'wont_hurt',
#               'filthy',
#               'directly',
#               'quiet',
#               'quickly',
#               'animal',
#               'gladly',
#               'doesnt_mean',
#               'appropriate',
#               'glad',
#               'except',
#               'duel',
#               'im_afraid',
#               'mmm',
#               '3',
#               'supply',
#               'freeze',
#               'itd',
#               'help_us',
#               'calm',
#               'littlefingers',
#               'wait_wait',
#               'lancel',
#               'plead',
#               'particularly',
#               'enjoy',
#               'im_not_sure',
#               'ive_done',
#               'advantage',
#               'rabbits',
#               'eventually',
#               'youve_done',
#               'ill_find',
#               'samwell_tarly',
#               'sufficient',
#               '15',
#               'unlikely',
#               'cruel',
#               'keep_the_peace',
#               'tourney',
#               'envy',
#               'counsel',
#               'presume',
#               'syrio',
#               'study',
#               'youre_afraid',
#               'pycelle',
#               'ser_hugh',
#               'immediately',
#               'helmet',
#               'afternoon',
#               'gag',
#               'leave_us',
#               'invite',
#               'stinks',
#               'slut',
#               'silly',
#               'want_to_see',
#               'rude',
#               'ser_gregor',
#               'im_glad',
#               'somebody',
#               'hmm',
#               'lets_go',
#               'ill_take',
#               'loudly',
#               'sow',
#               'absolutely',
#               'oh_yes',
#               'reply',
#               'strictly',
#               'going_to_kill',
#               'send_word',
#               'may_i_ask',
#               'go_ahead',
#               'wrote',
#               'needs_to_be_done',
#               'unpleasant',
#               'amount',
#               'get_used',
#               'lyanna',
#               'overcome',
#               'give_us',
#               'piece',
#               'trial_by_combat',
#               'avenge',
#               'animals',
#               'angry',
#               'gregor_clegane',
#               'i’ll_never',
#               'gentle',
#               'fierce',
#               'jaw',
#               'comes_of_age',
#               'fruit',
#               'samwell',
#               'daily',
#               'day_and_night',
#               'make_peace',
#               'apparently',
#               'youll_never',
#               'approve',
#               'pursue',
#               'interrupt',
#               'excuse',
#               'pleasant',
#               'somehow',
#               'afterwards',
#               'stupidity',
#               'exactly',
#               'whats_your_name',
#               'apprentice',
#               'slynt',
#               'forbid',
#               'fanatics',
#               'ive_always',
#               'ser_davos',
#               'whats_wrong',
#               'gossip',
#               'negotiate',
#               'stink',
#               'flea_bottom',
#               'jaqen_hghar',
#               'bravery',
#               'belief',
#               'unfortunate',
#               'gilly',
#               'cabin',
#               'tremendous',
#               'definitely',
#               'uncomfortable',
#               'im_not_afraid',
#               'holy',
#               'decency',
#               'necessary',
#               'recognize',
#               'deepwood_motte',
#               'affairs',
#               'seduce',
#               'released',
#               'willem',
#               'behavior',
#               'repaid',
#               'polliver',
#               'fanatic',
#               'xhoan',
#               'helps',
#               'onion_knight',
#               'passage',
#               'need_to_speak',
#               'jobs',
#               'issue',
#               'youve_ever',
#               'romantic',
#               'subjects',
#               'address',
#               'ocean',
#               'brilliant',
#               'ygritte',
#               'free_folk',
#               'qhorin_halfhand',
#               'affliction',
#               'think_id',
#               'torture',
#               'legacy',
#               'joy',
#               'thief',
#               'strategy',
#               'crib',
#               'lets_see',
#               'explains',
#               'necklace',
#               '12',
#               'rhoyne',
#               'map',
#               'folks',
#               '13',
#               'lady_margaery',
#               'hardly',
#               'swim',
#               'valar_morghulis',
#               'welcome_home',
#               'edd',
#               'avoid',
#               'uphold',
#               'luthor',
#               'jojen',
#               'jump',
#               'relief',
#               'martyn',
#               'ahem',
#               'isle',
#               'extraordinary',
#               'qyburn',
#               'appreciates',
#               'karhold',
#               'mm',
#               'mmhmm',
#               'rabbit',
#               'primary',
#               'yunkish',
#               'myranda',
#               'daario_naharis',
#               'triumph',
#               'reyne',
#               'loud',
#               'doesn’t_matter',
#               'arrogant',
#               'reek',
#               'sunspear',
#               'timid',
#               'pigeon',
#               'good_fortune',
#               'missandei',
#               'olly',
#               'tommens',
#               'uncle_petyr',
#               'shortly',
#               'meryn_trant',
#               'currently',
#               'hizdahr_zo_loraq',
#               'speech',
#               'yarwyck',
#               'stokeworth',
#               'kidney',
#               'suicide',
#               'dohaeris',
#               'decree',
#               'dwarf’s',
#               'hardhome',
#               'famously',
#               'trystane',
#               'i’m_afraid',
#               'i’m_glad',
#               'pussy',
#               'unella',
#               'wylis',
#               'actress',
#               'opposite',
#               'momma',
#               'addresses',
#               'marwyn',
#               'goldcloaks'],
#              18: ['our'],
#              19: ['orders', 'order'],
#              20: ['were'],
#              21: ['we'],
#              22: ['them'],
#              404: ['won’t', 'don’t', 'can’t'],
#              566: ['trouble',
#               'explain',
#               'fool',
#               'play',
#               'tongue',
#               'pentos',
#               'special',
#               'lesson',
#               'gut',
#               'cunt',
#               'supper',
#               'plans',
#               'plate',
#               'wilderness',
#               'guess',
#               'assume',
#               'corpse',
#               'skin',
#               'plan',
#               'priestess',
#               'argue',
#               'stuck',
#               'luckily',
#               'gamble',
#               'daddy',
#               'plague',
#               'hut',
#               'gonna_die',
#               'pink',
#               'suck',
#               'essos'],
#              23: ['us'],
#              24: ['no'],
#              25: ['more'],
#              411: ['don’t_think',
#               'don’t_know',
#               'don’t_care',
#               'believe',
#               'cant_believe',
#               'dont_believe',
#               'don’t_believe',
#               'believes',
#               'believed',
#               'don’t_need',
#               'didn’t_know'],
#              407: ['he’ll', 'we’ll', 'you’ll', 'shell', 'she’ll'],
#              26: ['ask'],
#              27: ['how'],
#              28: ['died'],
#              465: ['get_back',
#               'wake',
#               'go_home',
#               'rescue',
#               'spike',
#               'job',
#               'meet',
#               'begin',
#               'make_sure',
#               'wash',
#               'again',
#               'miss',
#               'visit',
#               'take_care',
#               'finish',
#               'asleep',
#               'tomorrow',
#               'spare',
#               'deep',
#               'sake',
#               'tunnel',
#               'target',
#               'sleep',
#               'red_keep',
#               'pass',
#               'slept',
#               'mourn',
#               'hurry',
#               'slip',
#               'weep',
#               'join_us',
#               'seek',
#               'persuade',
#               'get_some_sleep',
#               'journey',
#               'ride_south',
#               'chop',
#               'square',
#               'oldtown'],
#              29: ['on'],
#              440: ['your',
#               'thank',
#               'perhaps',
#               'apologies',
#               'welcome',
#               'pardon',
#               'ser_jorah',
#               'nonsense',
#               'youre_leaving',
#               'thank_the_gods',
#               'beg_your_pardon',
#               'ser_rodrik',
#               'thanks',
#               'petyr',
#               'cousin',
#               'respect',
#               'youre_right',
#               'also',
#               'courtesy',
#               'ser_alliser',
#               'ser_loras',
#               'quality',
#               'guilty',
#               'agreed',
#               'seize',
#               'thank_you_your_grace',
#               'apologize',
#               'indeed',
#               'shut_your_mouth',
#               'apology',
#               'cousins',
#               'punish',
#               'mustnt',
#               'note',
#               'selwyn',
#               'politics',
#               'equal',
#               'how’s',
#               'softly',
#               'gods’'],
#              540: ['horse',
#               'blade',
#               'reads',
#               'breakfast',
#               'blacksmith',
#               'choose',
#               'nose',
#               'cheese',
#               'bowl',
#               'fucks',
#               'grip',
#               'neck',
#               'fly',
#               'dragonglass',
#               'eastwatch',
#               'draw',
#               'arse',
#               'floor',
#               'stuff',
#               'shove',
#               'ranks',
#               'tail',
#               'collapse',
#               'lose',
#               'teeth',
#               'drove',
#               'group',
#               'camera',
#               'cutthroat',
#               'rope',
#               'bottom',
#               'ripe',
#               'picks',
#               'push',
#               'floors',
#               'flag',
#               'loose',
#               'draw_loose',
#               'rip',
#               'glass',
#               'shows',
#               'drawn',
#               'bloody_gate',
#               'draws'],
#              391: ['seem', 'seems', 'seed', 'seemed'],
#              442: ['have', 'we’ve', 'lve'],
#              528: ['moved',
#               'rode',
#               'lived',
#               'defeated',
#               'waited',
#               'lost',
#               'visited',
#               'prayed',
#               'settled',
#               'lifted',
#               'called',
#               'named',
#               'started',
#               'united',
#               'seized',
#               'treated',
#               'plotted',
#               'spoken',
#               'hanged',
#               'spotted',
#               'wasted',
#               'committed',
#               'signed',
#               'carved',
#               'tasted',
#               'seated'],
#              591: ['camp',
#               'water',
#               'eyrie',
#               'stern',
#               'warden',
#               'chickens',
#               'blackwater_bay',
#               'doorstep',
#               'garden',
#               'quarters',
#               'bay',
#               'blackwater',
#               'gardens',
#               'taverns',
#               'water_gardens',
#               'dozens',
#               'opens'],
#              457: ['here',
#               'where',
#               'there',
#               'somewhere',
#               'going_anywhere',
#               'anywhere',
#               'everywhere',
#               'wherever',
#               'else',
#               'fun',
#               'elsewhere',
#               'nowhere'],
#              30: ['see'],
#              31: ['went'],
#              32: ['is'],
#              33: ['it’s'],
#              34: ['go'],
#              479: ['father’s',
#               'oath',
#               'above',
#               'host',
#               'alive',
#               'none_of_us',
#               'against',
#               'ghost',
#               'prayers',
#               'rest_of_us',
#               'dont_need',
#               'filth',
#               'vows',
#               'scum',
#               'cost',
#               'tower',
#               'accompany',
#               'across_the_world',
#               'upon',
#               'lord_baelish',
#               'cannot',
#               'allow',
#               'darkness',
#               'lost_your_mind',
#               'sickness',
#               'company',
#               'lords_of_westeros',
#               'significant',
#               'capture',
#               'lord_walder',
#               'ser_barristan',
#               'captive',
#               'would_happen',
#               'whichever',
#               'dungeon',
#               'barristan',
#               'homeland',
#               'vow',
#               'revenge',
#               'custody',
#               'assassins',
#               'abandon',
#               'obey',
#               'scouts',
#               'affection',
#               'whisperers',
#               'blind',
#               'dominion',
#               'sacrifice',
#               'long_may',
#               'pyre',
#               'lord_of_light',
#               'upon_us',
#               'night_is_dark_and_full_of_terrors',
#               'lord_cast_your_light_upon',
#               'dignity',
#               'theons',
#               'demands',
#               'moat_cailin',
#               'edge_of_the_world',
#               'died_fighting',
#               'guide',
#               'open_the_gate',
#               'castamere',
#               'challenge',
#               'nothing_to_fear',
#               'must_die',
#               'sapphire',
#               'sapphires',
#               'sandor_clegane',
#               'locke',
#               'grey_worm',
#               'breaker_of_chains',
#               'collect',
#               'crakehall',
#               'open_the_gates',
#               'gift_for_the_gods',
#               'lower',
#               'lord’s',
#               'valar',
#               'dosh_khaleen'],
#              469: ['watching',
#               'watch',
#               'butcher',
#               'watched',
#               'watcher',
#               'watches'],
#              554: ['mother',
#               'mother’s',
#               'mothers',
#               'grandfather',
#               'grant',
#               'grandsons',
#               'grand',
#               'grandson',
#               'grandmother',
#               'granddaughter'],
#              384: ['fine', 'wine', 'nine', 'line', 'dine'],
#              535: ['work',
#               'case',
#               'cry',
#               'fresh',
#               'grass',
#               'sense',
#               'meat',
#               'cup',
#               'feasts',
#               'poor',
#               'task',
#               'stupid',
#               'shit',
#               'court',
#               'works',
#               'sneak',
#               'manage',
#               'point',
#               'cook',
#               'run_away',
#               'slay',
#               'blame',
#               'dry',
#               'pour',
#               'library',
#               'braavos',
#               'window',
#               'potatoes',
#               'vouch',
#               'solid',
#               'poetry',
#               'pod',
#               'points',
#               'arrange',
#               'pork'],
#              395: ['always',
#               'that',
#               'nothing',
#               'one_thing',
#               'shame',
#               'once',
#               'last_thing',
#               'good_thing',
#               'terrible',
#               'terrible_thing',
#               'horrible',
#               'ways',
#               'nothing_else',
#               'terribly',
#               'many_things'],
#              35: ['well'],
#              36: ['done'],
#              37: ['i'],
#              38: ['love'],
#              140: ['you’ve',
#               'you’ve_got',
#               'ive_got',
#               'youve_got',
#               'weve_got',
#               'theyve_got',
#               'you’ve_done'],
#              436: ['managed',
#               'captured',
#               'cat',
#               'beheaded',
#               'beloved',
#               'manned',
#               'chained',
#               'hoped',
#               'trained',
#               'dragged',
#               'wept',
#               'blueeyed',
#               'bleed',
#               'needed',
#               'bloodshed',
#               'stayed',
#               'placed',
#               'doomed',
#               'engaged',
#               'husbands',
#               'opened',
#               'arranged',
#               'owned',
#               'headed',
#               'strangled',
#               'faced',
#               'disobeyed',
#               'crucified',
#               'manyfaced'],
#              39: ['get'],
#              40: ['quite', 'quit'],
#              560: ['beautiful',
#               'forever',
#               'pretty',
#               'handsome',
#               'someday',
#               'insult',
#               'lovely',
#               'happy',
#               'easier',
#               'comfortable',
#               'suppose',
#               'entirely',
#               'grateful',
#               'careful',
#               'wench',
#               'handle',
#               'ugly',
#               'double',
#               'marvelous',
#               'miserable',
#               'easy',
#               'rich',
#               'fit',
#               'admirable',
#               'awful',
#               'simple',
#               'lust',
#               'wonderful',
#               'possess',
#               'eunuch',
#               'suitable',
#               'merciful',
#               'sue',
#               'temple',
#               'useful',
#               'smuggler',
#               'hateful',
#               'valuable',
#               'misery',
#               'harp',
#               'horror',
#               'lawful',
#               'successful',
#               'alright'],
#              41: ['which'],
#              42: ['of'],
#              43: ['was'],
#              44: ['at'],
#              559: ['ten',
#               'preparing',
#               'hearing',
#               'fearing',
#               'boring',
#               'staring',
#               'beard',
#               'wearing',
#               'ring',
#               'bearing',
#               'sand',
#               'sparring'],
#              45: ['keep', 'keeps'],
#              567: ['practicing',
#               'royal',
#               'expecting',
#               'began',
#               'secret',
#               'trap',
#               'thirteen',
#               'completely',
#               'remind',
#               'going_to_die',
#               'carefully',
#               'peasant',
#               'supposed',
#               'hurting',
#               'charming',
#               'funny',
#               'fascinating',
#               'complaining',
#               'surrounded',
#               'enjoying',
#               'below',
#               'noble',
#               'freezing',
#               'pretending',
#               'busy',
#               'cant_defend',
#               'lonely',
#               'thinks',
#               'convincing',
#               'aware',
#               'middle',
#               'perfectly',
#               'therell',
#               'surprised',
#               'human',
#               'exciting',
#               'complicated',
#               'capable',
#               'military',
#               'exhausted',
#               'especially',
#               'remaining',
#               'foul',
#               'wanting',
#               'legendary',
#               'believing',
#               'saan',
#               'devoted',
#               'supporting',
#               'ordinary',
#               'treating',
#               'complete',
#               'despise',
#               'beating',
#               'trant',
#               'forgetting',
#               'abandoning',
#               'frustrating',
#               'awaiting',
#               'complain',
#               'complication',
#               'citizens',
#               'travelling'],
#              588: ['bran',
#               'brandon',
#               'brans',
#               'hodor',
#               'ran',
#               'bran_and_rickon',
#               'ya',
#               'bran_bran',
#               'bran_wake'],
#              46: ['too'],
#              47: ['much'],
#              48: ['bow'],
#              49: ['arm', 'arms'],
#              50: ['jon'],
#              513: ['faster',
#               'ale',
#               'second',
#               'pale',
#               'horde',
#               'trick',
#               'belly',
#               'debt',
#               'afford',
#               'practice',
#               'trade',
#               'pride',
#               'taste',
#               'pile',
#               'tricks',
#               'lannister_always_pays',
#               'debts',
#               'laws',
#               'private',
#               'prisoner',
#               'vile',
#               'hole',
#               'livestock',
#               'prepare',
#               'gown',
#               'badge',
#               'price',
#               'golden',
#               'waste',
#               'rivals',
#               'judge',
#               'trip',
#               'language',
#               'claws',
#               'prisoners',
#               'treachery',
#               'privilege',
#               'crew',
#               'prison',
#               'prize',
#               'iron_bank',
#               'beetle',
#               'fighting_pits'],
#              526: ['lord_stark',
#               'house_stark',
#               'lord_of_winterfell',
#               'stark',
#               'lord_eddard_stark',
#               'stark’s',
#               'ned_stark',
#               'lord_tywin',
#               'lord_snow',
#               'lordship',
#               'hoster',
#               'arya_stark',
#               'brandon_stark',
#               'catelyn_stark',
#               'catelyn_starks',
#               'hostage',
#               'lord_frey',
#               'eddard_stark',
#               'lord_karstark',
#               'sansa_stark',
#               'karstark',
#               'lord_royce'],
#              311: ['lady', 'lads', 'lad', 'ladys', 'milady', 'lady_crane'],
#              51: ['just'],
#              417: ['hills',
#               'passes',
#               'candles',
#               'feet',
#               'tall',
#               'rider',
#               'bird',
#               'troubles',
#               'tribes',
#               'ladies',
#               'favorites',
#               'flowers',
#               'songs',
#               'riders',
#               'dresses',
#               'cripples',
#               'ive_heard',
#               'holdfast',
#               'titles',
#               'riddles',
#               'market',
#               'isles',
#               'path',
#               'losses',
#               'pirates',
#               'stares',
#               'duties',
#               'supplies',
#               'odds',
#               'rocks',
#               'tales',
#               'talents',
#               'mines',
#               'answers',
#               'beetles',
#               'kisses',
#               'area'],
#              430: ['night’s_watch',
#               'warden_of_the_north',
#               'hand_of_the_king',
#               'wildling',
#               'nights_watch',
#               'command',
#               'lord_commander',
#               'commands',
#               'north_of_the_wall',
#               'man_of_the_nights_watch',
#               'city_watch',
#               'commanded',
#               'knights_of_the_vale',
#               'lord_commander_of_the_nights_watch',
#               'commander',
#               'ing_in_the_north',
#               'ing_in_the_north_ing_in_the_north',
#               'sort_of_thing',
#               'jon_snow',
#               'king_in_the_north',
#               'mandon',
#               'lord_of_the_vale',
#               'army_of_the_dead',
#               'sons_of_the_harpy'],
#              565: ['saddle',
#               'listen',
#               'savage',
#               'dove',
#               'one_day',
#               'spread',
#               'read',
#               'executioner',
#               'receive',
#               'disappointment',
#               'final',
#               'yellow',
#               'rumor',
#               'remove',
#               'discuss',
#               'dirt',
#               'disappoint',
#               'discipline',
#               'dusk',
#               'rum',
#               'disappointed',
#               'spirit',
#               'occur',
#               'exist',
#               'volantis',
#               'daxos',
#               'swallow',
#               'list',
#               'woke',
#               'fellow',
#               'dig',
#               'distinction',
#               'disturb',
#               'disease',
#               'disgraced',
#               'perspective',
#               'disappear',
#               'behead',
#               'rush'],
#              380: ['horses',
#               'cities',
#               'lies',
#               'flies',
#               'dies',
#               'spies',
#               'bodies',
#               'allies'],
#              52: ['he'],
#              382: ['law',
#               'seven',
#               'course',
#               'serving',
#               'several',
#               'seven_gods',
#               'blessing',
#               'seven_hells',
#               'seven_blessings',
#               'pity',
#               'small_council',
#               'determined',
#               'sept_of_baelor',
#               'meetings',
#               'discussing',
#               'seventh'],
#              53: ['tell'],
#              54: ['he’s'],
#              546: ['coming',
#               'ready',
#               'came_back',
#               'go_back',
#               'come_back',
#               'bring_him_back',
#               'sack',
#               'coming_back'],
#              55: ['ned'],
#              338: ['young',
#               'being',
#               'meeting',
#               'jousting',
#               'dancing',
#               'waiting',
#               'trusting',
#               'stinking',
#               'wondering',
#               'uniting',
#               'disgusting',
#               'fancy',
#               'writing',
#               'acting',
#               'wasting',
#               'facing',
#               'tempting',
#               'lasting',
#               'resting'],
#              56: ['such'],
#              57: ['be'],
#              58: ['boy'],
#              59: ['run'],
#              60: ['back'],
#              61: ['rest'],
#              577: ['white_walkers',
#               'south_of_the_wall',
#               'aye',
#               'tried_to_kill',
#               'giant',
#               'wheel',
#               'vhagar',
#               'dynasty',
#               'heel',
#               'killed_my_father',
#               'wheat',
#               'nasty',
#               'white',
#               'fist',
#               'whilst',
#               'fucker',
#               'start_a_war',
#               'killed_a_white_walker',
#               'talker',
#               'white_walker',
#               'bare'],
#              62: ['saw'],
#              574: ['broke',
#               'hundred',
#               'helped',
#               'honored',
#               'assured',
#               'ordered',
#               'tired',
#               'betrayed',
#               'broken',
#               'wronged',
#               'suffered',
#               'wondered',
#               'feared',
#               'cared',
#               'butchered',
#               'prepared',
#               'covered',
#               'shared',
#               'branded',
#               'ended',
#               'destroyed',
#               'sacred',
#               'wounded',
#               'abandoned',
#               'considered',
#               'disappeared',
#               'offered',
#               'breed',
#               'acquired',
#               'flayed',
#               'underestimated',
#               'gathered',
#               'admired',
#               'endured',
#               'preferred',
#               'bored',
#               'delivered',
#               'occurred',
#               'ignored',
#               'conspired'],
#              63: ['i’m'],
#              594: ['should',
#               'could',
#               'shouldnt',
#               'couldnt',
#               'shouldve',
#               'couldve',
#               'should’ve'],
#              64: ['gone'],
#              65: ['wall'],
#              385: ['warned',
#               'wanted',
#               'earned',
#               'refused',
#               'damned',
#               'mentioned',
#               'played',
#               'forced',
#               'insulted',
#               'melted',
#               'invented',
#               'poisoned',
#               'became',
#               'enjoyed',
#               'accused',
#               'anointed',
#               'granted',
#               'cursed',
#               'hunted',
#               'painted',
#               'ruined',
#               'noticed',
#               'planned',
#               'executed',
#               'humiliated',
#               'joined',
#               'occupied',
#               'mounted',
#               'convinced',
#               'suggested',
#               'combined',
#               'counseled',
#               'invited',
#               'invaded',
#               'risked',
#               'confused',
#               'sentenced',
#               'reckoned',
#               'pointed',
#               'permitted',
#               'int'],
#              450: ['but',
#               'maybe',
#               'dress',
#               'mind',
#               'unless',
#               'mine',
#               'truly',
#               'minds',
#               'less',
#               'rumors',
#               'mindless',
#               'bless',
#               'weakness',
#               'useless',
#               'faceless',
#               'happiness',
#               'countless'],
#              368: ['people', 'personal', 'person', 'actually', 'actual'],
#              66: ['need'],
#              67: ['if'],
#              68: ['can'],
#              447: ['word',
#               'sword',
#               'swore',
#               'swords',
#               'knife',
#               'swordsman',
#               'sworn',
#               'sword_sword',
#               'put_a_sword',
#               'sellsword'],
#              519: ['family', 'families', 'family_name', 'familiar', 'familys'],
#              615: ['coward',
#               'forward',
#               'steward',
#               'steps',
#               'stewards',
#               'onto',
#               'randyll',
#               'dickon',
#               'steps_forward',
#               'nods'],
#              69: ['i’m_sorry', 'worry', 'sorry', 'i’m_sure', 'im_sorry'],
#              543: ['forgive', 'given', 'forgiveness', 'forgiven'],
#              70: ['me'],
#              71: ['lord'],
#              72: ['name'],
#              388: ['robert', 'robert’s', 'king_roberts', 'roberts'],
#              460: ['house_baratheon',
#               'robert_baratheon',
#               'usurper',
#               'aerys',
#               'king_robert',
#               'theon',
#               'baratheons',
#               'baratheon',
#               'stannis_baratheon',
#               'joffrey_baratheon',
#               'renly_baratheon'],
#              75: ['first_of_his_name',
#               'king_of_the_andals_and_the_first_men',
#               'lord_of_the_seven_kingdoms',
#               'protector_of_the_realm',
#               'andals_and_the_first_men',
#               'jorah_the_andal',
#               'light_of_the_seven',
#               'realms_of_men',
#               'first_men',
#               'old_gods_and_the_new'],
#              73: ['look'],
#              74: ['away'],
#              76: ['will'],
#              487: ['sentence',
#               'country',
#               'absence',
#               'choice',
#               'couple',
#               'essence',
#               'council',
#               'violence',
#               'presence',
#               'commit',
#               'silence',
#               'confidant',
#               'patience',
#               'wisdom',
#               'confidence',
#               'simply',
#               'wifes',
#               'custom',
#               'audience',
#               'mace',
#               'influence',
#               'holiness',
#               'poisons',
#               'condolences',
#               'innocence',
#               'consequences'],
#              77: ['die'],
#              78: ['did'],
#              79: ['why'],
#              542: ['said', 'afraid', 'paid', 'maid', 'raid', 'aid', 'laid'],
#              80: ['had'],
#              81: ['kill'],
#              82: ['him'],
#              83: ['way'],
#              84: ['old'],
#              85: ['who'],
#              318: ['swing',
#               'swinging',
#               'singing',
#               'bringing',
#               'swings',
#               'hanging'],
#              86: ['true'],
#              87: ['been'],
#              88: ['for'],
#              142: ['thousands_of_years',
#               'years',
#               'nine_years',
#               'since',
#               'year',
#               'many_years',
#               'years_ago',
#               '20_years',
#               'hours',
#               '10_years',
#               'long_time',
#               'years_old',
#               'week',
#               'many_years_ago',
#               'weeks',
#               '300_years',
#               'thousand_years',
#               'centuries',
#               'appears',
#               '1000_years'],
#              89: ['so'],
#              504: ['lying',
#               'starting',
#               'doing',
#               'trying',
#               'saying',
#               'buying',
#               'crying',
#               'shining',
#               'praying',
#               'playing',
#               'hoping',
#               'leaving',
#               'staying',
#               'seeing',
#               'dying',
#               'sing',
#               'starving',
#               'having',
#               'begging',
#               'losing',
#               'carrying',
#               'flying',
#               'saving',
#               'rising',
#               'spying',
#               'raping',
#               'undying',
#               'marrying',
#               'paying',
#               'weeping',
#               'terrifying'],
#              514: ['madman',
#               'hey',
#               'month',
#               'today',
#               'ceremony',
#               'money',
#               'mob',
#               'idiot',
#               'whisper',
#               'halfman',
#               'months',
#               'monster',
#               'monarch',
#               'coin',
#               'mom',
#               'moneys',
#               'gifts',
#               'red_woman',
#               'demon',
#               'monkey',
#               'worship',
#               'key',
#               'alley',
#               'heroes',
#               'mostly',
#               'chicken',
#               'mo'],
#              555: ['sees',
#               'likes',
#               'takes',
#               'owes',
#               'cares',
#               'makes',
#               'spikes',
#               'jokes',
#               'cakes',
#               'shakes'],
#              342: ['mountain',
#               'train',
#               'certain',
#               'pain',
#               'remain',
#               'rain',
#               'maintain',
#               'captain',
#               'chain',
#               'aint',
#               'mountains',
#               'main',
#               'gin',
#               'grain'],
#              365: ['lion',
#               'combat',
#               'bone',
#               'moon',
#               'throne_room',
#               'balerion',
#               'sigil',
#               'tyrion',
#               'bald',
#               'beric',
#               'dondarrion',
#               'bath',
#               'bar',
#               'baelor',
#               'wagon',
#               'onion',
#               'balon',
#               'shirt',
#               'bag'],
#              90: ['are'],
#              416: ['lions',
#               'moons',
#               'companions',
#               'jons',
#               'opinions',
#               'opinion',
#               'tyrions',
#               'onions',
#               'visions'],
#              91: ['these'],
#              428: ['woods',
#               'crypt',
#               'clouds',
#               'next',
#               'dark',
#               'beer',
#               'next_time',
#               'color',
#               'wet',
#               'sky',
#               'weapon',
#               'straight',
#               'sat',
#               'open',
#               'wooden',
#               'hood',
#               'town',
#               'white_harbor',
#               'weirwood',
#               'beneath',
#               'agony',
#               'crypts',
#               'harbor',
#               'wood',
#               'courtyard',
#               'overboard',
#               'settle',
#               'mood',
#               'pyramid'],
#              449: ['tough',
#               'rough',
#               'soon_enough',
#               'enough',
#               'far_away',
#               'hungry',
#               'thats_enough',
#               'far_enough',
#               'stupid_enough',
#               'strong_enough'],
#              497: ['beast',
#               'five',
#               'fast',
#               'feast',
#               'guest',
#               'least',
#               'wind',
#               'past',
#               'rast',
#               'breast',
#               'east',
#               'row',
#               'lasts',
#               'craster',
#               'coast',
#               'cast',
#               'pen',
#               'fastest',
#               'beasts',
#               'toast'],
#              92: ['now'],
#              93: ['want'],
#              472: ['hold',
#               'strong',
#               'wild',
#               'weak',
#               'cold',
#               'stronger',
#               'stronghold',
#               'strongest'],
#              224: ['belong', 'belongs', 'belonged'],
#              94: ['down'],
#              402: ['better',
#               'letter',
#               'happier',
#               'youd_better',
#               'feels',
#               'joke',
#               'feel_better',
#               'much_better',
#               'gutter',
#               'fewer'],
#              515: ['death', 'deal', 'deaths', 'dealt'],
#              95: ['last'],
#              360: ['without',
#               'greatest',
#               'great_honor',
#               'great',
#               'great_victory',
#               'grenn',
#               'victory',
#               'defeat',
#               'great_deal',
#               'great_warrior',
#               'greatness',
#               'treat',
#               'creature',
#               'greater',
#               'great_war',
#               'great_house'],
#              126: ['right',
#               'eight',
# ...
#               'protecting',
#               'protects',
#               'betray',
#               'protection',
#               'protected',
#               'protector',
#               'protect_us'],
#              232: ['spent', 'spend'],
#              353: ['different', 'difference', 'differences', 'differently'],
#              324: ['planning',
#               'winning',
#               'running',
#               'beginning',
#               'wings',
#               'wing'],
#              495: ['crown', 'crows', 'crow', 'crowd', 'crowded', 'crowns'],
#              233: ['shall'],
#              234: ['war'],
#              235: ['ser'],
#              517: ['mormont', 'jorah', 'mormonts', 'jorah_mormont'],
#              412: ['served', 'deserves', 'deserve', 'deserved'],
#              236: ['serve'],
#              362: ['eggs',
#               'fish',
#               'pigs',
#               'piggy',
#               'pin',
#               'pig',
#               'pit',
#               'pie'],
#              389: ['lands',
#               'castle',
#               'westeros',
#               'vale',
#               'riverrun',
#               'iron_islands',
#               'westerlands',
#               'dorne',
#               'riverlands',
#               'forces',
#               'west',
#               'stormlands',
#               'westerosi'],
#              429: ['turned',
#               'looked',
#               'shed',
#               'pulled',
#               'pushed',
#               'finished',
#               'crushed',
#               'wished'],
#              521: ['stone',
#               'million',
#               'stood',
#               'stolen',
#               'stallion',
#               'poison',
#               'storm',
#               'song',
#               'skills',
#               'stole',
#               'sausage',
#               'meals',
#               'dragonstone',
#               'lemon',
#               'stones',
#               'stony',
#               'stonemason',
#               'storms_end',
#               'stomach',
#               'orson'],
#              237: ['end'],
#              538: ['pick',
#               'stick',
#               'ass',
#               'sick',
#               'podrick',
#               'lick',
#               'dick',
#               'rodrick'],
#              414: ['land',
#               'bannermen',
#               'banner',
#               'bannerman',
#               'banners',
#               'band'],
#              308: ['spear', 'speaks', 'speak', 'talks'],
#              239: ['loyal', 'loyalty'],
#              240: ['boys'],
#              243: ['mad'],
#              244: ['isnt'],
#              245: ['cant'],
#              246: ['live'],
#              523: ['hands',
#               'hounds',
#               'ground',
#               'winds',
#               'sounds',
#               'rounds',
#               'wounds'],
#              247: ['youd'],
#              520: ['interest', 'interesting', 'interested', 'interests'],
#              248: ['ill'],
#              249: ['slaver', 'slaves', 'slave', 'slavery', 'slavers'],
#              250: ['selling',
#               'telling',
#               'killing',
#               'sell',
#               'calling',
#               'pulling'],
#              509: ['under',
#               'prettier',
#               'harder',
#               'wiser',
#               'older',
#               'prefer',
#               'intend',
#               'younger',
#               'gambler',
#               'pretend',
#               'surrender',
#               'pretender',
#               'bend',
#               'walder'],
#              251: ['wont'],
#              413: ['bitches',
#               'bitch',
#               'bunch',
#               'catch',
#               'hatch',
#               'match',
#               'pitch',
#               'fetch',
#               'witch'],
#              252: ['youre'],
#              253: ['ride'],
#              254: ['none'],
#              255: ['means'],
#              256: ['im'],
#              475: ['fall', 'calls', 'balls', 'walls', 'halls', 'falls'],
#              599: ['knees', 'needs', 'kneel', 'knee', 'kneeling', 'kneels'],
#              257: ['front'],
#              510: ['service',
#               'twice',
#               'notice',
#               'voice',
#               'spider',
#               'slice',
#               'spit',
#               'nice',
#               'spite',
#               'spice',
#               'spy',
#               'ice'],
#              427: ['bread',
#               'breath',
#               'breathing',
#               'break',
#               'breathe',
#               'breaks'],
#              259: ['mean'],
#              260: ['its'],
#              571: ['ridiculous',
#               'dangerous',
#               'famous',
#               'curious',
#               'ponderous',
#               'vicious',
#               'important',
#               'jealous',
#               'generous',
#               'serious',
#               'seriously',
#               'precious',
#               'obvious',
#               'glorious',
#               'nervous',
#               'tedious',
#               'reasonable',
#               'suspicious',
#               'obviously'],
#              456: ['wheres', 'theres', 'heres'],
#              372: ['built', 'build', 'builder', 'builders'],
#              261: ['side'],
#              463: ['tried', 'lied', 'cried', 'buried', 'worried'],
#              262: ['beat'],
#              263: ['came'],
#              399: ['screamed',
#               'screams',
#               'screamers',
#               'scream',
#               'screaming',
#               'flames',
#               'flame',
#               'screamer'],
#              490: ['return', 'returning', 'returns'],
#              264: ['am'],
#              530: ['standing',
#               'defend',
#               'sending',
#               'defense',
#               'defending',
#               'ending',
#               'defended'],
#              265: ['weve'],
#              589: ['taken', 'returned', 'retake', 'retaken'],
#              458: ['septa', 'septon', 'high_septon', 'sept', 'septons'],
#              451: ['gloves',
#               'holes',
#               'names',
#               'beds',
#               'finds',
#               'castles',
#               'babies',
#               'thieves',
#               'faces',
#               'tries',
#               'fires',
#               'trees',
#               'bones',
#               'holds',
#               'corpses',
#               'rises',
#               'inches',
#               'armies',
#               'homes',
#               'villages',
#               'leaves',
#               'moves',
#               'leagues',
#               'axes',
#               'lines',
#               'loses',
#               'foes',
#               'waves',
#               'roses',
#               'stores',
#               'defenses',
#               'continues',
#               'wages',
#               'boxes',
#               'reaches',
#               'pauses',
#               'glances',
#               'retrieves'],
#              266: ['dont'],
#              267: ['mans'],
#              268: ['youll'],
#              269: ['does'],
#              270: ['best'],
#              271: ['youve'],
#              272: ['made'],
#              482: ['really', 'sally', 'peace', 'usually', 'ally', 'rally'],
#              273: ['must'],
#              274: ['hard'],
#              557: ['kind',
#               'reward',
#               'kinder',
#               'sadly',
#               'badly',
#               'godly',
#               'kindly',
#               'kin'],
#              275: ['ive'],
#              276: ['ago'],
#              470: ['marry', 'carry', 'arry'],
#              277: ['few'],
#              278: ['big'],
#              616: ['tits', 'sits', 'pits', 'suits', 'wits', 'hits', 'exits'],
#              279: ['face'],
#              280: ['gonna'],
#              281: ['hit'],
#              282: ['wed'],
#              284: ['shes'],
#              285: ['legs', 'leg'],
#              593: ['start',
#               'part',
#               'smart',
#               'parts',
#               'cart',
#               'art',
#               'us_apart',
#               'apart'],
#              286: ['100000', '20000', '10000', '100', '2000', '1000', '8000'],
#              287: ['ships', 'ship'],
#              288: ['sea'],
#              289: ['sit'],
#              290: ['fed'],
#              291: ['id'],
#              568: ['born',
#               'horn',
#               'torn',
#               'lowborn',
#               'trueborn',
#               'ironborn',
#               'stubborn',
#               'reborn',
#               'firstborn'],
#              292: ['books', 'book', 'looks'],
#              317: ['room', 'rooms', 'rot', 'ros', 'root', 'roof'],
#              294: ['hes'],
#              466: ['six', '10', '50', '20', '500', '200', '300', '700'],
#              295: ['follows', 'follow', 'followed', 'following'],
#              296: ['fire'],
#              298: ['thousand', 'thousands'],
#              299: ['wife'],
#              572: ['learn', 'learned', 'learning', 'learns', 'learner'],
#              300: ['between'],
#              301: ['wasnt'],
#              419: ['stake', 'mistake', 'mistakes'],
#              396: ['reason', 'treason', 'reasons', 'treasonous'],
#              454: ['dagger', 'finger', 'longer', 'ginger'],
#              534: ['valyrian_steel', 'valyria', 'valyrian'],
#              302: ['gave'],
#              303: ['try'],
#              492: ['large', 'larger', 'largest'],
#              486: ['traveled', 'travel', 'travels', 'traveling'],
#              305: ['top'],
#              306: ['hasnt'],
#              307: ['ripped',
#               'chopped',
#               'stopped',
#               'wrapped',
#               'stripped',
#               'shipped',
#               'stepped',
#               'slipped',
#               'dropped',
#               'trapped',
#               'whipped'],
#              309: ['walk'],
#              310: ['safe'],
#              320: ['knight', 'knights', 'nights', 'knighted'],
#              312: ['bring', 'brings'],
#              313: ['stream',
#               'streets',
#               'steel',
#               'strike',
#               'street',
#               'struck',
#               'strip',
#               'tree',
#               'strikes',
#               'strife'],
#              467: ['joffrey',
#               'joffreys',
#               'king_joffrey',
#               'freys',
#               'king_joffreys',
#               'kill_joffrey'],
#              374: ['happened', 'happen', 'happens', 'happening'],
#              315: ['set'],
#              415: ['attacked', 'attack', 'attacks', 'attacking'],
#              392: ['river', 'arrive', 'arrived', 'drive'],
#              316: ['crime', 'crimes'],
#              319: ['chosen', 'chose'],
#              532: ['stabbed',
#               'knocked',
#               'fucked',
#               'naked',
#               'talked',
#               'kicked',
#               'worked',
#               'walked',
#               'picked',
#               'marked',
#               'mocked',
#               'wicked',
#               'shocked',
#               'locked'],
#              423: ['instead', 'stew', 'steal', 'stead', 'step'],
#              512: ['renly', 'renlys'],
#              438: ['tully',
#               'faithfully',
#               'faith',
#               'fully',
#               'rewarded',
#               'faith_militant',
#               'faithful'],
#              322: ['winter', 'winters'],
#              323: ['gold'],
#              325: ['owe'],
#              553: ['master_of_coin',
#               'master',
#               'masters',
#               'astapor',
#               'unsullied',
#               'kraznys',
#               'master_kraznys',
#               'yunkai',
#               'wise_masters',
#               'former_slaves',
#               'masks'],
#              326: ['fear'],
#              328: ['warrior', 'warriors'],
#              330: ['rebel', 'rebellion', 'rebelled', 'rebels'],
#              468: ['sorts',
#               'peasants',
#               'brains',
#               'guts',
#               'giants',
#               'veins',
#               'whores',
#               'puts',
#               'roots',
#               'boots',
#               'cunts',
#               'lips',
#               'silver',
#               'lots',
#               'chains',
#               'clans',
#               'rots',
#               'pockets',
#               'sets',
#               'cocks',
#               'pots',
#               'ideas',
#               'shoes',
#               'usual',
#               'captains',
#               'hornfoots'],
#              331: ['save'],
#              332: ['food'],
#              552: ['tells', 'smell', 'smells', 'smelled'],
#              333: ['em'],
#              358: ['either', 'neither', 'nor'],
#              334: ['ones'],
#              336: ['eye'],
#              337: ['city'],
#              476: ['knowledge',
#               'edge',
#               'pledge',
#               'bridge',
#               'sledge',
#               'pledged'],
#              339: ['grew'],
#              340: ['turn', 'turns'],
#              341: ['bad'],
#              383: ['able', 'stable', 'stables', 'table'],
#              344: ['cerseis', 'cersei', 'joffrey_cersei'],
#              549: ['hammer', 'hall', 'salt', 'ham', 'ha', 'hail', 'halt'],
#              346: ['hed'],
#              531: ['tywin', 'twins', 'tywins'],
#              348: ['buy'],
#              349: ['decides', 'decide', 'decided'],
#              350: ['ear'],
#              536: ['miles', 'smile', 'smiles'],
#              352: ['provided',
#               'provide',
#               'proved',
#               'prove',
#               'proven',
#               'declared'],
#              354: ['baby'],
#              355: ['days'],
#              356: ['flee', 'fleet', 'flesh'],
#              609: ['greyjoy',
#               'balon_greyjoy',
#               'greyjoys',
#               'lord_greyjoy',
#               'theon_greyjoy',
#               'euron_greyjoy',
#               'euron'],
#              364: ['sailors', 'sails', 'sail', 'ls', 'fail'],
#              361: ['worse'],
#              614: ['cowards',
#               'walking',
#               'gendry',
#               'toward',
#               'davos',
#               'towards',
#               'walks',
#               'yards',
#               'boat',
#               'pulls',
#               'walking_towards',
#               'walking_along',
#               'begins_walking',
#               'walks_away',
#               'turns_and_walks'],
#              578: ['marching', 'march', 'marched', 'marches'],
#              367: ['conquer',
#               'conqueror',
#               'conquerors',
#               'conquest',
#               'conquering',
#               'conquered'],
#              548: ['coins',
#               'ruin',
#               'tens',
#               'sins',
#               'wins',
#               'remains',
#               'runs',
#               'begins',
#               'ruins'],
#              369: ['charge', 'charges', 'charged'],
#              613: ['last_hearth',
#               'earth',
#               'qarth',
#               'tarth',
#               'island',
#               'naath',
#               'naarth'],
#              371: ['kept'],
#              516: ['claim', 'claims', 'claimed'],
#              505: ['message', 'age', 'village', 'cage', 'carriage'],
#              376: ['met'],
#              377: ['breach', 'beach', 'reach'],
#              378: ['won'],
#              379: ['red'],
#              544: ['ends', 'sends', 'depends', 'amends'],
#              381: ['games', 'game'],
#              386: ['concerned', 'concerns', 'concern', 'concerning'],
#              506: ['loras',
#               'house_tyrell',
#               'tyrell',
#               'loras_tyrell',
#               'tyrells',
#               'orell'],
#              547: ['freedom', 'free', 'freed', 'reed'],
#              393: ['lay'],
#              405: ['goes'],
#              406: ['god'],
#              435: ['cell', 'cells', 'bells'],
#              410: ['trial'],
#              421: ['low'],
#              582: ['paper', 'raped', 'rape', 'rat', 'raper'],
#              425: ['heir'],
#              431: ['led'],
#              597: ['green', 'meereenese', 'shireen', 'meereen', 'mereen'],
#              441: ['l'],
#              443: ['lm'],
#              445: ['gates', 'gate']})

# %% [markdown]
# That's pretty neat! We get some clusters, and we can see how the words are put in the same groups.
#
# Is there anything kind of annoying? Too many one-word clusters? Clusters with too many words? Let's remove them to find some more insightful results.

# %%
def get_insightful_clusters(clusters, min_len=3, max_len=25):
    insightful_clusters = {}
    for idx, words in clusters.items():
        if len(words) < min_len or len(words) > max_len:
            continue
        insightful_clusters[idx] = words
    return insightful_clusters
        

get_insightful_clusters(clusters)
# Out:
# {208: ['what', 'whatever', 'what’re', 'what’s', 'whats'],
#  605: ['expect',
#   'demand',
#   'expected',
#   'experienced',
#   'enemy',
#   'reputation',
#   'entire',
#   'question',
#   'mention',
#   'position',
#   'invitation',
#   'action',
#   'experience',
#   'ambition',
#   'direction',
#   'situation',
#   'notion',
#   'imagination',
#   'devotion',
#   'expert',
#   'traditionally',
#   'tradition',
#   'option',
#   'proposition',
#   'expedition'],
#  600: ['they’re',
#   'they',
#   'they’ve',
#   'theyre',
#   'theyve',
#   'theyll',
#   'theyd',
#   'they’ll',
#   'they’d'],
#  400: ['savages',
#   'dothraki',
#   'women',
#   'children',
#   'women_and_children',
#   'grandchildren',
#   'free_men',
#   'men_women_and_children'],
#  606: ['another',
#   'brother',
#   'half',
#   'brotherhood',
#   'brothels',
#   'brothel',
#   'older_brother',
#   'brother’s',
#   'bother',
#   'cause',
#   'halfhand',
#   'halfbrother'],
#  488: ['before', 'whore', 'shores', 'bore', 'shore', 'tore', 'ashore', 'ash'],
#  474: ['know',
#   'understand',
#   'meant',
#   'don’t_understand',
#   'dont_know',
#   'dont_care',
#   'dont_think',
#   'dont_trust',
#   'dont_worry',
#   'understands',
#   'understood',
#   'dont_understand'],
#  590: ['other',
#   'father',
#   'rather',
#   'id_rather',
#   'gather',
#   'matter',
#   'further',
#   'farther',
#   'whether',
#   'leather',
#   'weather'],
#  596: ['pieces',
#   'thats',
#   'shits',
#   'eats',
#   'cats',
#   'goats',
#   'lts',
#   'twat',
#   'rats',
#   'boats',
#   'twats'],
#  481: ['never_seen',
#   'never_met',
#   'ever_seen',
#   'ive_seen',
#   'ive_never',
#   'youve_seen',
#   'ive_never_seen',
#   'ive_ever_seen',
#   'i’ve_seen'],
#  607: ['thing', 'things', 'think', 'thin'],
#  321: ['like',
#   'feel_like',
#   'wasn’t',
#   'looked_like',
#   'sounds_like',
#   'dont_like',
#   'youd_like',
#   'felt_like',
#   'felt',
#   'hadnt',
#   'looks_like',
#   'id_like',
#   'look_like',
#   'seems_like',
#   'alike'],
#  507: ['this',
#   'anything',
#   'plenty',
#   'something',
#   'perfect',
#   'anything_else',
#   'sometimes',
#   'theres_nothing',
#   'there’s_nothing',
#   'something_else',
#   'theres_something',
#   'theres_still'],
#  115: ['ever',
#   'never',
#   'fever',
#   'clever',
#   'whoever',
#   'ive_ever',
#   'however',
#   'whenever'],
#  166: ['close', 'closed', 'closest', 'closer'],
#  187: ['would', 'wouldn’t', 'shouldn’t', 'wouldnt', 'couldn’t'],
#  491: ['the', 'their', 'theirs'],
#  404: ['won’t', 'don’t', 'can’t'],
#  411: ['don’t_think',
#   'don’t_know',
#   'don’t_care',
#   'believe',
#   'cant_believe',
#   'dont_believe',
#   'don’t_believe',
#   'believes',
#   'believed',
#   'don’t_need',
#   'didn’t_know'],
#  407: ['he’ll', 'we’ll', 'you’ll', 'shell', 'she’ll'],
#  391: ['seem', 'seems', 'seed', 'seemed'],
#  442: ['have', 'we’ve', 'lve'],
#  591: ['camp',
#   'water',
#   'eyrie',
#   'stern',
#   'warden',
#   'chickens',
#   'blackwater_bay',
#   'doorstep',
#   'garden',
#   'quarters',
#   'bay',
#   'blackwater',
#   'gardens',
#   'taverns',
#   'water_gardens',
#   'dozens',
#   'opens'],
#  457: ['here',
#   'where',
#   'there',
#   'somewhere',
#   'going_anywhere',
#   'anywhere',
#   'everywhere',
#   'wherever',
#   'else',
#   'fun',
#   'elsewhere',
#   'nowhere'],
#  469: ['watching', 'watch', 'butcher', 'watched', 'watcher', 'watches'],
#  554: ['mother',
#   'mother’s',
#   'mothers',
#   'grandfather',
#   'grant',
#   'grandsons',
#   'grand',
#   'grandson',
#   'grandmother',
#   'granddaughter'],
#  384: ['fine', 'wine', 'nine', 'line', 'dine'],
#  395: ['always',
#   'that',
#   'nothing',
#   'one_thing',
#   'shame',
#   'once',
#   'last_thing',
#   'good_thing',
#   'terrible',
#   'terrible_thing',
#   'horrible',
#   'ways',
#   'nothing_else',
#   'terribly',
#   'many_things'],
#  140: ['you’ve',
#   'you’ve_got',
#   'ive_got',
#   'youve_got',
#   'weve_got',
#   'theyve_got',
#   'you’ve_done'],
#  559: ['ten',
#   'preparing',
#   'hearing',
#   'fearing',
#   'boring',
#   'staring',
#   'beard',
#   'wearing',
#   'ring',
#   'bearing',
#   'sand',
#   'sparring'],
#  588: ['bran',
#   'brandon',
#   'brans',
#   'hodor',
#   'ran',
#   'bran_and_rickon',
#   'ya',
#   'bran_bran',
#   'bran_wake'],
#  526: ['lord_stark',
#   'house_stark',
#   'lord_of_winterfell',
#   'stark',
#   'lord_eddard_stark',
#   'stark’s',
#   'ned_stark',
#   'lord_tywin',
#   'lord_snow',
#   'lordship',
#   'hoster',
#   'arya_stark',
#   'brandon_stark',
#   'catelyn_stark',
#   'catelyn_starks',
#   'hostage',
#   'lord_frey',
#   'eddard_stark',
#   'lord_karstark',
#   'sansa_stark',
#   'karstark',
#   'lord_royce'],
#  311: ['lady', 'lads', 'lad', 'ladys', 'milady', 'lady_crane'],
#  430: ['night’s_watch',
#   'warden_of_the_north',
#   'hand_of_the_king',
#   'wildling',
#   'nights_watch',
#   'command',
#   'lord_commander',
#   'commands',
#   'north_of_the_wall',
#   'man_of_the_nights_watch',
#   'city_watch',
#   'commanded',
#   'knights_of_the_vale',
#   'lord_commander_of_the_nights_watch',
#   'commander',
#   'ing_in_the_north',
#   'ing_in_the_north_ing_in_the_north',
#   'sort_of_thing',
#   'jon_snow',
#   'king_in_the_north',
#   'mandon',
#   'lord_of_the_vale',
#   'army_of_the_dead',
#   'sons_of_the_harpy'],
#  380: ['horses',
#   'cities',
#   'lies',
#   'flies',
#   'dies',
#   'spies',
#   'bodies',
#   'allies'],
#  382: ['law',
#   'seven',
#   'course',
#   'serving',
#   'several',
#   'seven_gods',
#   'blessing',
#   'seven_hells',
#   'seven_blessings',
#   'pity',
#   'small_council',
#   'determined',
#   'sept_of_baelor',
#   'meetings',
#   'discussing',
#   'seventh'],
#  546: ['coming',
#   'ready',
#   'came_back',
#   'go_back',
#   'come_back',
#   'bring_him_back',
#   'sack',
#   'coming_back'],
#  338: ['young',
#   'being',
#   'meeting',
#   'jousting',
#   'dancing',
#   'waiting',
#   'trusting',
#   'stinking',
#   'wondering',
#   'uniting',
#   'disgusting',
#   'fancy',
#   'writing',
#   'acting',
#   'wasting',
#   'facing',
#   'tempting',
#   'lasting',
#   'resting'],
#  577: ['white_walkers',
#   'south_of_the_wall',
#   'aye',
#   'tried_to_kill',
#   'giant',
#   'wheel',
#   'vhagar',
#   'dynasty',
#   'heel',
#   'killed_my_father',
#   'wheat',
#   'nasty',
#   'white',
#   'fist',
#   'whilst',
#   'fucker',
#   'start_a_war',
#   'killed_a_white_walker',
#   'talker',
#   'white_walker',
#   'bare'],
#  594: ['should',
#   'could',
#   'shouldnt',
#   'couldnt',
#   'shouldve',
#   'couldve',
#   'should’ve'],
#  450: ['but',
#   'maybe',
#   'dress',
#   'mind',
#   'unless',
#   'mine',
#   'truly',
#   'minds',
#   'less',
#   'rumors',
#   'mindless',
#   'bless',
#   'weakness',
#   'useless',
#   'faceless',
#   'happiness',
#   'countless'],
#  368: ['people', 'personal', 'person', 'actually', 'actual'],
#  447: ['word',
#   'sword',
#   'swore',
#   'swords',
#   'knife',
#   'swordsman',
#   'sworn',
#   'sword_sword',
#   'put_a_sword',
#   'sellsword'],
#  519: ['family', 'families', 'family_name', 'familiar', 'familys'],
#  615: ['coward',
#   'forward',
#   'steward',
#   'steps',
#   'stewards',
#   'onto',
#   'randyll',
#   'dickon',
#   'steps_forward',
#   'nods'],
#  69: ['i’m_sorry', 'worry', 'sorry', 'i’m_sure', 'im_sorry'],
#  543: ['forgive', 'given', 'forgiveness', 'forgiven'],
#  388: ['robert', 'robert’s', 'king_roberts', 'roberts'],
#  460: ['house_baratheon',
#   'robert_baratheon',
#   'usurper',
#   'aerys',
#   'king_robert',
#   'theon',
#   'baratheons',
#   'baratheon',
#   'stannis_baratheon',
#   'joffrey_baratheon',
#   'renly_baratheon'],
#  75: ['first_of_his_name',
#   'king_of_the_andals_and_the_first_men',
#   'lord_of_the_seven_kingdoms',
#   'protector_of_the_realm',
#   'andals_and_the_first_men',
#   'jorah_the_andal',
#   'light_of_the_seven',
#   'realms_of_men',
#   'first_men',
#   'old_gods_and_the_new'],
#  542: ['said', 'afraid', 'paid', 'maid', 'raid', 'aid', 'laid'],
#  318: ['swing', 'swinging', 'singing', 'bringing', 'swings', 'hanging'],
#  142: ['thousands_of_years',
#   'years',
#   'nine_years',
#   'since',
#   'year',
#   'many_years',
#   'years_ago',
#   '20_years',
#   'hours',
#   '10_years',
#   'long_time',
#   'years_old',
#   'week',
#   'many_years_ago',
#   'weeks',
#   '300_years',
#   'thousand_years',
#   'centuries',
#   'appears',
#   '1000_years'],
#  555: ['sees',
#   'likes',
#   'takes',
#   'owes',
#   'cares',
#   'makes',
#   'spikes',
#   'jokes',
#   'cakes',
#   'shakes'],
#  342: ['mountain',
#   'train',
#   'certain',
#   'pain',
#   'remain',
#   'rain',
#   'maintain',
#   'captain',
#   'chain',
#   'aint',
#   'mountains',
#   'main',
#   'gin',
#   'grain'],
#  365: ['lion',
#   'combat',
#   'bone',
#   'moon',
#   'throne_room',
#   'balerion',
#   'sigil',
#   'tyrion',
#   'bald',
#   'beric',
#   'dondarrion',
#   'bath',
#   'bar',
#   'baelor',
#   'wagon',
#   'onion',
#   'balon',
#   'shirt',
#   'bag'],
#  416: ['lions',
#   'moons',
#   'companions',
#   'jons',
#   'opinions',
#   'opinion',
#   'tyrions',
#   'onions',
#   'visions'],
#  449: ['tough',
#   'rough',
#   'soon_enough',
#   'enough',
#   'far_away',
#   'hungry',
#   'thats_enough',
#   'far_enough',
#   'stupid_enough',
#   'strong_enough'],
#  497: ['beast',
#   'five',
#   'fast',
#   'feast',
#   'guest',
#   'least',
#   'wind',
#   'past',
#   'rast',
#   'breast',
#   'east',
#   'row',
#   'lasts',
#   'craster',
#   'coast',
#   'cast',
#   'pen',
#   'fastest',
#   'beasts',
#   'toast'],
#  472: ['hold',
#   'strong',
#   'wild',
#   'weak',
#   'cold',
#   'stronger',
#   'stronghold',
#   'strongest'],
#  224: ['belong', 'belongs', 'belonged'],
#  402: ['better',
#   'letter',
#   'happier',
#   'youd_better',
#   'feels',
#   'joke',
#   'feel_better',
#   'much_better',
#   'gutter',
#   'fewer'],
#  515: ['death', 'deal', 'deaths', 'dealt'],
#  360: ['without',
#   'greatest',
#   'great_honor',
#   'great',
#   'great_victory',
#   'grenn',
#   'victory',
#   'defeat',
#   'great_deal',
#   'great_warrior',
#   'greatness',
#   'treat',
#   'creature',
#   'greater',
#   'great_war',
#   'great_house'],
#  126: ['right',
#   'eight',
#   'might',
#   'sight',
#   'weight',
#   'light',
#   'bright',
#   'height'],
#  200: ['please',
#   'please_please',
#   'please_dont',
#   'release',
#   'ease',
#   'please_stop',
#   'pleased'],
#  99: ['yourselves', 'yourself', 'themselves', 'ourselves'],
#  581: ['feed',
#   'daughter',
#   'slaughtered',
#   'slaughter',
#   'laugh',
#   'laughed',
#   'slaughtering'],
#  258: ['bury', 'burned', 'burnt', 'burn', 'burning', 'burns'],
#  575: ['one’s', 'there’s', 'where’s', 'she’s', 'here’s'],
#  556: ['warn', 'wars', 'warm', 'warmer', 'warg'],
#  539: ['casterly_rock',
#   'cock',
#   'lock',
#   'knock',
#   'flock',
#   'rock',
#   'nock',
#   'mock',
#   'block'],
#  446: ['foot',
#   'battle',
#   'himself',
#   'movements',
#   'battlements',
#   'battlefield',
#   'battles'],
#  189: ['drop', 'drogo', 'drogon'],
#  439: ['lannisters',
#   'jaime_lannister',
#   'tyrion_lannister',
#   'lannister',
#   'ser_jaime',
#   'lannisport',
#   'cersei_lannister',
#   'house_lannister',
#   'brother_jaime',
#   'tommen',
#   'jaime',
#   'king’s_landing',
#   'lannister’s',
#   'tywin_lannister',
#   'ser_jaime_lannister',
#   'ser_meryn',
#   'uncle_jaime',
#   'king_tommen'],
#  501: ['jon_arryn',
#   'lord_arryn',
#   'rhaegar',
#   'lysa',
#   'lady_arryn',
#   'arryn',
#   'lysa_arryn',
#   'meryn',
#   'oberyn',
#   'aunt_lysa'],
#  561: ['someone',
#   'anyone',
#   'everyone_else',
#   'one_else',
#   'someones',
#   'anyone_else',
#   'someone_else'],
#  409: ['husband',
#   'doubt',
#   'touch',
#   'swear',
#   'madness',
#   'wish',
#   'admire',
#   'kindness',
#   'admit',
#   'wish_i_could',
#   'bend_the_knee',
#   'anymore',
#   'didnt_mean',
#   'send_a_raven',
#   'wish_to_confess',
#   'confess',
#   'beg',
#   'summoned',
#   'confessed',
#   'witness',
#   'wishes',
#   'asks',
#   'execute',
#   'authority'],
#  401: ['outsider',
#   'hundreds',
#   'bigger',
#   'outside',
#   'number',
#   'outnumbered',
#   'umber',
#   'outnumber',
#   'numbers',
#   'miles_away',
#   'umbers'],
#  503: ['old_gods',
#   'drown',
#   'drowned_god',
#   'red_god',
#   'drowned',
#   'many_faced_god'],
#  525: ['rules', 'ruler', 'rulers'],
#  603: ['raven',
#   'news',
#   'maester_luwin',
#   'maester',
#   'grand_maester',
#   'reports',
#   'citadel',
#   'maester_aemon',
#   'ser_dontos',
#   'maesters',
#   'grand_maester_pycelle',
#   'archmaester',
#   'royce',
#   'maester_wolkan',
#   'wolkan'],
#  527: ['kings_landing',
#   'king’s',
#   'kings',
#   'capital',
#   'kingsroad',
#   'mad_king',
#   'kings_hand',
#   'kingslayer',
#   'kingswood'],
#  473: ['health', 'healthy', 'wealth', 'wealthy', 'wealthiest'],
#  558: ['good',
#   'good_man',
#   'good_news',
#   'lucky',
#   'good_lad',
#   'luck',
#   'good_deal',
#   'good_luck',
#   'goodbye'],
#  564: ['brought', 'caught', 'fought', 'ought', 'bought', 'taught', 'sought'],
#  335: ['rides', 'sides', 'hides', 'hide'],
#  576: ['winterfell',
#   'lack',
#   'black',
#   'thorne',
#   'pack',
#   'castle_black',
#   'backs',
#   'tormund',
#   'back_to_castle_black'],
#  592: ['queen',
#   'queen’s',
#   'daenerys',
#   'queens',
#   'daenerys_stormborn',
#   'queen_regent',
#   'mother_of_dragons',
#   'queen_margaery',
#   'queen_daenerys',
#   'dragon_queen'],
#  238: ['after', 'later', 'hunter', 'hunt', 'enter'],
#  499: ['chamber', 'spot', 'chambers', 'chairs', 'chamber_pot', 'chaos'],
#  173: ['night',
#   'every_night',
#   'everything',
#   'every',
#   'full',
#   'every_day',
#   'tonight',
#   'everyone',
#   'long_night',
#   'everybody',
#   'every_time',
#   'last_night',
#   'every_one',
#   'every_man'],
#  123: ['drinks', 'drink', 'drinking'],
#  363: ['possibly', 'possible', 'impossible'],
#  461: ['hear', 'heart', 'heads', 'hearts', 'heart’s'],
#  477: ['southern',
#   'together',
#   'northern',
#   'south',
#   'northerners',
#   'soup',
#   'northerner',
#   'southerners',
#   'souls'],
#  387: ['stab',
#   'stand',
#   'starve',
#   'stag',
#   'stannis',
#   'stands',
#   'stars',
#   'starts',
#   'stairs',
#   'stags',
#   'stare',
#   'stays'],
#  345: ['hair', 'air', 'fair', 'chair', 'pair'],
#  480: ['grow', 'brown', 'grown'],
#  347: ['many_times',
#   'times',
#   'three',
#   'threw',
#   'three_days',
#   'three_times',
#   'three_dragons',
#   'six_times'],
#  550: ['climbing',
#   'bite',
#   'load',
#   'climb',
#   'ate',
#   'appear',
#   'pirate',
#   'climbed',
#   'near',
#   'cloak',
#   'appreciate',
#   'fate',
#   'reckon',
#   'mate',
#   'climbs',
#   'climate',
#   'cliff',
#   'intimate',
#   'state'],
#  483: ['road', 'seat', 'searching', 'seas', 'search', 'seal'],
#  551: ['promise',
#   'promised',
#   'pray',
#   'wise',
#   'otherwise',
#   'raise',
#   'proper',
#   'noise',
#   'rise',
#   'raised',
#   'devise',
#   'sunrise',
#   'surprise',
#   'praise',
#   'rose'],
#  498: ['sansa', 'sansas', 'aryas'],
#  418: ['sister',
#   'guests',
#   'brothers',
#   'monsters',
#   'enemies',
#   'daughters',
#   'resist',
#   'fathers',
#   'sisters',
#   'sister’s',
#   'brothers_and_sisters',
#   'eldest',
#   'terms',
#   'gathers',
#   'oysters'],
#  403: ['move', 'coat', 'mouths', 'mouth', 'mount'],
#  452: ['guarding',
#   'guarded',
#   'guards',
#   'guard',
#   'pays',
#   'kingsguard',
#   'vanguard',
#   'shield_that_guards',
#   'many_men',
#   'hang'],
#  489: ['shut', 'shh', 'shh_shh', 'shhh'],
#  146: ['soldier', 'sold', 'soldiers'],
#  241: ['that’s', 'let’s', 'lets'],
#  397: ['little',
#   'little_lord',
#   'little_brother',
#   'little_birds',
#   'littlefinger',
#   'little_boy',
#   'little_shit',
#   'little_girl',
#   'little_girls'],
#  611: ['through', 'throw', 'thrown', 'throat', 'throats', 'throws'],
#  587: ['teach', 'tear', 'teaching', 'teacher'],
#  343: ['remember',
#   'dont_remember',
#   'remembered',
#   'remembers',
#   'member',
#   'members'],
#  602: ['showed',
#   'bled',
#   'fled',
#   'asked',
#   'allowed',
#   'received',
#   'failed',
#   'sailed',
#   'saved',
#   'exile',
#   'begged',
#   'spoke',
#   'sealed',
#   'smiled',
#   'exiled'],
#  203: ['didn’t',
#   'don’t_want',
#   'didn’t_want',
#   'dont_want',
#   'didnt',
#   'didnt_want'],
#  598: ['you’re',
#   'youre_going',
#   'im_going',
#   'im_not_going',
#   'we’re_going',
#   'i’m_not_going',
#   'i’m_going',
#   'you’re_going',
#   'we’re_gonna'],
#  424: ['worthy',
#   'worst',
#   'worth',
#   'worm',
#   'wore',
#   'sooner',
#   'worthless',
#   'mess'],
#  394: ['honor', 'young_man', 'honorable_man', 'honorable', 'old_man', 'evil'],
#  195: ['kingdom', 'kingdoms', 'seven_kingdoms'],
#  437: ['while', 'mile', 'awhile'],
#  433: ['early', 'clean', 'nearly', 'tarly', 'clear', 'clears', 'clearly'],
#  541: ['grave', 'leave', 'heat', 'heavy', 'carve', 'cave', 'heave'],
#  155: ['iron_throne', 'throne', 'iron', 'crone'],
#  158: ['bound',
#   'found',
#   'wound',
#   'around',
#   'hound',
#   'sound',
#   'round',
#   'surround'],
#  455: ['blood', 'bloody', 'magic', 'blood_magic'],
#  164: ['hates', 'hate', 'hated'],
#  398: ['meaning',
#   'morning',
#   'threat',
#   'eaten',
#   'training',
#   'evening',
#   'warning',
#   'threatening',
#   'threaten',
#   'drowning',
#   'listening',
#   'threats',
#   'threatened',
#   'joining',
#   'turning'],
#  390: ['door', 'doors', 'doom'],
#  529: ['starks', 'ned_starks', 'robb_starks', 'karstarks', 'marks'],
#  485: ['sundown',
#   'bride',
#   'cross',
#   'fields',
#   'box',
#   'crops',
#   'across',
#   'shields',
#   'crossing',
#   'leads',
#   'crossroads',
#   'roads',
#   'bolt',
#   'crossbow'],
#  293: ['alone',
#   'inside',
#   'behind',
#   'alongside',
#   'stand_behind',
#   'aside',
#   'along',
#   'hide_behind',
#   'beside'],
#  214: ['first', 'first_time', 'last_time', 'first_time_i_saw'],
#  608: ['thought',
#   'we’d',
#   'he’d',
#   'you’d',
#   'though',
#   'thoughts',
#   'never_thought',
#   'thought_youd',
#   'thought_you’d'],
#  453: ['short',
#   'comfort',
#   'escort',
#   'party',
#   'destroy',
#   'sort',
#   'refuse',
#   'deliver',
#   'behalf',
#   'fortnight',
#   'delay',
#   'count',
#   'report',
#   'fortunate',
#   'effort',
#   'port',
#   'fork',
#   'declare',
#   'seaworth',
#   'dreadfort',
#   'fortress'],
#  170: ['changes', 'chances', 'change', 'changed', 'exchange'],
#  502: ['place',
#   'third',
#   'khal_drogo',
#   'dangerous_place',
#   'safest',
#   'sam',
#   'sad',
#   'safely',
#   'safety',
#   'loss',
#   'palace',
#   'safest_place',
#   'safer',
#   'first_place',
#   'better_place'],
#  579: ['hill',
#   'fell',
#   'mighty',
#   'till',
#   'fill',
#   'lll',
#   'dull',
#   'skull',
#   'pull',
#   'skill',
#   'mill',
#   'quill',
#   'spill',
#   'doll'],
#  494: ['dreams', 'dreaming', 'dread', 'dreamed', 'dream', 'dreamt'],
#  524: ['targaryens',
#   'house_targaryen',
#   'daenerys_targaryen',
#   'rhaegar_targaryen',
#   'targaryen',
#   'aegon',
#   'aegons',
#   'targaryen_girl',
#   'aegon_targaryen',
#   'elia'],
#  228: ['isn’t', 'doesn’t', 'doesnt'],
#  610: ['over', 'cover', 'lover', 'glover'],
#  448: ['knows', 'snows', 'everyone_knows', 'one_knows'],
#  375: ['forget', 'forgot', 'forged', 'forge'],
#  511: ['friends', 'friend', 'old_friend', 'friendship'],
#  176: ['woman’s', 'womans', 'woman', 'man’s'],
#  297: ['dragon', 'dragons', 'wagons'],
#  370: ['history', 'story', 'stories', 'histories'],
#  434: ['reign', 'foreign', 'foreigners'],
#  562: ['known',
#   'ever_lived',
#   'never_knew',
#   'ive_known',
#   'ever_met',
#   'ever_since',
#   'ever_known'],
#  493: ['rightful_king',
#   'true_king',
#   'wrong',
#   'speaking',
#   'realm',
#   'new_king',
#   'truth',
#   'rightful',
#   'one_true_god',
#   'one_true_king',
#   'five_kings',
#   'night_king'],
#  422: ['whole', 'whose', 'whos', 'whom', 'who’s', 'whoa', 'whoa_whoa'],
#  569: ['finest',
#   'brave',
#   'youngest',
#   'honest',
#   'richest',
#   'biggest',
#   'darkest',
#   'post',
#   'incest',
#   'forest',
#   'priest',
#   'harvest',
#   'chest',
#   'bravest'],
#  182: ['killers', 'killed', 'killer', 'kills'],
#  231: ['trust', 'trusts', 'trustworthy', 'trusted'],
#  185: ['married', 'carried', 'marries'],
#  563: ['common',
#   'business',
#   'liar',
#   'pet',
#   'champion',
#   'mark',
#   'proof',
#   'true_friend',
#   'companion',
#   'places',
#   'mission',
#   'permission',
#   'role',
#   'discussion',
#   'truths',
#   'passion',
#   'religion',
#   'decision',
#   'corruption',
#   'commoner',
#   'lifetime',
#   'profession',
#   'truce'],
#  209: ['offense', 'offend', 'offer', 'offended'],
#  408: ['gives', 'lives', 'loves', 'wives'],
#  304: ['khal', 'khaleesi', 'khals', 'khalasar'],
#  500: ['prince',
#   'child',
#   'princess',
#   'whip',
#   'princes',
#   'oldest',
#   'myrcella',
#   'margaery',
#   'martell',
#   'princess_myrcella',
#   'martells',
#   'frey',
#   'tullys',
#   'prince_doran',
#   'prince_oberyn'],
#  584: ['powerful_man', 'power', 'idea', 'powerful', 'powers', 'powerless'],
#  204: ['aren’t', 'arent', 'weren’t'],
#  496: ['lady_stark',
#   'catelyn',
#   'ilyn',
#   'payne',
#   'lady_catelyn',
#   'lady_sansa',
#   'baelish',
#   'brienne_of_tarth',
#   'brienne',
#   'lady_brienne',
#   'lady_olenna',
#   'niece'],
#  595: ['bastard',
#   'rickon',
#   'alton',
#   'lord_bolton',
#   'boltons',
#   'bolton',
#   'roose_bolton',
#   'ramsay',
#   'ramsay_bolton'],
#  359: ['giving', 'surviving', 'living', 'survive', 'survival', 'survived'],
#  351: ['making',
#   'talking',
#   'taking',
#   'fucking',
#   'looking',
#   'thinking',
#   'ing',
#   'asking',
#   'joking',
#   'lurking',
#   'willing',
#   'working',
#   'ruling',
#   'helping',
#   'knocking',
#   'breaking',
#   'seeking'],
#  585: ['advice',
#   'advising',
#   'size',
#   'advise',
#   'advisor',
#   'advisors',
#   'advised'],
#  583: ['used',
#   'heard',
#   'dressed',
#   'shoved',
#   'healed',
#   'crossed',
#   'passed',
#   'missed',
#   'pissed',
#   'blessed',
#   'liked',
#   'kissed',
#   'filled',
#   'tossed'],
#  242: ['hurt', 'stops', 'stop_stop', 'stop', 'atop'],
#  612: ['bastards',
#   'regards',
#   'words',
#   'lords',
#   'last_words',
#   'birds',
#   'sellswords',
#   'records'],
#  329: ['bear', 'bears', 'tears', 'ears', 'wears', 'hears', 'spears', 'bars'],
#  522: ['ranger', 'danger', 'strange', 'strangers', 'stranger'],
#  327: ['walkers',
#   'rapers',
#   'hers',
#   'matters',
#   'coppers',
#   'spiders',
#   'rangers',
#   'clothes',
#   'officers',
#   'lovers',
#   'fingers',
#   'others',
#   'whispers',
#   'letters',
#   'tents',
#   'weapons',
#   'crasters',
#   'fuckers',
#   'towers',
#   'farmers',
#   'archers',
#   'invaders',
#   'upper',
#   'mutineers',
#   'pillars'],
#  357: ['robb', 'robbs', 'robin', 'robb_stark'],
#  484: ['scared', 'care', 'scar', 'scare'],
#  366: ['hidden',
#   'highborn',
#   'highly',
#   'high',
#   'higher',
#   'highgarden',
#   'highest',
#   'high_sparrow'],
#  373: ['title',
#   'chance',
#   'ancient',
#   'lance',
#   'ancestors',
#   'birth',
#   'dance',
#   'inheritance',
#   'harrenhal',
#   'marriage',
#   'mance',
#   'importance',
#   'renounce',
#   'stand_a_chance',
#   'alliance',
#   'substance',
#   'allegiance',
#   'vengeance',
#   'circumstances',
#   'signal',
#   'ancestral',
#   'inspire',
#   'distance',
#   'slaver’s_bay',
#   'iron_fleet'],
#  283: ['field', 'held', 'wield', 'yield', 'shield'],
#  464: ['become', 'comes', 'becomes'],
#  518: ['fight', 'fighting', 'fighter', 'fights', 'fighters'],
#  508: ['wedding',
#   'laughing',
#   'wedding_night',
#   'bidding',
#   'bedding',
#   'royal_wedding',
#   'red_wedding'],
#  471: ['murdered',
#   'murders',
#   'murder',
#   'murderer',
#   'murdering',
#   'murderers',
#   'judges'],
#  432: ['protect',
#   'protecting',
#   'protects',
#   'betray',
#   'protection',
#   'protected',
#   'protector',
#   'protect_us'],
#  353: ['different', 'difference', 'differences', 'differently'],
#  324: ['planning', 'winning', 'running', 'beginning', 'wings', 'wing'],
#  495: ['crown', 'crows', 'crow', 'crowd', 'crowded', 'crowns'],
#  517: ['mormont', 'jorah', 'mormonts', 'jorah_mormont'],
#  412: ['served', 'deserves', 'deserve', 'deserved'],
#  362: ['eggs', 'fish', 'pigs', 'piggy', 'pin', 'pig', 'pit', 'pie'],
#  389: ['lands',
#   'castle',
#   'westeros',
#   'vale',
#   'riverrun',
#   'iron_islands',
#   'westerlands',
#   'dorne',
#   'riverlands',
#   'forces',
#   'west',
#   'stormlands',
#   'westerosi'],
#  429: ['turned',
#   'looked',
#   'shed',
#   'pulled',
#   'pushed',
#   'finished',
#   'crushed',
#   'wished'],
#  521: ['stone',
#   'million',
#   'stood',
#   'stolen',
#   'stallion',
#   'poison',
#   'storm',
#   'song',
#   'skills',
#   'stole',
#   'sausage',
#   'meals',
#   'dragonstone',
#   'lemon',
#   'stones',
#   'stony',
#   'stonemason',
#   'storms_end',
#   'stomach',
#   'orson'],
#  538: ['pick', 'stick', 'ass', 'sick', 'podrick', 'lick', 'dick', 'rodrick'],
#  414: ['land', 'bannermen', 'banner', 'bannerman', 'banners', 'band'],
#  308: ['spear', 'speaks', 'speak', 'talks'],
#  523: ['hands', 'hounds', 'ground', 'winds', 'sounds', 'rounds', 'wounds'],
#  520: ['interest', 'interesting', 'interested', 'interests'],
#  249: ['slaver', 'slaves', 'slave', 'slavery', 'slavers'],
#  250: ['selling', 'telling', 'killing', 'sell', 'calling', 'pulling'],
#  509: ['under',
#   'prettier',
#   'harder',
#   'wiser',
#   'older',
#   'prefer',
#   'intend',
#   'younger',
#   'gambler',
#   'pretend',
#   'surrender',
#   'pretender',
#   'bend',
#   'walder'],
#  413: ['bitches',
#   'bitch',
#   'bunch',
#   'catch',
#   'hatch',
#   'match',
#   'pitch',
#   'fetch',
#   'witch'],
#  475: ['fall', 'calls', 'balls', 'walls', 'halls', 'falls'],
#  599: ['knees', 'needs', 'kneel', 'knee', 'kneeling', 'kneels'],
#  510: ['service',
#   'twice',
#   'notice',
#   'voice',
#   'spider',
#   'slice',
#   'spit',
#   'nice',
#   'spite',
#   'spice',
#   'spy',
#   'ice'],
#  427: ['bread', 'breath', 'breathing', 'break', 'breathe', 'breaks'],
#  571: ['ridiculous',
#   'dangerous',
#   'famous',
#   'curious',
#   'ponderous',
#   'vicious',
#   'important',
#   'jealous',
#   'generous',
#   'serious',
#   'seriously',
#   'precious',
#   'obvious',
#   'glorious',
#   'nervous',
#   'tedious',
#   'reasonable',
#   'suspicious',
#   'obviously'],
#  456: ['wheres', 'theres', 'heres'],
#  372: ['built', 'build', 'builder', 'builders'],
#  463: ['tried', 'lied', 'cried', 'buried', 'worried'],
#  399: ['screamed',
#   'screams',
#   'screamers',
#   'scream',
#   'screaming',
#   'flames',
#   'flame',
#   'screamer'],
#  490: ['return', 'returning', 'returns'],
#  530: ['standing',
#   'defend',
#   'sending',
#   'defense',
#   'defending',
#   'ending',
#   'defended'],
#  589: ['taken', 'returned', 'retake', 'retaken'],
#  458: ['septa', 'septon', 'high_septon', 'sept', 'septons'],
#  482: ['really', 'sally', 'peace', 'usually', 'ally', 'rally'],
#  557: ['kind', 'reward', 'kinder', 'sadly', 'badly', 'godly', 'kindly', 'kin'],
#  470: ['marry', 'carry', 'arry'],
#  616: ['tits', 'sits', 'pits', 'suits', 'wits', 'hits', 'exits'],
#  593: ['start', 'part', 'smart', 'parts', 'cart', 'art', 'us_apart', 'apart'],
#  286: ['100000', '20000', '10000', '100', '2000', '1000', '8000'],
#  568: ['born',
#   'horn',
#   'torn',
#   'lowborn',
#   'trueborn',
#   'ironborn',
#   'stubborn',
#   'reborn',
#   'firstborn'],
#  292: ['books', 'book', 'looks'],
#  317: ['room', 'rooms', 'rot', 'ros', 'root', 'roof'],
#  466: ['six', '10', '50', '20', '500', '200', '300', '700'],
#  295: ['follows', 'follow', 'followed', 'following'],
#  572: ['learn', 'learned', 'learning', 'learns', 'learner'],
#  419: ['stake', 'mistake', 'mistakes'],
#  396: ['reason', 'treason', 'reasons', 'treasonous'],
#  454: ['dagger', 'finger', 'longer', 'ginger'],
#  534: ['valyrian_steel', 'valyria', 'valyrian'],
#  492: ['large', 'larger', 'largest'],
#  486: ['traveled', 'travel', 'travels', 'traveling'],
#  307: ['ripped',
#   'chopped',
#   'stopped',
#   'wrapped',
#   'stripped',
#   'shipped',
#   'stepped',
#   'slipped',
#   'dropped',
#   'trapped',
#   'whipped'],
#  320: ['knight', 'knights', 'nights', 'knighted'],
#  313: ['stream',
#   'streets',
#   'steel',
#   'strike',
#   'street',
#   'struck',
#   'strip',
#   'tree',
#   'strikes',
#   'strife'],
#  467: ['joffrey',
#   'joffreys',
#   'king_joffrey',
#   'freys',
#   'king_joffreys',
#   'kill_joffrey'],
#  374: ['happened', 'happen', 'happens', 'happening'],
#  415: ['attacked', 'attack', 'attacks', 'attacking'],
#  392: ['river', 'arrive', 'arrived', 'drive'],
#  532: ['stabbed',
#   'knocked',
#   'fucked',
#   'naked',
#   'talked',
#   'kicked',
#   'worked',
#   'walked',
#   'picked',
#   'marked',
#   'mocked',
#   'wicked',
#   'shocked',
#   'locked'],
#  423: ['instead', 'stew', 'steal', 'stead', 'step'],
#  438: ['tully',
#   'faithfully',
#   'faith',
#   'fully',
#   'rewarded',
#   'faith_militant',
#   'faithful'],
#  553: ['master_of_coin',
#   'master',
#   'masters',
#   'astapor',
#   'unsullied',
#   'kraznys',
#   'master_kraznys',
#   'yunkai',
#   'wise_masters',
#   'former_slaves',
#   'masks'],
#  330: ['rebel', 'rebellion', 'rebelled', 'rebels'],
#  552: ['tells', 'smell', 'smells', 'smelled'],
#  358: ['either', 'neither', 'nor'],
#  476: ['knowledge', 'edge', 'pledge', 'bridge', 'sledge', 'pledged'],
#  383: ['able', 'stable', 'stables', 'table'],
#  344: ['cerseis', 'cersei', 'joffrey_cersei'],
#  549: ['hammer', 'hall', 'salt', 'ham', 'ha', 'hail', 'halt'],
#  531: ['tywin', 'twins', 'tywins'],
#  349: ['decides', 'decide', 'decided'],
#  536: ['miles', 'smile', 'smiles'],
#  352: ['provided', 'provide', 'proved', 'prove', 'proven', 'declared'],
#  356: ['flee', 'fleet', 'flesh'],
#  609: ['greyjoy',
#   'balon_greyjoy',
#   'greyjoys',
#   'lord_greyjoy',
#   'theon_greyjoy',
#   'euron_greyjoy',
#   'euron'],
#  364: ['sailors', 'sails', 'sail', 'ls', 'fail'],
#  614: ['cowards',
#   'walking',
#   'gendry',
#   'toward',
#   'davos',
#   'towards',
#   'walks',
#   'yards',
#   'boat',
#   'pulls',
#   'walking_towards',
#   'walking_along',
#   'begins_walking',
#   'walks_away',
#   'turns_and_walks'],
#  578: ['marching', 'march', 'marched', 'marches'],
#  367: ['conquer',
#   'conqueror',
#   'conquerors',
#   'conquest',
#   'conquering',
#   'conquered'],
#  548: ['coins',
#   'ruin',
#   'tens',
#   'sins',
#   'wins',
#   'remains',
#   'runs',
#   'begins',
#   'ruins'],
#  369: ['charge', 'charges', 'charged'],
#  613: ['last_hearth', 'earth', 'qarth', 'tarth', 'island', 'naath', 'naarth'],
#  516: ['claim', 'claims', 'claimed'],
#  505: ['message', 'age', 'village', 'cage', 'carriage'],
#  377: ['breach', 'beach', 'reach'],
#  544: ['ends', 'sends', 'depends', 'amends'],
#  386: ['concerned', 'concerns', 'concern', 'concerning'],
#  506: ['loras', 'house_tyrell', 'tyrell', 'loras_tyrell', 'tyrells', 'orell'],
#  547: ['freedom', 'free', 'freed', 'reed'],
#  435: ['cell', 'cells', 'bells'],
#  582: ['paper', 'raped', 'rape', 'rat', 'raper'],
#  597: ['green', 'meereenese', 'shireen', 'meereen', 'mereen']}

# %% [markdown]
# These clusters are okay, but there's definitely a lot that could be improved.
#
# Quiz: What would make these clusters better?
# - more data
# - longer convergence iter
# - less weight on character parts

# %% [markdown]
# _Wait a second, what do you mean by better?_

# %% [markdown]
# ### How do I compare two clustering results?
#
# A metric exists to do this: the [silhouette score](https://en.wikipedia.org/wiki/Silhouette_(clustering)#:~:targetText=The%20silhouette%20value%20is%20a,poorly%20matched%20to%20neighboring%20clusters.).
#
# > The silhouette value is a measure of how similar an object is to its own cluster (cohesion) compared to other clusters (separation).
#
# From [sklearn](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html#sklearn.metrics.silhouette_score)
# > The Silhouette Coefficient is calculated using the mean intra-cluster distance (a) and the mean nearest-cluster distance (b) for each sample. The Silhouette Coefficient for a sample is (b - a) / max(a, b). To clarify, b is the distance between a sample and the nearest cluster that the sample is not a part of.
#
# Sure was clear, eh?

# %% [markdown]
# Let's get a better definition of $a$ and $b$.
#
# ![intra-cluster distance](figures/silhouette-a.png)
#
# So for each point $i$ in a cluster, we define $a(i)$ to be the average distance between $i$ and every other point in the cluster. This is a measure of how well $i$ fits in its cluster.
#
# What kind of value (smaller or larger) for $a(i)$ indicates a good fit?

# %% [markdown]
# ![mean nearest-cluster distance](figures/silhouette-b.png)
#
# We find the next-best fitting (or _neighboring_) cluster for point $i$, and measure the average distance from $i$ to all points in that next-best fitting cluster.
#
# What does a high value for $b(i)$ indicate? A low one?

# %% [markdown]
# Now actually to the funciton for the silhouette score...
#
# ![silhouette-score-def](figures/silhouette-def.png)
#
# Which can also be written as a piecewise function that's easier to analyze
#
# ![silhouette-rewritten](figures/silhouette-rewritten.png)
#
# How do $a(i)$ and $b(i)$ compare in each of these situations?
#
# Does this make the silhouette score bounded or unbounded?
#
# Is a higher or lower silhouette score better?

# %% [markdown]
# Let's get a visualization of what's really going on.
#
# ![silhouette visualized](figures/silhouette-visualized.gif)

# %% [markdown]
# Since we care about more than a single point in the clustering results, we average over all points to get teh silhouete score for a data set.
#
# ![Silhouette scores](figures/silhouette_analysis.png)

# %%
from sklearn.metrics import silhouette_score
# sklearn computes the mean silhouette score for all samples
silhouette_score(vectors, af.labels_)
# Out:
# 0.037122615

# %% [markdown]
# Let's compare this with the unphrased model

# %%
# load in the unphrased model
unphrased_model_path = os.path.join('models', 'got_ft.model')
unphrased_model = FastText.load(unphrased_model_path)

# %%
# preprocess and cluster
vectors, words = get_vectors_and_words(unphrased_model)
af = AffinityPropagation(convergence_iter=40,
                         max_iter=1000,
                        )
af.fit(vectors)
# Out:
# AffinityPropagation(affinity='euclidean', convergence_iter=40, copy=True,
#           damping=0.5, max_iter=1000, preference=None, verbose=False)

# %%
# get the silhouette score
silhouette_score(vectors, af.labels_)
# Out:
# 0.024296613

# %% [markdown]
# ## Which model was better?
#
# Objectively: Which model had the better silhouette score?
#
# Subjectively: Let's check out the clusters too.

# %%
# look at the first 20 clusters from the unphrased model
clusters = get_clusters(words, af)
insightful_clusters = get_insightful_clusters(clusters)
insightful_clusters
# Out:
# {195: ['what', 'that’s', 'whatever', 'you’re', 'what’re', 'what’s', 'whats'],
#  434: ['expect',
#   'worthy',
#   'trust',
#   'trusts',
#   'loyal',
#   'worth',
#   'truly',
#   'thinks',
#   'truths',
#   'trustworthy',
#   'trusted',
#   'truce'],
#  529: ['they’re',
#   'they',
#   'they’ve',
#   'theyre',
#   'theyve',
#   'theyll',
#   'theyd',
#   'they’ll',
#   'they’d'],
#  331: ['goat',
#   'horse',
#   'horses',
#   'horde',
#   'hot',
#   'supper',
#   'horseback',
#   '50',
#   'thorne',
#   'arse',
#   'hole',
#   'pack',
#   'market',
#   'shields',
#   'sick',
#   'moat',
#   'atop',
#   'backs',
#   'upper',
#   'dick'],
#  439: ['before',
#   'after',
#   'whore',
#   'short',
#   'shores',
#   'bore',
#   'shore',
#   'tore',
#   'ashore',
#   'ash'],
#  389: ['know',
#   'care',
#   'rare',
#   'dare',
#   'spare',
#   'aware',
#   'scare',
#   'bare',
#   'area'],
#  118: ['never',
#   'ever',
#   'fever',
#   'clever',
#   'once',
#   'wherever',
#   'however',
#   'whenever'],
#  536: ['thing', 'think', 'things', 'thin'],
#  15: ['close', 'closed', 'closer', 'lose'],
#  524: ['would',
#   'should',
#   'might',
#   'shouldnt',
#   'shouldve',
#   'couldve',
#   'should’ve'],
#  443: ['the', 'them', 'their', 'theirs'],
#  383: ['were', 'aren’t', 'werent', 'weren’t'],
#  376: ['won’t', 'cannot', 'can’t'],
#  379: ['he’ll', 'we’ll', 'you’ll', 'shell', 'she’ll'],
#  370: ['seem', 'felt', 'seems', 'seed', 'seemed'],
#  479: ['have',
#   'feed',
#   'hear',
#   'grave',
#   'leave',
#   'heat',
#   'finish',
#   'drove',
#   'heir',
#   'seek',
#   'sends',
#   'carve',
#   'cave',
#   'heave'],
#  303: ['moved',
#   'bled',
#   'fled',
#   'prayed',
#   'healed',
#   'played',
#   'called',
#   'failed',
#   'lied',
#   'seized',
#   'proved',
#   'carried',
#   'cried',
#   'sealed',
#   'headed',
#   'marked',
#   'exiled'],
#  476: ['camp',
#   'captured',
#   'hundred',
#   'tired',
#   'offended',
#   'ends',
#   'suffered',
#   'prepared',
#   'ended',
#   'opened',
#   'arrived',
#   'declared',
#   'offered',
#   'acquired',
#   'endured',
#   'risked',
#   'carved',
#   'intended'],
#  413: ['here',
#   'where',
#   'somewhere',
#   'anywhere',
#   'else',
#   'wheres',
#   'everywhere',
#   'elsewhere',
#   'nowhere'],
#  419: ['watching', 'watch', 'butcher', 'watched', 'watcher', 'watches'],
#  363: ['fine', 'nine', 'wine', 'line', 'dine'],
#  511: ['work', 'piss', 'point', 'pot', 'pour', 'port', 'pork'],
#  395: ['always',
#   'touch',
#   'properly',
#   'liar',
#   'anyone',
#   'either',
#   'admit',
#   'often',
#   'proper',
#   'deny',
#   'prophecy',
#   'proposal',
#   'property',
#   'propose',
#   'prophecies'],
#  342: ['love', 'cover', 'lover', 'lovers', 'glover'],
#  41: ['you’ve', 'we’ve', 'youve'],
#  293: ['which', 'white', 'while', 'whip', 'ship', 'whichever', 'whilst'],
#  407: ['ten', 'coin', 'whisper', 'whispers', 'whispering', 'whisperers'],
#  287: ['bow',
#   'stream',
#   'streets',
#   'strength',
#   'strike',
#   'street',
#   'strip',
#   'strengths',
#   'view',
#   'bottom',
#   'flame',
#   'wood',
#   'strife'],
#  516: ['quick',
#   'itll',
#   'till',
#   'fill',
#   'lll',
#   'dull',
#   'skill',
#   'mill',
#   'quill',
#   'doll'],
#  196: ['stark', 'starks', 'stark’s', 'karstark'],
#  539: ['rode',
#   'trick',
#   'rickon',
#   'rodrik',
#   'gregor',
#   'bronn',
#   'podrick',
#   'rodrick'],
#  478: ['night’s', 'night', 'nights', 'knights', 'nightfall', 'nightshade'],
#  455: ['lads', 'road', 'rot', 'heads', 'roads'],
#  538: ['oath',
#   'north',
#   'hearth',
#   'middle',
#   'earth',
#   'tarth',
#   'qarth',
#   'naath',
#   'naarth'],
#  401: ['young',
#   'bigger',
#   'finger',
#   'youngest',
#   'older',
#   'longer',
#   'younger',
#   'ginger'],
#  333: ['winter', 'winterfell', 'winters'],
#  514: ['walkers', 'walk', 'walker'],
#  322: ['warned', 'earned', 'learn', 'learned', 'learns', 'learner'],
#  410: ['but',
#   'anything',
#   'maybe',
#   'nonsense',
#   'sense',
#   'mind',
#   'unless',
#   'happier',
#   'kindness',
#   'mine',
#   'minds',
#   'less',
#   'worthless',
#   'mindless',
#   'bless',
#   'weakness',
#   'useless',
#   'faceless',
#   'happiness'],
#  429: ['people',
#   'south',
#   'fools',
#   'southern',
#   'together',
#   'northern',
#   'northerners',
#   'northerner',
#   'southerners',
#   'folk',
#   'farther',
#   'souls'],
#  250: ['need', 'needle', 'needs', 'needing', 'needed'],
#  468: ['family', 'families', 'familiar', 'familys'],
#  487: ['forgive', 'given', 'forgiveness', 'forgiven'],
#  355: ['robert', 'robert’s', 'roberts'],
#  264: ['protector',
#   'protect',
#   'protecting',
#   'protects',
#   'protection',
#   'protected'],
#  420: ['realm', 'real', 'realms'],
#  412: ['eddard',
#   'guarding',
#   'guarded',
#   'hard',
#   'open',
#   'guards',
#   'guard',
#   'kingsguard',
#   'vanguard',
#   'hollard',
#   'hang',
#   'board'],
#  456: ['warden', 'highgarden', 'garden', 'gardens'],
#  481: ['said', 'paid', 'raid', 'aid', 'laid'],
#  390: ['years',
#   'wear',
#   'bears',
#   'tears',
#   'ears',
#   'wears',
#   'appears',
#   'hears',
#   'spears',
#   'bars'],
#  460: ['madman',
#   'girls',
#   'hey',
#   'month',
#   'aye',
#   'son’s',
#   'party',
#   'money',
#   'mob',
#   'idiot',
#   'months',
#   'monster',
#   'monarch',
#   'eager',
#   'soul',
#   'mom',
#   'martells',
#   'moneys',
#   'demon',
#   'monkey',
#   'key',
#   'mo'],
#  492: ['sees',
#   'likes',
#   'takes',
#   'cares',
#   'makes',
#   'spikes',
#   'jokes',
#   'cakes',
#   'shakes'],
#  319: ['mountain',
#   'train',
#   'explain',
#   'second',
#   'certain',
#   'pain',
#   'again',
#   'remain',
#   'rain',
#   'maintain',
#   'captain',
#   'mountains',
#   'main',
#   'gin',
#   'grain'],
#  341: ['lion',
#   'tyrion',
#   'hound',
#   'balon',
#   'balerion',
#   'thoros',
#   'bald',
#   'beric',
#   'dondarrion',
#   'bath',
#   'bar',
#   'wagon',
#   'onion',
#   'bag',
#   'euron'],
#  405: ['there', 'theres', 'therell'],
#  472: ['these',
#   'reason',
#   'treason',
#   'reasons',
#   'tree',
#   'treat',
#   'treasonous',
#   'reasonable'],
#  450: ['beast',
#   'fast',
#   'feast',
#   'island',
#   'guest',
#   'wolf',
#   'cold',
#   'past',
#   'rast',
#   'cock',
#   'waste',
#   'east',
#   'lasts',
#   'corner',
#   'craster',
#   'coast',
#   'pen',
#   'fastest',
#   'toast'],
#  375: ['five',
#   'outsider',
#   'hundreds',
#   'number',
#   'company',
#   'outnumbered',
#   'umber',
#   'four',
#   'outnumber',
#   'numbers',
#   'sour',
#   'umbers'],
#  425: ['hold',
#   'strong',
#   'bold',
#   'wild',
#   'destroy',
#   'weak',
#   'stronger',
#   'stronghold',
#   'strongest',
#   'uphold'],
#  381: ['mother’s', 'husband', 'sister', 'sisters', 'sister’s'],
#  211: ['belong', 'belongs', 'below', 'belonged'],
#  161: ['down', 'sundown', 'sun', 'least', 'town', 'gown', 'dawn', 'taverns'],
#  423: ['better',
#   'letter',
#   'hunter',
#   'matters',
#   'worse',
#   'wore',
#   'matter',
#   'enter',
#   'gutter',
#   'oer'],
#  462: ['death', 'dear', 'deal', 'deaths', 'dealt'],
#  466: ['right',
#   'eight',
#   'host',
#   'fool',
#   'rightful',
#   'bird',
#   'vows',
#   'cost',
#   'birth',
#   'sight',
#   'weight',
#   'bright',
#   'stupidity',
#   'birthright',
#   'sapphires',
#   'height',
#   'alright'],
#  470: ['take', 'wake', 'taken', 'visit', 'stake', 'sake', 'retake', 'retaken'],
#  104: ['yourselves', 'yours', 'yourself', 'themselves', 'ourselves', 'ours'],
#  239: ['bury', 'burned', 'burnt', 'burn', 'burns'],
#  512: ['one’s', 'there’s', 'where’s', 'she’s', 'heres', 'here’s'],
#  421: ['duty',
#   'defend',
#   'defeat',
#   'defense',
#   'defending',
#   'defenses',
#   'defended'],
#  510: ['show', 'knows', 'shove', 'shown', 'shows'],
#  367: ['casterly',
#   'capital',
#   'hands',
#   'river',
#   'westeros',
#   'riverrun',
#   'islands',
#   'westerlands',
#   'riverlands',
#   'eldest',
#   'west',
#   'stormlands',
#   'westerosi'],
#  368: ['foot', 'shoot', 'shoo', 'shot', 'tear', 'shop'],
#  464: ['water',
#   'reads',
#   'eyrie',
#   'wars',
#   'warm',
#   'spread',
#   'sky',
#   'steel',
#   'blue',
#   'ducks',
#   'ingslayer',
#   'path',
#   'camera',
#   'docks',
#   'rope',
#   'warlocks',
#   'odds',
#   'folks',
#   'rocks',
#   'warg',
#   'swings',
#   'pyramid',
#   'slayer',
#   'dozens',
#   'thorns'],
#  372: ['afraid',
#   'meaning',
#   'ready',
#   'morning',
#   'threat',
#   'three',
#   'threw',
#   'winning',
#   'eaten',
#   'running',
#   'beginning',
#   'evening',
#   'threatening',
#   'threaten',
#   'drowning',
#   'listening',
#   'threats',
#   'threatened',
#   'helping',
#   'torturing'],
#  178: ['we’re', 'we’d', 'you’d'],
#  386: ['lannisters', 'lannister', 'lannisport', 'lannister’s', 'martell'],
#  422: ['arryn', 'marry', 'carry', 'arry'],
#  343: ['someone',
#   'little',
#   'hidden',
#   'highborn',
#   'highly',
#   'high',
#   'himself',
#   'higher',
#   'highest'],
#  475: ['rules', 'rule', 'ruler', 'rulers'],
#  222: ['landing', 'lands', 'land'],
#  498: ['brought',
#   'thought',
#   'caught',
#   'fought',
#   'ought',
#   'bought',
#   'taught',
#   'sought'],
#  309: ['rides', 'sides', 'hides', 'hide'],
#  147: ['queen', 'queen’s', 'queens'],
#  394: ['chamber', 'chained', 'chain', 'chairs', 'chair', 'chains'],
#  125: ['drinks', 'drink', 'cup', 'drinking', 'stinks'],
#  533: ['could',
#   'didn’t',
#   'wouldn’t',
#   'shouldn’t',
#   'wouldnt',
#   'couldnt',
#   'couldn’t'],
#  338: ['possibly', 'possible', 'impossible'],
#  532: ['case',
#   'demand',
#   'nose',
#   'reputation',
#   'person',
#   'question',
#   'mention',
#   'position',
#   'action',
#   'affection',
#   'role',
#   'ambition',
#   'direction',
#   'situation',
#   'notion',
#   'imagination',
#   'devotion',
#   'expert',
#   'mandon',
#   'actual',
#   'traditionally',
#   'tradition',
#   'option',
#   'traditions',
#   'expedition'],
#  463: ['stab',
#   'start',
#   'stabbed',
#   'starve',
#   'stag',
#   'stannis',
#   'stars',
#   'heel',
#   'stairs',
#   'stags',
#   'stares',
#   'statue',
#   'courtyard',
#   'stare',
#   'stays',
#   'state'],
#  518: ['royal',
#   'imp',
#   'tavern',
#   'tent',
#   'moment',
#   'meal',
#   'decent',
#   'trident',
#   'aunt',
#   'invitation',
#   'consent',
#   'excuse',
#   'accent',
#   'decided',
#   'bent',
#   'scent',
#   'current',
#   'recent',
#   'amusement',
#   'accident'],
#  324: ['hair', 'air', 'fair'],
#  432: ['grow', 'brown', 'grown'],
#  535: ['brandon',
#   'daughter',
#   'grand',
#   'daughters',
#   'grandfather',
#   'grant',
#   'slaughter',
#   'aemon',
#   'grandsons',
#   'grandson',
#   'grandmother',
#   'granddaughter'],
#  474: ['climbing', 'climb', 'climbed', 'onto', 'climbs', 'cliff'],
#  139: ['promise', 'promised', 'promises'],
#  451: ['sansa', 'sansas', 'aryas'],
#  366: ['grace', 'concerned', 'concerns', 'concern', 'concerning'],
#  506: ['shut', 'hurt', 'gut', 'hut'],
#  145: ['soldier', 'sold', 'soldiers'],
#  454: ['then',
#   'through',
#   'door',
#   'cry',
#   'fields',
#   'neck',
#   'doors',
#   'laugh',
#   'doorstep',
#   'doom'],
#  240: ['loved', 'lived', 'beloved', 'saved'],
#  358: ['teach', 'breach', 'beach', 'reach'],
#  321: ['remember', 'remembered', 'remembers', 'member', 'members'],
#  484: ['fuck',
#   'stick',
#   'stupid',
#   'struck',
#   'luck',
#   'steal',
#   'stead',
#   'lick',
#   'stuck',
#   'suck'],
#  377: ['honor',
#   'alive',
#   'risk',
#   'nobody',
#   'wise',
#   'slow',
#   'otherwise',
#   'raise',
#   'wiser',
#   'noise',
#   'slay',
#   'angry',
#   'rise',
#   'nor',
#   'advise',
#   'devise',
#   'despise',
#   'praise'],
#  399: ['early', 'clean', 'nearly', 'tarly', 'clear', 'clears', 'clearly'],
#  155: ['meant', 'means', 'mean'],
#  371: ['bound',
#   'found',
#   'wound',
#   'around',
#   'ground',
#   'round',
#   'rounds',
#   'surround'],
#  521: ['blood',
#   'left',
#   'bloody',
#   'ahead',
#   'leg',
#   'lock',
#   'knock',
#   'flock',
#   'nock',
#   'mock',
#   'locke',
#   'block'],
#  251: ['call', 'calls', 'tells'],
#  308: ['hates', 'hate', 'hated'],
#  263: ['alone',
#   'inside',
#   'behind',
#   'alongside',
#   'outside',
#   'amongst',
#   'aside',
#   'along',
#   'beside'],
#  525: ['changes',
#   'chances',
#   'ladies',
#   'choices',
#   'resources',
#   'charge',
#   'behalf',
#   'arrive',
#   'marriage',
#   'charges',
#   'confess',
#   'forces',
#   'besides',
#   'centuries',
#   'confessed',
#   'conversation',
#   'notices',
#   'agrees',
#   'marries',
#   'alliances',
#   'graces',
#   'creatures',
#   'hopes',
#   'condolences',
#   'consequences'],
#  438: ['place',
#   'bride',
#   'gift',
#   'pale',
#   'bone',
#   'choice',
#   'face',
#   'pride',
#   'peace',
#   'places',
#   'box',
#   'palace',
#   'pair',
#   'necklace',
#   'kiss',
#   'mace'],
#  542: ['clouds',
#   'brans',
#   'dresses',
#   'patrol',
#   'cloak',
#   'golden',
#   'cloaks',
#   'clans',
#   'glass',
#   'addresses',
#   'goldcloaks'],
#  447: ['dreams', 'dress', 'dreaming', 'dread', 'dreamed', 'dream', 'dreamt'],
#  214: ['isn’t', 'doesn’t', 'does', 'doesnt'],
#  329: ['year', 'week', 'weeks', 'weep'],
#  523: ['asked',
#   'scared',
#   'looked',
#   'knocked',
#   'fucked',
#   'cared',
#   'liked',
#   'talked',
#   'kicked',
#   'worked',
#   'walked',
#   'picked',
#   'mocked',
#   'wicked',
#   'shocked',
#   'locked'],
#  167: ['friends', 'friend', 'friendship'],
#  169: ['woman’s', 'mans', 'womans', 'woman', 'man’s'],
#  441: ['body', 'knife', 'sat', 'throat', 'throats', 'cutthroat'],
#  345: ['history', 'story', 'stories', 'histories'],
#  356: ['known', 'forgot', 'forgotten', 'gotten'],
#  393: ['whole', 'whose', 'whos', 'whom', 'who’s', 'whoa', 'whoever'],
#  279: ['khal', 'khaleesi', 'khals', 'khalasar', 'khaleen'],
#  388: ['finest',
#   'most',
#   'best',
#   'rich',
#   'closest',
#   'oldest',
#   'richest',
#   'biggest',
#   'largest',
#   'chest'],
#  177: ['killers', 'killed', 'killer', 'kills'],
#  323: ['narrow', 'arrow', 'row', 'arrows', 'sparrow'],
#  183: ['lack', 'black', 'siege', 'sack'],
#  380: ['gives', 'lives', 'loves', 'wives'],
#  285: ['prince', 'princess', 'princes'],
#  415: ['powerful', 'power', 'powers'],
#  435: ['seat', 'searching', 'seas', 'search', 'seal'],
#  446: ['greatest', 'great', 'greater'],
#  314: ['making',
#   'being',
#   'letting',
#   'worst',
#   'meeting',
#   'jousting',
#   'joking',
#   'trusting',
#   'rotting',
#   'uniting',
#   'disgusting',
#   'fancy',
#   'worried',
#   'writing',
#   'wasting',
#   'lasting',
#   'resting'],
#  457: ['advice',
#   'spike',
#   'twice',
#   'notice',
#   'voice',
#   'spider',
#   'slice',
#   'spit',
#   'nice',
#   'spite',
#   'spirit',
#   'spice',
#   'spy',
#   'ice'],
#  520: ['used',
#   'dressed',
#   'shoved',
#   'crossed',
#   'passed',
#   'missed',
#   'touched',
#   'pissed',
#   'blessed',
#   'kissed',
#   'raised',
#   'tossed'],
#  453: ['bear', 'heard', 'beard'],
#  485: ['trap',
#   'traveled',
#   'travel',
#   'travels',
#   'bravely',
#   'traveling',
#   'travelling'],
#  473: ['ranger', 'danger', 'strange', 'strangers', 'stranger', 'strangled'],
#  284: ['catelyn', 'ilyn', 'loras', 'lysa', 'llyn', 'meryn'],
#  258: ['field', 'held', 'wield', 'yield', 'shield', 'battlefield'],
#  417: ['become', 'comes', 'becomes'],
#  467: ['fight', 'fighting', 'fighter', 'fights', 'fighters'],
#  461: ['taking',
#   'putting',
#   'selling',
#   'telling',
#   'stealing',
#   'walking',
#   'sitting',
#   'starving',
#   'willing',
#   'killing',
#   'calling',
#   'pulling',
#   'falling',
#   'cutting',
#   'pull'],
#  540: ['stops',
#   'gloves',
#   'finds',
#   'thieves',
#   'keeps',
#   'holds',
#   'tricks',
#   'ranks',
#   'leaves',
#   'tents',
#   'ran',
#   'strikes',
#   'believes',
#   'picks',
#   'reaches',
#   'approaches',
#   'pulls',
#   'retrieves'],
#  402: ['says', 'pays', 'lay', 'lays'],
#  424: ['murdered',
#   'murders',
#   'murder',
#   'betray',
#   'betrayed',
#   'murderer',
#   'murdering',
#   'murderers',
#   'judges'],
#  330: ['different', 'difference', 'differences', 'differently'],
#  448: ['crown',
#   'crops',
#   'crows',
#   'crow',
#   'crowd',
#   'crowded',
#   'crone',
#   'crowns'],
#  384: ['served', 'deserves', 'deserve', 'deserved'],
#  282: ['turned',
#   'ripped',
#   'chopped',
#   'stopped',
#   'wrapped',
#   'stripped',
#   'shipped',
#   'stepped',
#   'slipped',
#   'dropped',
#   'whipped'],
#  493: ['happy', 'kind', 'kinder', 'badly', 'kindly', 'kin'],
#  336: ['pick', 'shit', 'dogs', 'pigs', 'piggy', 'pin', 'pig', 'pit', 'pie'],
#  283: ['spear', 'speaking', 'speaks', 'speak', 'talks', 'asks'],
#  480: ['boar', 'goats', 'boat', 'boats'],
#  469: ['interest', 'interesting', 'interested', 'interests'],
#  483: ['wish', 'punished', 'shed', 'pushed', 'finished', 'crushed', 'wished'],
#  232: ['slaver', 'slaves', 'slave', 'slavery', 'slavers', 'slaver’s'],
#  427: ['fall', 'balls', 'walls', 'halls', 'falls'],
#  527: ['knees', 'knee', 'feels', 'kneel', 'kneeling', 'kneels'],
#  404: ['service',
#   'loyalty',
#   'tully',
#   'faithfully',
#   'faith',
#   'fully',
#   'faithful'],
#  397: ['bread',
#   'breath',
#   'breathing',
#   'break',
#   'breathe',
#   'breast',
#   'breaks',
#   'breaker'],
#  528: ['lost',
#   'manned',
#   'damned',
#   'trained',
#   'received',
#   'realized',
#   'imagined',
#   'poisoned',
#   'enjoyed',
#   'summoned',
#   'ruined',
#   'reckon',
#   'joined',
#   'combined',
#   'signed',
#   'pardoned',
#   'reckoned'],
#  349: ['built', 'build', 'builder', 'builders'],
#  374: ['screamed',
#   'screams',
#   'screamers',
#   'scream',
#   'screaming',
#   'flames',
#   'screamer'],
#  440: ['return', 'turns', 'returning', 'returned', 'returns'],
#  537: ['regards', 'words', 'lords', 'birds', 'terms', 'records'],
#  505: ['septa', 'sept', 'septon', 'septons'],
#  465: ['swords', 'swordsman', 'sell', 'sellsword', 'sellswords'],
#  433: ['20', '500', '10', '300', '2000', '200'],
#  541: ['tits', 'sits', 'suits', 'wits', 'hits', 'opens', 'exits'],
#  305: ['100000', '20000', '10000', '100', '1000', '8000'],
#  339: ['ships', 'sails', 'sail', 'sailed', 'sailing'],
#  273: ['throw', 'thrown', 'drown', 'throws'],
#  502: ['born',
#   'horn',
#   'torn',
#   'lowborn',
#   'stormborn',
#   'trueborn',
#   'ironborn',
#   'reborn',
#   'firstborn'],
#  436: ['part', 'heart', 'cart', 'art'],
#  262: ['books', 'looks', 'book'],
#  360: ['belly',
#   'easily',
#   'finally',
#   'poor',
#   'sally',
#   'silk',
#   'usually',
#   'silly',
#   'drunk',
#   'ally',
#   'rally',
#   'gilly',
#   'mostly',
#   'olly'],
#  265: ['steward', 'reward', 'stew', 'stewards'],
#  294: ['room', 'rooms', 'ros', 'roots', 'root', 'roof', 'roose', 'royce'],
#  353: ['happening', 'happened', 'happen', 'happens'],
#  268: ['follows', 'follow', 'followed', 'following'],
#  346: ['dragons', 'aegon', 'aegons', 'wagons'],
#  504: ['dangerous',
#   'famous',
#   'curious',
#   'ponderous',
#   'busy',
#   'vicious',
#   'important',
#   'jealous',
#   'generous',
#   'serious',
#   'precious',
#   'obvious',
#   'glorious',
#   'nervous',
#   'tedious',
#   'suspicious',
#   'obviously'],
#  280: ['sounds', 'hounds', 'sound', 'wounds'],
#  385: ['bitch', 'catch', 'hatch', 'match', 'pitch', 'witch'],
#  445: ['hasnt', 'hadnt', 'ham', 'ha'],
#  458: ['safe', 'safest', 'safely', 'safety', 'safer'],
#  296: ['joffrey', 'joffreys', 'freys'],
#  288: ['unharmed',
#   'chosen',
#   'chose',
#   'harmed',
#   'armed',
#   'soft',
#   'harm',
#   'escaped',
#   'frightened',
#   'unarmed',
#   'proud',
#   'consumed',
#   'humiliated',
#   'devoted',
#   'respected',
#   'shy',
#   'qyburn',
#   'betraying',
#   'softly',
#   'informed',
#   'niece',
#   'currently',
#   'crucified',
#   'advised',
#   'assumed'],
#  387: ['attacked', 'attack', 'attacks', 'attacking'],
#  290: ['asleep', 'sleep', 'sleeping'],
#  327: ['command', 'commander', 'commands', 'commanded', 'demands'],
#  304: ['rebel', 'rebellion', 'rebelled', 'rebels'],
#  310: ['castles', 'castle', 'cast'],
#  361: ['cities',
#   'lies',
#   'tries',
#   'flies',
#   'dies',
#   'armies',
#   'spies',
#   'bodies',
#   'allies'],
#  486: ['named', 'claim', 'claims', 'claimed'],
#  428: ['knowledge', 'edge', 'pledge', 'sledge', 'pledged'],
#  362: ['able', 'stable', 'stables', 'table'],
#  490: ['brains',
#   'coins',
#   'ruin',
#   'tens',
#   'sins',
#   'wins',
#   'remains',
#   'runs',
#   'twins',
#   'begins',
#   'rains',
#   'ruins'],
#  334: ['flee', 'fleet', 'flesh', 'flea'],
#  357: ['greyjoy', 'greyjoys', 'grey'],
#  400: ['hells', 'cell', 'cells', 'bells'],
#  437: ['cowards', 'toward', 'towards', 'yards'],
#  517: ['marching', 'march', 'marched', 'marches'],
#  344: ['conquer',
#   'conqueror',
#   'conquerors',
#   'conquest',
#   'conquering',
#   'conquered'],
#  364: ['bannermen', 'banner', 'bannerman', 'banners', 'manners', 'band'],
#  489: ['freedom', 'free', 'freed', 'reed'],
#  426: ['healthy', 'wealth', 'wealthy', 'wealthiest'],
#  519: ['paper', 'raped', 'rape', 'rat', 'raper'],
#  526: ['green', 'meereenese', 'shireen', 'meereen', 'mereen'],
#  491: ['bolton', 'boltons', 'bolt', 'ramsay']}

# %% [markdown]
# Sure enough, seems like worse clusters without the phrased data.

# %% [markdown]
# ## Labeling Clusters Using a Hierarchy
#
# Powerpoint presentation [here](https://callminer-my.sharepoint.com/:p:/p/kirsten_stallings/Ef_H9hSc15FPnujGQDGVdp4B6zCQGJZSpjgCs_ZfSBChxQ?e=d6zbhY).
#
# These clusters are insightful, but there's a lot of them to dig through. It's hard to know where to start.
#
# If each cluster had a _label_, we could sort on that label and get things closer together, focusing on the clusters we want to refine first.
#
# In order to label these clusters, we need a resource to know which words tend to get this label. This is the _hierarchy_, a tree of terms.
#
# Each node cruciall has
# - a name or label, like `root-feeling-negative_sentiment-angry`
#
# and each node _might_ have
# - children -  child of `root-feeling-negative_sentiment-angry` might be `root-feeling-negative_sentiment-angry-irate`
# - parents - the parent of `root-feeling-negative_sentiment-angry` is `root-feeling-negative_sentiment`
# - words that are associated with this label, like `upset, frustrated, in_denial, angry`
#
# Each child of that node contains concepts that are more specific.
#
# For instance,
# > dog -> herders -> shetland sheepdog
#
# Given a cluster and a word embedding model, the _labeler_ moves through the hierarchy to determine the best label for this unseen cluster.
#
# ![hiearchy and labeler](figures/hierarchy-and-labeler.png)

# %% [markdown]
# ## The Hierarchy
#
# Here's an example from the hierarchy we created by using clusters from call center data.
#
# ![hierarchy expanding](figures/hierarchy-expanding.gif)
#
# Each of these children of root holds a lot of significance in the call center space. That's the first distinction we make on a word/phrase!
#
# These concepts are crucially never client or product specific. Since this will be used across many different clients, we don't want the product name from one to influence another incorrectly.

# %% [markdown]
# ## The Labeler
#
# The labeler moves throught the hierarchy to find the best fitting name for the unseen cluster generated above in the clustering step.
#
# First, we find the centroid of the unseen cluster. We average all the word vectors to get the _centroid_, a vector that represents this cluster in space.
#
# The labeler is looking to find the closest centroid in the hierarchy to the centroid of the cluster we are currrently looking at. We look at two centroids:
#
# 1. The vectors for the words in the node and it's subtree
# 2. The vectors for only the words in the node.
#
# We use the client's FastText model to calculate the centroids of the hierarchy nodes, effectively projecting the hierarchy into the client's space.
#
# Quiz: _Why is it important to use the client's model here?_
#
# We take all the word vectors in the subtree rooted at the current node and average them to get the centroid. The serves as the middle location for this node in the the client's vector space. For each child of root, we have a centroid.
#
# We also compare with the centroid based on the words at this node _only_. If either of the two of those centroids is closer than the previously-considered-closest centroid, we move to this node in the tree and repeat with its children.
#
# When the closest centroid is found (none of the children's centroids are closer than the current node's), we label this cluster with the name of this node in the hierarchy.
#
# ![moving through the hierarchy](figures/moving-through-the-hierarchy.gif)

# %%
# we can't show you any code for this - we'd have to build a whole new GOT hierarchy

# %% [markdown]
# Here are some examples of the hierarchy and labeler performing on real call center clusters:
#
# ![real life examples](figures/labeled-clusters.png)

# %% [markdown]
# # Summary
# - what is clustering?
# - clustering algorithms
#     - k-means
#     - hierarchical clustering
#         - affinity propagation
# - clustering word embeddings
#     - how to get insight from clusters of word embeddings
# - labeling clusters using a hierarchy
